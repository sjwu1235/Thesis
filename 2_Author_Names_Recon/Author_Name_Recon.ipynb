# %% [markdown]
# # Author Name Recon
#
# This notebook cleans the author names of each paper for the top 5 economic journals for all time using jstor metadata. Running through the cells produces a reconciliation file for the author names as they appear in the masterlists in a raw format. ie: what went in for each author name of an article, what came out and possible aliases. (write this more clearly) I have not filtered on content_type or year.
#
# ## Notes
#
# * Going through this data, some of the citation files for JPE acquired from the chicago journals website has an error where special characters are not encoding properly. I have created a manual resolution of these files, but this should be fixed further up the pipeline. There are only 33 names with this problem and you can't resolve it by using the unidecode library. But, specifically, these files:
#
# {'uchicago_jpe126_1.bib',
#  'uchicago_jpe126_3.bib',
#  'uchicago_jpe126_5.bib',
#  'uchicago_jpe126_6.bib',
#  'uchicago_jpe126_S1.bib',
#  'uchicago_jpe127_1.bib',
#  'uchicago_jpe127_2.bib',
#  'uchicago_jpe127_3.bib',
#  'uchicago_jpe127_4.bib',
#  'uchicago_jpe127_5.bib',
#  'uchicago_jpe128_1.bib',
#  'uchicago_jpe128_10.bib',
#  'uchicago_jpe128_11.bib',
#  'uchicago_jpe128_12.bib',
#  'uchicago_jpe128_2.bib',
#  'uchicago_jpe128_4.bib',
#  'uchicago_jpe128_5.bib',
#  'uchicago_jpe128_7.bib',
#  'uchicago_jpe128_8.bib',
#  'uchicago_jpe128_9.bib'}
# * Resolution of some special characters results in empty string using unicodedata.normalize() function. For example the danish o (o with a slash) does not result in o but rather an empty string. So I have made a function and a accompanying recon file that fixes this.
# * There are some authors which:
#     * have only their initials (even the last name is contracted)
#     * they are just referred to by their last name because of how well known they are.
#     * there are so many authors that only the primary author is mentioned and the others are contracted into a catch-all term like "other", "company" or "co.".
#
#     These are limited and recommend resolving here as they are easily picked out. Todo: Construct a recon file manually compiled to replace these.
#
# **Input**:
# * each of the cleaned masterlists with file ending in \_M_sco_du.xlsx
#
# **Output**:
# * a json file of reconciliated and cleaned author names and associated article URLs
# * a list of UTF-8 characters and the ascii equivalent to which they should resolve.
# * a list of author name corrections for JPE errors
# * TODO: a list of author name corrections for contraction cases, need to do article URL matching.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
from unidecode import unidecode
import re
from datetime import date
import json
import numpy as np
import string
import time
# set column options
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Read in input files

# %%
JOURNALS= ['AER', 'JPE', 'ECTA', 'RES', 'QJE']
#read in all processed masterlists
j_data=pd.DataFrame()
for i in JOURNALS:
    j_data=pd.concat([pd.read_excel('/Users/sijiawu/Work/Refs Danae/Thesis/Data/Combined/'+i+'_M_sco_du.xlsx'), j_data], ignore_index=True)
#Create a batch file

j_data=j_data[j_data.duplicated()==False].ßreset_index().drop('index', axis=1)

# %%
j_data.columns # verify headers
# Out:
# Index(['issue_url', 'ISSN', 'URL', 'journal', 'number', 'publisher', 'title',
#        'urldate', 'volume', 'year', 'abstract', 'author', 'pages',
#        'reviewed-author', 'uploaded', 'content_type', 'author_split',
#        'title_10', 'type', 'authorsSCO', 'titleSCO', 'journalSCO', 'DOI',
#        'affiliations', 'abstractSCO', 'citations', 'document type',
#        'index keywords', 'author keywords', 'document_type'],
#       dtype='object')

# %%
len(j_data) #number of articles
# Out:
# 62262

# %%
j_data["content_type"].value_counts()
# Out:
# content_type
# Article       32882
# Review        13037
# MISC          12466
# Comment        1420
# Reply           834
# Review2         761
# Discussion      709
# Rejoinder       153
# Name: count, dtype: int64

# %% [markdown]
# ## Create a restricted character set

# %%
char_set="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ ,'.-"
chars=[*char_set]

# %% [markdown]
# ## Constants

# %%
auth_ad=[
    "c.p.a.",
    "m.e.",
    "jr.", #junior
    "m.d.",
    "s.j.", #society of jesus
    "s. j.", #society of jesus
    "2nd",
    "3rd",
    "wm.",  #contraction of the given name William
    "yr." #misspelling of junior?
]

# %% [markdown]
# ## Resolve the JPE formatting issue
#
# Please generate the file using the code block at the end of the notebook and manually resolve the errors. Rename the file and run the next two codeblocks.

# %%
with open('jpe_problem_names.json') as f: 
    data = f.read() 
names_repl = json.loads(data)

# %%
for i in j_data.index:
    if j_data.loc[i, "author"] in names_repl.keys():
         j_data.loc[i, "author"]=names_repl[j_data.loc[i, "author"]]

# %% [markdown]
# ## Resolve special characters outside ascii
#
# As above, generate the file using code at the end of the notebook. Or copy in the file.

# %%
with open('spec_char_replacement.json') as f: 
    data = f.read() 
js = json.loads(data) 

def replace_spec_chars(str_in):
    hold=""
    for o in str_in:
        if o.lower() in js.keys():
            hold=hold+js[o.lower()]
        else:
            hold=hold+o
    return hold

# %%
for i in j_data.index:
    if j_data.loc[i, "author"] is not np.NaN:
        if j_data.loc[i, "author"].isascii()==True:
            continue
        j_data.loc[i, "author"]=replace_spec_chars(j_data.loc[i,"author"])
        if j_data.loc[i, "author"].isascii()==False:
            print(j_data.loc[i, "author"])
# Out:
# Ayse İmrohoroglu and Selahattin İmrohoroglu and Douglas H. Joines
# Luisa Fuster and Ayse İmrohoroglu and Selahattin İmrohoroglu
# Mariagiovanna Baccara and Ayse İmrohoroglu and Alistair J. Wilson and Leeat Yariv
# Kaiji Chen and Ayse İmrohoroglu and Selahattin İmrohoroglu
# Ayse İmrohoroglu and Selahattin İmrohoroglu and Douglas H. Joines

# %% [markdown]
# Create a new column where all author names are split by " and ".

# %%
j_data["test"]=j_data['author'].str.split(" and ")

# %% [markdown]
# ## Process author names

# %%
#store the aliases in lists for comparison later
a1=[]
a2=[]
i1=[]
ln=[]


#function for creating aliases
#todo annotate function
def proc_auth(auth_str):
#     print(auth_str)
    auth_split=auth_str.split(" ")
    check=0
    for j in auth_split:
        if "." in j:
            check=check+1
    if check==len(auth_split):
        return [auth_str, auth_str, auth_str, auth_str, 0]

    if len(auth_split)>1:
        init_auth=auth_split[0][0]+'. '+auth_split[-1]
        alt_auth=""
        alt_2_auth=auth_split[0]+" "
        if len(auth_split)>2:
            for k in auth_split[1:-1]:
                alt_2_auth+=k[0]+'. '
        alt_2_auth+=auth_split[-1]
        
        
        for k in auth_split[:-1]:
            alt_auth+=k[0]+'. '
        alt_auth+=auth_split[-1]
        ln.append(auth_split[-1])
        a1.append(alt_2_auth)
        a2.append(alt_auth)
        i1.append(init_auth)
        
        
        
        return [alt_2_auth, alt_auth, init_auth, auth_split[-1]]
    else:
         return[auth_str, auth_str, auth_str, auth_str, 0]

# %%
all_authors=[]
all_authors_a=[]
autht=0
proc_auths_all={}
for i in j_data.index:
    authors=j_data.loc[i,"test"]
    proc_auths={"authors":{}, "year":j_data.loc[i,"year"], 'content_type':j_data.loc[i, "content_type"]}
    if authors is not np.NaN:
        if "suggested" in j_data.loc[i, "author"]:
            print(j_data.loc[i, "author"])
            continue
        for j in range(len(authors)):
            
            sa=authors[j].lower()
            all_authors_a.append(str(sa))
            sa=re.sub('\xa0'," ",sa)
            sa=re.sub("  "," ",sa)
            autht=autht+1
            
            if "," in sa:
                o=None
                for k in auth_ad:
                    p=", "+k
                    if p in sa:
                        o=", "+k
                if o is None:
                    reorg=sa.split(r", ")
                    sa=reorg[1].strip()+ " "+ reorg[0].strip()
           
            all_authors.append(sa)
            proc_auths["authors"][j]={}
            proc_auths["authors"][j]["raw"]=authors[j]
            proc_auths["authors"][j]["init"]=sa
            
            aliases=proc_auth(sa)
            if len(aliases)==5:
                print(sa)
                print(j_data.loc[i,"author"])
                print(j_data.loc[i, "URL"])
                print(j_data.loc[i, "year"])
                print(j_data.loc[i, "journal"])

            proc_auths["authors"][j]["a1"]=aliases[0]
            proc_auths["authors"][j]["a2"]=aliases[1]
            proc_auths["authors"][j]["a3"]=aliases[2]

            if ("[" in sa) or ("(" in sa):
                print(sa)
                print(j_data.loc[i,"author"])
                print(j_data.loc[i, "year"])
                print(j_data.loc[i, "journal"])
                print(j_data.loc[i, "URL"])

    else:
        a=a+1
    proc_auths_all[j_data.loc[i,"URL"]]=proc_auths
# Out:
# e. h. c.
# E. H. C.
# https://www.jstor.org/stable/1885441
# 1929
# The Quarterly Journal of Economics
# f. w. t.
# F. W. T.
# https://www.jstor.org/stable/1886061
# 1909
# The Quarterly Journal of Economics
# f. w. t.
# F. W. T.
# https://www.jstor.org/stable/1883356
# 1907
# The Quarterly Journal of Economics
# e. f. g.
# E. F. G.
# https://www.jstor.org/stable/1884868
# 1904
# The Quarterly Journal of Economics
# w. j. a.
# Frances Gardiner Davenport and W. J. A.
# https://www.jstor.org/stable/1882129
# 1897
# The Quarterly Journal of Economics
# w. j. a.
# Henry W. Wolff and W. J. A.
# https://www.jstor.org/stable/1882880
# 1893
# The Quarterly Journal of Economics
# j. g. b.
# J. G. B.
# https://www.jstor.org/stable/1882518
# 1892
# The Quarterly Journal of Economics
# [samuel b. clarke]
# [Samuel B. Clarke]
# 1891
# The Quarterly Journal of Economics
# https://www.jstor.org/stable/1879614
# jeong ho (john) kim
# JUNEHYUK JUNG and JEONG HO (JOHN) KIM and FILIP MATeJKA and CHRISTOPHER A. SIMS
# 2019
# The Review of Economic Studies
# https://www.jstor.org/stable/26839941
# g. r. e. q. a. m.
# Margaret E. Slade and G. R. E. Q. A. M.
# https://www.jstor.org/stable/2567004
# 1998
# The Review of Economic Studies
# daya
# Daya
# https://www.jstor.org/stable/2296285
# 1954
# The Review of Economic Studies
# fan-hung
# Fan-Hung
# https://www.jstor.org/stable/2967594
# 1939
# The Review of Economic Studies
# evelpides
# Milton Gilbert and Colin Clark and J. R. N. Stone and Francois Perroux and D. K. Lieu and Evelpides and Francois Divisia and Tinbergen and Kuznets and Smithies and Shirras and MacGregor
# https://www.jstor.org/stable/1907313
# 1949
# Econometrica
# tinbergen
# Milton Gilbert and Colin Clark and J. R. N. Stone and Francois Perroux and D. K. Lieu and Evelpides and Francois Divisia and Tinbergen and Kuznets and Smithies and Shirras and MacGregor
# https://www.jstor.org/stable/1907313
# 1949
# Econometrica
# kuznets
# Milton Gilbert and Colin Clark and J. R. N. Stone and Francois Perroux and D. K. Lieu and Evelpides and Francois Divisia and Tinbergen and Kuznets and Smithies and Shirras and MacGregor
# https://www.jstor.org/stable/1907313
# 1949
# Econometrica
# smithies
# Milton Gilbert and Colin Clark and J. R. N. Stone and Francois Perroux and D. K. Lieu and Evelpides and Francois Divisia and Tinbergen and Kuznets and Smithies and Shirras and MacGregor
# https://www.jstor.org/stable/1907313
# 1949
# Econometrica
# shirras
# Milton Gilbert and Colin Clark and J. R. N. Stone and Francois Perroux and D. K. Lieu and Evelpides and Francois Divisia and Tinbergen and Kuznets and Smithies and Shirras and MacGregor
# https://www.jstor.org/stable/1907313
# 1949
# Econometrica
# macgregor
# Milton Gilbert and Colin Clark and J. R. N. Stone and Francois Perroux and D. K. Lieu and Evelpides and Francois Divisia and Tinbergen and Kuznets and Smithies and Shirras and MacGregor
# https://www.jstor.org/stable/1907313
# 1949
# Econometrica
# pertinax
# Pertinax
# https://www.jstor.org/stable/1912140
# 1949
# Econometrica
# sang yoon (tim) lee
# Lee, Sang Yoon (Tim) and Seshadri, Ananth
# 2019
# Journal of Political Economy
# https://doi.org/10.1086/700765
# (suggested by robert e. cumby
# (Suggested by Robert E. Cumby and Douglas W. Elmendorf)
# 2000
# Journal of Political Economy
# https://www.jstor.org/stable/10.1086/317691
# (suggested by francois r. velde)
# (Suggested by Francois R. Velde)
# 2000
# Journal of Political Economy
# https://www.jstor.org/stable/10.1086/317679
# (suggested by arun khanna)
# (Suggested by Arun Khanna)
# 2000
# Journal of Political Economy
# https://www.jstor.org/stable/10.1086/316105
# t. w.
# T. W.
# https://www.jstor.org/stable/1829158
# 1966
# Journal of Political Economy
# w. h. n.
# W. H. N.
# https://www.jstor.org/stable/1824930
# 1946
# Journal of Political Economy
# f. h. k.
# F. H. K.
# https://www.jstor.org/stable/1824130
# 1943
# Journal of Political Economy
# f. h. k.
# F. H. K. and Charles Oman
# https://www.jstor.org/stable/1824307
# 1937
# Journal of Political Economy
# f. h. k.
# F. H. K.
# https://www.jstor.org/stable/1826019
# 1937
# Journal of Political Economy
# l. d. c.
# L. D. C.
# https://www.jstor.org/stable/1822226
# 1933
# Journal of Political Economy
# j. e. ler.
# J. E. LeR.
# https://www.jstor.org/stable/1820273
# 1926
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1820597
# 1926
# Journal of Political Economy
# e. b. b.
# E. B. B.
# https://www.jstor.org/stable/1820825
# 1921
# Journal of Political Economy
# c. c. p.
# C. C. P.
# https://www.jstor.org/stable/1820681
# 1919
# Journal of Political Economy
# h. g. m.
# H. G. M.
# https://www.jstor.org/stable/1821906
# 1919
# Journal of Political Economy
# c. o. h.
# C. O. H.
# https://www.jstor.org/stable/1821907
# 1919
# Journal of Political Economy
# f. m. s.
# F. M. S.
# https://www.jstor.org/stable/1820544
# 1919
# Journal of Political Economy
# i. m. r.
# I. M. R.
# https://www.jstor.org/stable/1821774
# 1917
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1819886
# 1917
# Journal of Political Economy
# j. w. t.
# J. W. T.
# https://www.jstor.org/stable/1820316
# 1917
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1819086
# 1917
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1819741
# 1915
# Journal of Political Economy
# j. p. h.
# J. P. H.
# https://www.jstor.org/stable/1822020
# 1911
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1819223
# 1911
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1820215
# 1911
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1820616
# 1911
# Journal of Political Economy
# c. w. w.
# C. W. W.
# https://www.jstor.org/stable/1819788
# 1910
# Journal of Political Economy
# j. a. f.
# J. A. F.
# https://www.jstor.org/stable/1819790
# 1910
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1820013
# 1910
# Journal of Political Economy
# c. w. w.
# C. W. W.
# https://www.jstor.org/stable/1820801
# 1910
# Journal of Political Economy
# c. w. w.
# C. W. W.
# https://www.jstor.org/stable/1821004
# 1910
# Journal of Political Economy
# a. s. j.
# A. S. J.
# https://www.jstor.org/stable/1829787
# 1910
# Journal of Political Economy
# j. a. f.
# J. A. F.
# https://www.jstor.org/stable/1821811
# 1910
# Journal of Political Economy
# a. s. j.
# A. S. J.
# https://www.jstor.org/stable/1821812
# 1910
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1821816
# 1910
# Journal of Political Economy
# c. w. w.
# C. W. W.
# https://www.jstor.org/stable/1822976
# 1909
# Journal of Political Economy
# j. a. f.
# J. A. F.
# https://www.jstor.org/stable/1822978
# 1909
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1822979
# 1909
# Journal of Political Economy
# s. p. b.
# S. P. B.
# https://www.jstor.org/stable/1822151
# 1909
# Journal of Political Economy
# j. a. f.
# J. A. F.
# https://www.jstor.org/stable/1820893
# 1909
# Journal of Political Economy
# l. c. m.
# L. C. M.
# https://www.jstor.org/stable/1820894
# 1909
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1821828
# 1909
# Journal of Political Economy
# c. w. w.
# C. W. W.
# https://www.jstor.org/stable/1821829
# 1909
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1821830
# 1909
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1820395
# 1909
# Journal of Political Economy
# e. k. e.
# E. K. E.
# https://www.jstor.org/stable/1820397
# 1909
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817902
# 1907
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817903
# 1907
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817904
# 1907
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1817501
# 1907
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1817502
# 1907
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1819997
# 1906
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1819998
# 1906
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1820001
# 1906
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1820002
# 1906
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1817652
# 1906
# Journal of Political Economy
# c. m. h.
# C. M. H.
# https://www.jstor.org/stable/1817655
# 1906
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1817330
# 1906
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1817331
# 1906
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1817473
# 1906
# Journal of Political Economy
# r. m.
# R. M.
# https://www.jstor.org/stable/1817942
# 1906
# Journal of Political Economy
# e. a.
# E. A.
# https://www.jstor.org/stable/1817943
# 1906
# Journal of Political Economy
# e. r. d.
# E. R. D.
# https://www.jstor.org/stable/1817623
# 1906
# Journal of Political Economy
# w.c.m.
# W.C.M.
# https://www.jstor.org/stable/1817552
# 1905
# Journal of Political Economy
# s.p.b.
# S.P.B.
# https://www.jstor.org/stable/1817559
# 1905
# Journal of Political Economy
# j. m.
# J. M.
# https://www.jstor.org/stable/1817563
# 1905
# Journal of Political Economy
# c.m.h.
# C.M.H.
# https://www.jstor.org/stable/1817565
# 1905
# Journal of Political Economy
# s.g.l.
# S.G.L.
# https://www.jstor.org/stable/1817568
# 1905
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817572
# 1905
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817728
# 1904
# Journal of Political Economy
# c.c.p.
# C.C.P.
# https://www.jstor.org/stable/1817730
# 1904
# Journal of Political Economy
# i. w. h.
# I. W. H.
# https://www.jstor.org/stable/1817739
# 1904
# Journal of Political Economy
# i. a. h.
# I. A. H.
# https://www.jstor.org/stable/1819378
# 1904
# Journal of Political Economy
# g. o. v.
# G. O. V.
# https://www.jstor.org/stable/1819380
# 1904
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1819387
# 1904
# Journal of Political Economy
# f. r. c.
# F. R. C.
# https://www.jstor.org/stable/1819390
# 1904
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1819393
# 1904
# Journal of Political Economy
# a. m. w.
# A. M. W.
# https://www.jstor.org/stable/1819394
# 1904
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1819396
# 1904
# Journal of Political Economy
# c. c. p.
# C. C. P.
# https://www.jstor.org/stable/1833354
# 1904
# Journal of Political Economy
# h. j. d.
# H. J. D.
# https://www.jstor.org/stable/1833356
# 1904
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1833361
# 1904
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1819256
# 1904
# Journal of Political Economy
# w. h.
# W. H.
# https://www.jstor.org/stable/1819258
# 1904
# Journal of Political Economy
# a. m. w.
# A. M. W.
# https://www.jstor.org/stable/1820473
# 1903
# Journal of Political Economy
# e. s. m.
# E. S. M.
# https://www.jstor.org/stable/1820475
# 1903
# Journal of Political Economy
# j. m.
# J. M.
# https://www.jstor.org/stable/1820477
# 1903
# Journal of Political Economy
# a. p. w.
# A. P. W.
# https://www.jstor.org/stable/1819325
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1819327
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1819328
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1819329
# 1903
# Journal of Political Economy
# w. h.
# W. H.
# https://www.jstor.org/stable/1819333
# 1903
# Journal of Political Economy
# h. p. w.
# H. P. W.
# https://www.jstor.org/stable/1820961
# 1903
# Journal of Political Economy
# h. p. w.
# H. P. W.
# https://www.jstor.org/stable/1820962
# 1903
# Journal of Political Economy
# h. p. w.
# H. P. W.
# https://www.jstor.org/stable/1820967
# 1903
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1820969
# 1903
# Journal of Political Economy
# j. c.
# J. C.
# https://www.jstor.org/stable/1820971
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817297
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817298
# 1903
# Journal of Political Economy
# g. m. f.
# G. M. F.
# https://www.jstor.org/stable/1817301
# 1903
# Journal of Political Economy
# r. r. k.
# R. R. K.
# https://www.jstor.org/stable/1817303
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817305
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817306
# 1903
# Journal of Political Economy
# w. h.
# W. H.
# https://www.jstor.org/stable/1817311
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817312
# 1903
# Journal of Political Economy
# c. r. h.
# C. R. H.
# https://www.jstor.org/stable/1817317
# 1903
# Journal of Political Economy
# r. r. k.
# R. R. K.
# https://www.jstor.org/stable/1817321
# 1903
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1822624
# 1902
# Journal of Political Economy
# j. h. c.
# J. H. C.
# https://www.jstor.org/stable/1822628
# 1902
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1822631
# 1902
# Journal of Political Economy
# w. h.
# W. H.
# https://www.jstor.org/stable/1822635
# 1902
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1822640
# 1902
# Journal of Political Economy
# c. c. c.
# C. C. C.
# https://www.jstor.org/stable/1822645
# 1902
# Journal of Political Economy
# i. w. h.
# I. W. H.
# https://www.jstor.org/stable/1822648
# 1902
# Journal of Political Economy
# c. c. c.
# C. C. C.
# https://www.jstor.org/stable/1822653
# 1902
# Journal of Political Economy
# w. h.
# W. H.
# https://www.jstor.org/stable/1820248
# 1902
# Journal of Political Economy
# w. c. m.
# W. C. M.
# https://www.jstor.org/stable/1819690
# 1901
# Journal of Political Economy
# a. m. w.
# A. M. W.
# https://www.jstor.org/stable/1819692
# 1901
# Journal of Political Economy
# a. m. w.
# A. M. W.
# https://www.jstor.org/stable/1819694
# 1901
# Journal of Political Economy
# f. a. f.
# F. A. F.
# https://www.jstor.org/stable/1817373
# 1901
# Journal of Political Economy
# f. a. f.
# F. A. F.
# https://www.jstor.org/stable/1817374
# 1901
# Journal of Political Economy
# m. w.
# M. W.
# https://www.jstor.org/stable/1817377
# 1901
# Journal of Political Economy
# c. r. h.
# C. R. H.
# https://www.jstor.org/stable/1817706
# 1900
# Journal of Political Economy
# w. c. m.
# W. C. M.
# https://www.jstor.org/stable/1817709
# 1900
# Journal of Political Economy
# w. c. m.
# W. C. M.
# https://www.jstor.org/stable/1817710
# 1900
# Journal of Political Economy
# t. v.
# T. V.
# https://www.jstor.org/stable/1817712
# 1900
# Journal of Political Economy
# a. c. m.
# A. C. M.
# https://www.jstor.org/stable/1822778
# 1900
# Journal of Political Economy
# t. v.
# T. V.
# https://www.jstor.org/stable/1822781
# 1900
# Journal of Political Economy
# a. c. m.
# A. C. M.
# https://www.jstor.org/stable/1817487
# 1900
# Journal of Political Economy
# a. c. m.
# A. C. M.
# https://www.jstor.org/stable/1817349
# 1900
# Journal of Political Economy
# a. c. m.
# A. C. M.
# https://www.jstor.org/stable/1817350
# 1900
# Journal of Political Economy
# t. v.
# T. V. and William Crookes
# https://www.jstor.org/stable/1817351
# 1900
# Journal of Political Economy
# t. v.
# T. V.
# https://www.jstor.org/stable/1817352
# 1900
# Journal of Political Economy
# t. v.
# T. V.
# https://www.jstor.org/stable/1817353
# 1900
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817960
# 1899
# Journal of Political Economy
# i. w. h.
# I. W. H.
# https://www.jstor.org/stable/1817970
# 1899
# Journal of Political Economy
# w. h.
# W. H.
# https://www.jstor.org/stable/1817971
# 1899
# Journal of Political Economy
# i. w. h.
# I. W. H.
# https://www.jstor.org/stable/1817972
# 1899
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817973
# 1899
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817441
# 1898
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1820370
# 1898
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817758
# 1897
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817793
# 1897
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817798
# 1897
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817799
# 1897
# Journal of Political Economy
# v.
# V.
# https://www.jstor.org/stable/1817807
# 1897
# Journal of Political Economy
# a. c. m.
# A. C. M.
# https://www.jstor.org/stable/1817587
# 1895
# Journal of Political Economy
# h. w. s.
# H. W. S.
# https://www.jstor.org/stable/1817841
# 1895
# Journal of Political Economy
# w.
# W.
# https://www.jstor.org/stable/1819479
# 1894
# Journal of Political Economy
# l.
# L.
# https://www.jstor.org/stable/1817539
# 1893
# Journal of Political Economy
# hei sing (ron) chan
# Hei Sing (Ron) Chan and Maureen L. Cropper and Kabir Malik
# 2014
# The American Economic Review
# https://www.jstor.org/stable/42921003
# xiaoquan (michael) zhang
# Xiaoquan (Michael) Zhang and Feng Zhu
# 2011
# The American Economic Review
# https://www.jstor.org/stable/23045913
# jin (ginger) wu
# Torben G. Andersen and Tim Bollerslev and Francis X. Diebold and Jin (Ginger) Wu
# 2005
# The American Economic Review
# https://www.jstor.org/stable/4132855
# company
# Touche Ross and Company
# https://www.jstor.org/stable/1806876
# 1989
# The American Economic Review
# company
# Touche Ross and Company
# https://www.jstor.org/stable/1804119
# 1987
# The American Economic Review
# co.
# Touche Ross and Co.
# https://www.jstor.org/stable/1814832
# 1985
# The American Economic Review
# company
# Touche Ross and Company
# https://www.jstor.org/stable/1831567
# 1982
# The American Economic Review
# company
# Arthur Andersen and Company
# https://www.jstor.org/stable/1802802
# 1981
# The American Economic Review
# l. a. s., jr.
# L. A. S., Jr.
# https://www.jstor.org/stable/1811482
# 1945
# The American Economic Review
# others
# H. R. Tolley and Others
# https://www.jstor.org/stable/1818464
# 1945
# The American Economic Review
# lt. (j.g.) kenyon e. poole
# Lt. (j.g.) Kenyon E. Poole
# 1944
# The American Economic Review
# https://www.jstor.org/stable/1910756
# n. s. b. g.
# N. S. B. G.
# https://www.jstor.org/stable/1807681
# 1940
# The American Economic Review
# company
# Arthur Andersen and Company
# https://www.jstor.org/stable/1806979
# 1939
# The American Economic Review
# e. w. k.
# E. W. K.
# https://www.jstor.org/stable/1807573
# 1933
# The American Economic Review
# c. e. p.
# C. E. P.
# https://www.jstor.org/stable/1808518
# 1925
# The American Economic Review
# c. d.
# C. D.
# https://www.jstor.org/stable/1803694
# 1918
# The American Economic Review
# g. e. b.
# G. E. B.
# https://www.jstor.org/stable/1805712
# 1918
# The American Economic Review
# a. l. b.
# William R. Camp and A. L. B.
# https://www.jstor.org/stable/1808567
# 1916
# The American Economic Review
# h. c. e.
# H. C. E.
# https://www.jstor.org/stable/1803406
# 1915
# The American Economic Review
# j. l. l.
# J. L. L.
# https://www.jstor.org/stable/1806050
# 1914
# The American Economic Review
# h. b. g.
# H. B. G.
# https://www.jstor.org/stable/1805017
# 1914
# The American Economic Review
# j. m. c.
# J. M. C.
# https://www.jstor.org/stable/1804418
# 1913
# The American Economic Review
# c. c. w.
# C. C. W.
# https://www.jstor.org/stable/1804458
# 1913
# The American Economic Review
# c. c. a.
# C. C. A.
# https://www.jstor.org/stable/1827989
# 1913
# The American Economic Review
# h. b. g.
# H. B. G.
# https://www.jstor.org/stable/1828001
# 1913
# The American Economic Review
# h. b. g.
# H. B. G.
# https://www.jstor.org/stable/1828002
# 1913
# The American Economic Review
# h. b. g.
# H. B. G.
# https://www.jstor.org/stable/1828003
# 1913
# The American Economic Review
# w. f. g.
# W. F. G.
# https://www.jstor.org/stable/1828314
# 1913
# The American Economic Review
# w. b. b.
# W. B. B.
# https://www.jstor.org/stable/1828237
# 1912
# The American Economic Review
# w. f. g.
# W. F. G.
# https://www.jstor.org/stable/1828243
# 1912
# The American Economic Review
# r. f. f.
# R. F. F.
# https://www.jstor.org/stable/1804651
# 1912
# The American Economic Review
# e. w. k.
# E. W. K.
# https://www.jstor.org/stable/1827617
# 1912
# The American Economic Review
# c. w. d.
# C. W. D.
# https://www.jstor.org/stable/1827629
# 1912
# The American Economic Review
# a. b. w.
# A. B. W.
# https://www.jstor.org/stable/1809831
# 1912
# The American Economic Review
# e. v. r.
# E. V. R.
# https://www.jstor.org/stable/1809845
# 1912
# The American Economic Review
# w. b. b.
# W. B. B.
# https://www.jstor.org/stable/1806942
# 1911
# The American Economic Review
# c. c. p.
# C. C. P.
# https://www.jstor.org/stable/1828141
# 1911
# The American Economic Review
# a. a. y.
# A. A. Y.
# https://www.jstor.org/stable/1804307
# 1911
# The American Economic Review
# c. j. b.
# C. J. B.
# https://www.jstor.org/stable/1802943
# 1911
# The American Economic Review
# e. g. b.
# E. G. B.
# https://www.jstor.org/stable/1802947
# 1911
# The American Economic Review
# m. h. r.
# M. H. R.
# https://www.jstor.org/stable/1802956
# 1911
# The American Economic Review

# %% [markdown]
# ## Save the output

# %%
with open("author_proc_"+str(time.time())+".json", "w") as outfile: 
    json.dump(proc_auths_all, outfile, indent=4, default=int)

# %% [markdown]
# ## Compute some stats

# %%
auth_t=list(set(all_authors_a))
u_auth=list(set(all_authors))
u_a1=list(set(a1))
u_a2=list(set(a2))
u_a3=list(set(i1))
u_ln=list(set(ln))
print("The total number of authors: "+ str(len(all_authors)))
print("The number of unique author names without editing: "+ str(len(auth_t)))
print("The number of unique author names after initial processing: "+str(len(u_auth)))
print("Unique alias 1 type names (contracted middle names): "+str(len(u_a1)))
print("Unique alias 2 type names (contracted first names): "+str(len(u_a2)))
print("Unique alias 3 type names (contracted first name + last name): "+str(len(u_a3)))
print("Unique last names: "+str(len(u_ln)))
# Out:
# The total number of authors: 68450
# The number of unique author names without editing: 23164
# The number of unique author names after initial processing: 22559
# Unique alias 1 type names (contracted middle names): 22115
# Unique alias 2 type names (contracted first names): 20289
# Unique alias 3 type names (contracted first name + last name): 17720
# Unique last names: 12562

# %% [markdown]
# ## Top 20 Author Output Ranked for all time

# %%
# after initial process
pd.DataFrame(all_authors).value_counts()[:20]
# Out:
# frank h. knight         113
# george j. stigler        95
# a. b. wolfe              92
# paul a. samuelson        91
# daron acemoglu           85
# f. w. taussig            84
# william j. baumol        83
# m. bronfenbrenner        81
# j. m. clark              79
# jean tirole              77
# joseph e. stiglitz       75
# paul h. douglas          71
# h. parker willis         68
# wesley c. mitchell       67
# milton friedman          66
# franklin m. fisher       64
# harry g. johnson         63
# t. n. carver             60
# j. laurence laughlin     57
# chester w. wright        57
# Name: count, dtype: int64

# %%
# using a1
pd.DataFrame(a1).value_counts()[:20]
# Out:
# frank h. knight       113
# george j. stigler      95
# a. b. wolfe            92
# paul a. samuelson      91
# j. m. clark            88
# daron acemoglu         85
# f. w. taussig          84
# william j. baumol      83
# m. bronfenbrenner      81
# jean tirole            77
# joseph e. stiglitz     75
# paul h. douglas        71
# h. p. willis           70
# wesley c. mitchell     67
# milton friedman        66
# franklin m. fisher     64
# harry g. johnson       63
# frank a. fetter        60
# t. n. carver           60
# j. l. laughlin         58
# Name: count, dtype: int64

# %%
# using a2
pd.DataFrame(a2).value_counts()[:20]
# Out:
# f. h. knight         133
# m. bronfenbrenner    101
# j. m. clark           97
# p. a. samuelson       96
# g. j. stigler         95
# a. b. wolfe           94
# w. j. baumol          90
# f. w. taussig         86
# j. e. stiglitz        86
# d. acemoglu           85
# j. tirole             77
# w. c. mitchell        75
# h. p. willis          74
# p. h. douglas         73
# m. friedman           66
# f. m. fisher          66
# t. n. carver          64
# a. p. lerner          64
# h. g. johnson         63
# f. a. fetter          63
# Name: count, dtype: int64

# %%
# using a3
pd.DataFrame(i1).value_counts()[:20]
# Out:
# f. knight            133
# j. clark             112
# f. fetter            111
# m. bronfenbrenner    101
# r. gordon            101
# j. stiglitz           98
# p. samuelson          98
# g. stigler            97
# a. wolfe              94
# w. baumol             92
# f. taussig            86
# d. acemoglu           85
# w. mitchell           83
# m. feldstein          78
# j. tirole             77
# v. smith              74
# p. douglas            74
# h. willis             74
# j. robinson           73
# c. wright             71
# Name: count, dtype: int64

# %% [markdown]
# ## Frequency of Authors scale of output for all time

# %%
# after initial processing
summary=[]
seq=[0,1,2,5,10,50,100,200,1000]
nms=pd.DataFrame(pd.DataFrame(all_authors).value_counts()).reset_index()
for i in range(len(seq)-1):
#     print("between "+str(seq[i])+" exclusive and "+str(seq[i+1])+ " inclusive")
#     print(nms[(nms["count"]<=seq[i+1])&(nms["count"]>seq[i])].shape[0])
    summary.append({"occurences":str(seq[i])+" < x <= "+str(seq[i+1]), "number":nms[(nms["count"]<=seq[i+1])&(nms["count"]>seq[i])].shape[0]})
    
pd.DataFrame(summary)
# Out:
#         occurences  number
# 0       0 < x <= 1   12873
# 1       1 < x <= 2    3610
# 2       2 < x <= 5    3439
# 3      5 < x <= 10    1610
# 4     10 < x <= 50    1166
# 5    50 < x <= 100      33
# 6   100 < x <= 200       1
# 7  200 < x <= 1000       0

# %%
# first initial + last name
summary=[]
seq=[0,1,2,5,10,50,100,200,1000]
nms=pd.DataFrame(pd.DataFrame(i1).value_counts()).reset_index()
for i in range(len(seq)-1):
#     print("between "+str(seq[i])+" exclusive and "+str(seq[i+1])+ " inclusive")
#     print(nms[(nms["count"]<=seq[i+1])&(nms["count"]>seq[i])].shape[0])
    summary.append({"occurences":str(seq[i])+" < x <= "+str(seq[i+1]), "number":nms[(nms["count"]<=seq[i+1])&(nms["count"]>seq[i])].shape[0]})
    
pd.DataFrame(summary)
# Out:
#         occurences  number
# 0       0 < x <= 1    8824
# 1       1 < x <= 2    2854
# 2       2 < x <= 5    3155
# 3      5 < x <= 10    1640
# 4     10 < x <= 50    1365
# 5    50 < x <= 100      44
# 6   100 < x <= 200       5
# 7  200 < x <= 1000       0

# %%
# Initials and last name
summary=[]
seq=[0,1,2,5,10,50,100,200,1000]
nms=pd.DataFrame(pd.DataFrame(a2).value_counts()).reset_index()
for i in range(len(seq)-1):
    print("between "+str(seq[i])+" exclusive and "+str(seq[i+1])+ " inclusive")
    print(nms[(nms["count"]<=seq[i+1])&(nms["count"]>seq[i])].shape[0])
    summary.append({"occurences":str(seq[i])+" < x <= "+str(seq[i+1]), "number":nms[(nms["count"]<=seq[i+1])&(nms["count"]>seq[i])].shape[0]})
    
pd.DataFrame(summary)
# Out:
# between 0 exclusive and 1 inclusive
# 10915
# between 1 exclusive and 2 inclusive
# 3266
# between 2 exclusive and 5 inclusive
# 3366
# between 5 exclusive and 10 inclusive
# 1637
# between 10 exclusive and 50 inclusive
# 1247
# between 50 exclusive and 100 inclusive
# 39
# between 100 exclusive and 200 inclusive
# 2
# between 200 exclusive and 1000 inclusive
# 0
#         occurences  number
# 0       0 < x <= 1   10915
# 1       1 < x <= 2    3266
# 2       2 < x <= 5    3366
# 3      5 < x <= 10    1637
# 4     10 < x <= 50    1247
# 5    50 < x <= 100      39
# 6   100 < x <= 200       2
# 7  200 < x <= 1000       0

# %%
# contracted middle names
summary=[]
seq=[0,1,2,5,10,50,100,200,1000]
nms=pd.DataFrame(pd.DataFrame(a1).value_counts()).reset_index()
for i in range(len(seq)-1):
#     print("between "+str(seq[i])+" exclusive and "+str(seq[i+1])+ " inclusive")
#     print(nms[(nms["count"]<=seq[i+1])&(nms["count"]>seq[i])].shape[0])
    summary.append({"occurences":str(seq[i])+" < x <= "+str(seq[i+1]), "number":nms[(nms["count"]<=seq[i+1])&(nms["count"]>seq[i])].shape[0]})
    
pd.DataFrame(summary)
# Out:
#         occurences  number
# 0       0 < x <= 1   12542
# 1       1 < x <= 2    3564
# 2       2 < x <= 5    3418
# 3      5 < x <= 10    1619
# 4     10 < x <= 50    1182
# 5    50 < x <= 100      34
# 6   100 < x <= 200       1
# 7  200 < x <= 1000       0

# %% [markdown]
# ## Resolving problem names for JPE
#
# It is just read in above but this is how it should be generated if the file above is not applied to the variable j_data. They are printed to a json file with a unique timestamp please resolve each name, using the URLs below to check for the author name on the article page if the names were cutoff.

# %%
stuff={}
for i in j_data.index:
    authors=j_data.loc[i,"author"]
    if authors is not np.NaN:
        sa=authors.lower()
        if ("{" in sa) or ("\\" in sa):
            print(j_data.loc[i,"author"])
            print(j_data.loc[i, "URL"])
            stuff[j_data.loc[i, "author"]]=j_data.loc[i, "author"]
            print()

with open("jpe_problem_names_"+str(time.time())+".json", "w") as outfile: 
    json.dump(stuff, outfile, indent=4)
# Out:
# Gr\"{o}nqvist, Hans and Nilsson, J. Peter and Robling, Per-Olof
# https://doi.org/10.1086/708725
#
# Foley-Fisher, Nathan and Narajabad, Borghan and Verani, St\'{e}phane
# https://doi.org/10.1086/708817
#
# Hansman, Christopher and Hjort, Jonas and Le\'{o}n-Ciliotta, Gianmarco and Teachout, Matthieu
# https://doi.org/10.1086/708818
#
# Baliga, Sandeep and Sj\"{o}str\"{o}m, Tomas
# https://doi.org/10.1086/707767
#
# Mourifi\'{e
# https://doi.org/10.1086/708724
#
# Harstad, B\r{a}rd
# https://doi.org/10.1086/707024
#
# Alm\r{a}s, Ingvild and Cappelen, Alexander W. and Tungodden, Bertil
# https://doi.org/10.1086/705551
#
# Bhuller, Manudeep and Dahl, Gordon B. and L\o{}ken, Katrine V. and Mogstad, Magne
# https://doi.org/10.1086/705330
#
# Kosse, Fabian and Deckers, Thomas and Pinger, Pia and Schildberg-H\"{o}risch, Hannah and Falk, Armin
# https://doi.org/10.1086/704386
#
# Herrera, Helios and Ordo\~{n}ez, Guillermo and Trebesch, Christoph
# https://doi.org/10.1086/704544
#
# Battaglini, Marco and Harstad, B\r{a}rd
# https://doi.org/10.1086/704610
#
# Calsamiglia, Caterina and Fu, Chao and G\"{u}ell, Maia
# https://doi.org/10.1086/704573
#
# Condorelli, Daniele and Szentes, Bal\'{a}zs
# https://doi.org/10.1086/704574
#
# Ciscato, Edoardo and Galichon, Alfred and Gouss\'{e
# https://doi.org/10.1086/704611
#
# Azevedo, Eduardo M. and Deng, Alex and Montiel Olea, Jos\'{e} Luis and Rao, Justin and Weyl, E. Glen
# https://doi.org/10.1086/710607
#
# Chiappori, Pierre-Andr\'{e} and Oreffice, Sonia and Quintana-Domeque, Climent
# https://doi.org/10.1086/710838
#
# P\'{a}stor, Ľubo\v{s} and Veronesi, Pietro
# https://doi.org/10.1086/710532
#
# Glover, Andrew and Heathcote, Jonathan and Krueger, Dirk and R\'{\i}os-Rull, Jos\'{e}-V\'{\i}ctor
# https://doi.org/10.1086/708820
#
# S\'{a}nchez de la Sierra, Ra\'{u}l
# https://doi.org/10.1086/703989
#
# Borovi\v{c}ka, Jaroslav
# https://doi.org/10.1086/704072
#
# L\'{o}pez, \'{A}ngel L. and Vives, Xavier
# https://doi.org/10.1086/701811
#
# Allen, Jason and Clark, Robert and Houde, Jean-Fran\c{c}ois
# https://doi.org/10.1086/701684
#
# Garcia-Marin, Alvaro and Voigtl\"{a}nder, Nico
# https://doi.org/10.1086/701607
#
# Dur, Umut Mert and \"{U}nver, M. Utku
# https://doi.org/10.1086/701358
#
# Alfaro, Laura and Antr\`{a}s, Pol and Chor, Davin and Conconi, Paola
# https://doi.org/10.1086/700935
#
# Eugster, Beatrix and Parchet, Rapha\"{e}l
# https://doi.org/10.1086/700760
#
# Becker, Gary S. and Kominers, Scott Duke and Murphy, Kevin M. and Spenkuch, J\"{o}rg L.
# https://doi.org/10.1086/698759
#
# Chiappori, Pierre-Andr\'{e} and Dias, Monica Costa and Meghir, Costas
# https://doi.org/10.1086/698748
#
# Cornelissen, Thomas and Dustmann, Christian and Raute, Anna and Sch\"{o}nberg, Uta
# https://doi.org/10.1086/699979
#
# Dur, Umut and Kominers, Scott Duke and Pathak, Parag A. and S\"{o}nmez, Tayfun
# https://doi.org/10.1086/699974
#
# Alan, Sule and Browning, Martin and Ejrn\ae{}s, Mette
# https://doi.org/10.1086/699186
#
# Philippe, Arnaud and Ouss, Aur\'{e}lie
# https://doi.org/10.1086/699210
#
# Desmet, Klaus and Nagy, D\'{a}vid Kriszti\'{a}n and Rossi-Hansberg, Esteban
# https://doi.org/10.1086/697084
#
# Magnac, Thierry and Pistolesi, Nicolas and Roux, S\'{e}bastien
# https://doi.org/10.1086/697206
#
# Bouton, Laurent and Llorente-Saguer, Aniol and Malherbe, Fr\'{e}d\'{e}ric
# https://doi.org/10.1086/695477

# %% [markdown]
# ## Resolving special characters
#
# Todo: optimize this code.
# As above, add in the the unresolvable characters directly in the file and rename it to match the file name above.

# %%
spec_char_set={}

spec_chars=[]
def process_string(str_in):
    if str_in.isascii()==True:
        return str_in
    hold=""
    for o in str_in:
        if o.isascii()==False:
            spec_chars.append(o)
            print(str_in)

for i in j_data.index:
    authors=j_data.loc[i,"author"]
    if authors is not np.NaN:
        sa=authors.lower()
        process_string(sa)
        
u_spec_chars=list(set(spec_chars))
u_spec_chars.sort()

for o in u_spec_chars:
    spec_char_set[o]=unicodedata.normalize("NFKD", o).encode('ascii', 'ignore').decode('utf-8')
    if len(spec_char_set[o])==0:
        print(o)
        
print("end")
        
with open("spec_char_replacement_"+str(time.time())+".json", "w") as outfile: 
    json.dump(spec_char_set, outfile, indent=4)
# Out:
# ayse i̇mrohoroglu and selahattin i̇mrohoroglu and douglas h. joines
# ayse i̇mrohoroglu and selahattin i̇mrohoroglu and douglas h. joines
# luisa fuster and ayse i̇mrohoroglu and selahattin i̇mrohoroglu
# luisa fuster and ayse i̇mrohoroglu and selahattin i̇mrohoroglu
# mariagiovanna baccara and ayse i̇mrohoroglu and alistair j. wilson and leeat yariv
# kaiji chen and ayse i̇mrohoroglu and selahattin i̇mrohoroglu
# kaiji chen and ayse i̇mrohoroglu and selahattin i̇mrohoroglu
# ayse i̇mrohoroglu and selahattin i̇mrohoroglu and douglas h. joines
# ayse i̇mrohoroglu and selahattin i̇mrohoroglu and douglas h. joines
# ̇
# end
