# %%
# libraries required, please install pandas
import pandas as pd
from unidecode import unidecode
import re
from datetime import date
import json
import numpy as np
# set column options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


# change base path to point to the results of the mturk data
# the expectation is that this was directly downloaded from the mturk results interface
base_path="/Users/sijiawu/Downloads/thesis_docs/ref_results/"
base_path="/Users/sijiawu/Downloads/mturk_process/"

# %%
# reading in the mturk processed data, first round
file_names=[
#"progress_ecta_501_results.csv",
#"progress_ecta_1001_results.csv",
# "progress_ecta_1501_results.csv",
# "progress_ecta_2001_results.csv",
# "progress_ecta_2501_results.csv",
# "progress_ecta_2651_results.csv",
# "progress_res_501_results.csv",
# "progress_res_1001_results.csv",
# "progress_res_1501_results.csv",
# "progress_res_2001_results.csv",
# "progress_res_2501_results.csv",
# "progress_jpe_501_results.csv",
# "progress_jpe_1001_results.csv",
# "progress_jpe_1501_results.csv",
# "progress_jpe_2001_results.csv",
# "progress_jpe_2501_results.csv",
# "progress_jpe_3001_results.csv",
# "progress_jpe_3501_results.csv",
# "progress_jpe_4001_results.csv",
# "progress_jpe_4501_results.csv",
# "progress_jpe_5001_results.csv",
# "progress_jpe_5501_results.csv",
# "progress_jpe_6001_results.csv",
# "progress_jpe_6501_results.csv",
# "progress_jpe_7001_results.csv",
# "progress_jpe_7501_results.csv",
# "progress_jpe_8001_results.csv",
# "progress_jpe_8101_results.csv",
# "progress_jpe_8201_results.csv",
# "progress_jpe_8301_results.csv",
# "progress_jpe_8401_results.csv",
# "progress_jpe_8501_results.csv",
# "progress_jpe_8601_results.csv",
# "progress_jpe_8701_results.csv",
# "progress_jpe_8801_results.csv",
# "progress_jpe_8901_results.csv",
# "progress_jpe_9001_results.csv",
# "progress_jpe_9501_results.csv",
# "progress_jpe_10001_results.csv",
# "progress_jpe_10168_results.csv",
# "progress_qje_wo_nones_501_results.csv",
# "progress_qje_wo_nones_1001_results.csv",
    
#     "progress_qje_wo_nones_1501_results.csv",
#     "progress_qje_wo_nones_2001_results.csv",
#     "progress_qje_wo_nones_5501_results.csv",
    
#     "progress_qje_wo_nones_2501_results.csv",
#     "progress_qje_wo_nones_4001_results.csv",
#     "progress_qje_wo_nones_4501_results.csv",
#     "progress_qje_wo_nones_5001_results.csv",
]

All=[]
for i in file_names:
    All.append(pd.read_csv(base_path+i))
All=pd.concat(All, ignore_index=True)
All.shape
# Out:
# (427, 198)

# %%
# some column renaming
dict = {'Answer.ref1.1':'Answer.1.1',
'Answer.ref1.2':'Answer.1.2',
'Answer.ref1.3':'Answer.1.3',
'Answer.ref1.4':'Answer.1.4',
'Answer.ref1.5':'Answer.1.5',
'Answer.ref1.6':'Answer.1.6',
'Answer.ref1.7':'Answer.1.7',
'Answer.ref2.1':'Answer.2.1',
'Answer.ref2.2':'Answer.2.2',
'Answer.ref2.3':'Answer.2.3',
'Answer.ref2.4':'Answer.2.4',
'Answer.ref2.5':'Answer.2.5',
'Answer.ref2.6':'Answer.2.6',
'Answer.ref2.7':'Answer.2.7',
'Answer.ref3.1':'Answer.3.1',
'Answer.ref3.2':'Answer.3.2',
'Answer.ref3.3':'Answer.3.3',
'Answer.ref3.4':'Answer.3.4',
'Answer.ref3.5':'Answer.3.5',
'Answer.ref3.6':'Answer.3.6',
'Answer.ref3.7':'Answer.3.7',
'Answer.ref4.1':'Answer.4.1',
'Answer.ref4.2':'Answer.4.2',
'Answer.ref4.3':'Answer.4.3',
'Answer.ref4.4':'Answer.4.4',
'Answer.ref4.5':'Answer.4.5',
'Answer.ref4.6':'Answer.4.6',
'Answer.ref4.7':'Answer.4.7',
'Answer.ref5.1':'Answer.5.1',
'Answer.ref5.2':'Answer.5.2',
'Answer.ref5.3':'Answer.5.3',
'Answer.ref5.4':'Answer.5.4',
'Answer.ref5.5':'Answer.5.5',
'Answer.ref5.6':'Answer.5.6',
'Answer.ref5.7':'Answer.5.7',
'Answer.ref6.1':'Answer.6.1',
'Answer.ref6.2':'Answer.6.2',
'Answer.ref6.3':'Answer.6.3',
'Answer.ref6.4':'Answer.6.4',
'Answer.ref6.5':'Answer.6.5',
'Answer.ref6.6':'Answer.6.6',
'Answer.ref6.7':'Answer.6.7',
'Answer.ref7.1':'Answer.7.1',
'Answer.ref7.2':'Answer.7.2',
'Answer.ref7.3':'Answer.7.3',
'Answer.ref7.4':'Answer.7.4',
'Answer.ref7.5':'Answer.7.5',
'Answer.ref7.6':'Answer.7.6',
'Answer.ref7.7':'Answer.7.7',
'Answer.ref8.1':'Answer.8.1',
'Answer.ref8.2':'Answer.8.2',
'Answer.ref8.3':'Answer.8.3',
'Answer.ref8.4':'Answer.8.4',
'Answer.ref8.5':'Answer.8.5',
'Answer.ref8.6':'Answer.8.6',
'Answer.ref8.7':'Answer.8.7',
'Answer.ref9.1':'Answer.9.1',
'Answer.ref9.2':'Answer.9.2',
'Answer.ref9.3':'Answer.9.3',
'Answer.ref9.4':'Answer.9.4',
'Answer.ref9.5':'Answer.9.5',
'Answer.ref9.6':'Answer.9.6',
'Answer.ref9.7':'Answer.9.7',
'Answer.ref10.1':'Answer.10.1',
'Answer.ref10.2':'Answer.10.2',
'Answer.ref10.3':'Answer.10.3',
'Answer.ref10.4':'Answer.10.4',
'Answer.ref10.5':'Answer.10.5',
'Answer.ref10.6':'Answer.10.6',
'Answer.ref10.7':'Answer.10.7',
'Answer.ref11.1':'Answer.11.1',
'Answer.ref11.2':'Answer.11.2',
'Answer.ref11.3':'Answer.11.3',
'Answer.ref11.4':'Answer.11.4',
'Answer.ref11.5':'Answer.11.5',
'Answer.ref11.6':'Answer.11.6',
'Answer.ref11.7':'Answer.11.7',
'Answer.ref12.1':'Answer.12.1',
'Answer.ref12.2':'Answer.12.2',
'Answer.ref12.3':'Answer.12.3',
'Answer.ref12.4':'Answer.12.4',
'Answer.ref12.5':'Answer.12.5',
'Answer.ref12.6':'Answer.12.6',
'Answer.ref12.7':'Answer.12.7',
'Answer.ref13.1':'Answer.13.1',
'Answer.ref13.2':'Answer.13.2',
'Answer.ref13.3':'Answer.13.3',
'Answer.ref13.4':'Answer.13.4',
'Answer.ref13.5':'Answer.13.5',
'Answer.ref13.6':'Answer.13.6',
'Answer.ref13.7':'Answer.13.7',
'Answer.ref14.1':'Answer.14.1',
'Answer.ref14.2':'Answer.14.2',
'Answer.ref14.3':'Answer.14.3',
'Answer.ref14.4':'Answer.14.4',
'Answer.ref14.5':'Answer.14.5',
'Answer.ref14.6':'Answer.14.6',
'Answer.ref14.7':'Answer.14.7',
'Answer.ref15.1':'Answer.15.1',
'Answer.ref15.2':'Answer.15.2',
'Answer.ref15.3':'Answer.15.3',
'Answer.ref15.4':'Answer.15.4',
'Answer.ref15.5':'Answer.15.5',
'Answer.ref15.6':'Answer.15.6',
'Answer.ref15.7':'Answer.15.7',
'Answer.ref16.1':'Answer.16.1',
'Answer.ref16.2':'Answer.16.2',
'Answer.ref16.3':'Answer.16.3',
'Answer.ref16.4':'Answer.16.4',
'Answer.ref16.5':'Answer.16.5',
'Answer.ref16.6':'Answer.16.6',
'Answer.ref16.7':'Answer.16.7',

       }

All=All.rename(columns=dict)

# list of columns to drop
lst=['HITTypeId',
 'Title',
 'Description',
 'Keywords',
 'Reward',
 'CreationTime',
 'MaxAssignments',
 'RequesterAnnotation',
 'AssignmentDurationInSeconds',
 'AutoApprovalDelayInSeconds',
 'Expiration',
 'NumberOfSimilarHITs',
 'LifetimeInSeconds',
 'AssignmentId',
 'AssignmentStatus',
 'AcceptTime',
 'AutoApprovalTime',
 'ApprovalTime',
 'RejectionTime',
 'LifetimeApprovalRate',
 'Last30DaysApprovalRate',
 'Last7DaysApprovalRate',
 'SubmitTime']

All=All.drop(lst, axis=1)

# add for number of referencing counts
All["num_refs"] = None

# %%
All.sort_index(axis=1, inplace=True)
All.head()
# Out:
#   Answer.1.1 Answer.1.2 Answer.1.3 Answer.1.4 Answer.1.5 Answer.1.6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3      False      False       True      False      False      False
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.1.7 Answer.2.1 Answer.2.2 Answer.2.3 Answer.2.4 Answer.2.5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3      False      False      False       True      False      False
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.2.6 Answer.2.7 Answer.3.1 Answer.3.2 Answer.3.3 Answer.3.4  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3      False      False      False      False       True      False
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.3.5 Answer.3.6 Answer.3.7 Answer.4.1 Answer.4.2 Answer.4.3  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3      False      False      False      False       True      False
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.4.4 Answer.4.5 Answer.4.6 Answer.4.7 Answer.5.1 Answer.5.2  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3      False      False      False      False      False      False
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.5.3 Answer.5.4 Answer.5.5 Answer.5.6 Answer.5.7 Answer.6.1  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3       True      False      False      False      False        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.6.2 Answer.6.3 Answer.6.4 Answer.6.5 Answer.6.6 Answer.6.7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.7.1 Answer.7.2 Answer.7.3 Answer.7.4 Answer.7.5 Answer.7.6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.7.7 Answer.8.1 Answer.8.2 Answer.8.3 Answer.8.4 Answer.8.5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Answer.8.6 Answer.8.7 Answer.button  Answer.cutoff.on  \
# 0        NaN        NaN             +             False
# 1        NaN        NaN             +             False
# 2        NaN        NaN             +             False
# 3        NaN        NaN             -              True
# 4        NaN        NaN             +             False
#
#                       Answer.ref.0_author Answer.ref.0_chapter_title  \
# 0                           Ragnar Frisch                        NaN
# 1                             G. A. Bliss                       none
# 2  Norman S. Buchanan and Howard S. Ellis                       none
# 3                         R. Warren James                        NaN
# 4                                  Mixter                       none
#
#   Answer.ref.0_issue                                  Answer.ref.0_journal  \
# 0               none                      Zeitschrift fur Nationalokonomie
# 1                NaN                                                   NaN
# 2                NaN                                                   NaN
# 3               none  Canadian  Journal of Economics and Political Science
# 4                NaN                                                   NaN
#
#   Answer.ref.0_location Answer.ref.0_pages        Answer.ref.0_publisher  \
# 0                   NaN             62-163                           NaN
# 1                  none               none  University of  Chicago Press
# 2              New York                424       Twentieth  Century Fund
# 3                   NaN                142                           NaN
# 4                  none               none                          none
#
#   Answer.ref.0_textfull  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
#                                                               Answer.ref.0_title  \
# 0  Einige Punkte einer Preistheorie mit Boden und Arbeit als Produktionsfaktoren
# 1                                         Lectures on the Calculus of Variations
# 2                                            Approaches to  Economic Development
# 3                                                  The Life and Work of John Rae
# 4                                                 Sociological Theory of Capital
#
#   Answer.ref.0_vol Answer.ref.0_year Answer.ref.1_author  \
# 0              III              1931                 NaN
# 1             none              1946                 NaN
# 2             none              1955                 NaN
# 3             XVII              1951                 Rae
# 4             none              none                 NaN
#
#   Answer.ref.1_chapter_title Answer.ref.1_issue Answer.ref.1_journal  \
# 0                        NaN                NaN                  NaN
# 1                        NaN                NaN                  NaN
# 2                        NaN                NaN                  NaN
# 3                       none                NaN                  NaN
# 4                        NaN                NaN                  NaN
#
#   Answer.ref.1_location Answer.ref.1_pages Answer.ref.1_publisher  \
# 0                   NaN                NaN                    NaN
# 1                   NaN                NaN                    NaN
# 2                   NaN                NaN                    NaN
# 3                Boston               none                   none
# 4                   NaN                NaN                    NaN
#
#   Answer.ref.1_textfull  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
#                                                                                                                                                                            Answer.ref.1_title  \
# 0                                                                                                                                                                                         NaN
# 1                                                                                                                                                                                         NaN
# 2                                                                                                                                                                                         NaN
# 3  Statement of Some New Principles on the Subject of Political  Economy, Exposing the Fallacies of the System of Free Trade and of Some Other  Doctrines Maintained in the "Wealth of Nation
# 4                                                                                                                                                                                         NaN
#
#   Answer.ref.1_vol Answer.ref.1_year Answer.ref.2_author  \
# 0              NaN               NaN                 NaN
# 1              NaN               NaN                 NaN
# 2              NaN               NaN                 NaN
# 3             none              1834      Helmut Lehmann
# 4              NaN               NaN                 NaN
#
#   Answer.ref.2_chapter_title Answer.ref.2_issue Answer.ref.2_journal  \
# 0                        NaN                NaN                  NaN
# 1                        NaN                NaN                  NaN
# 2                        NaN                NaN                  NaN
# 3                       none                NaN                  NaN
# 4                        NaN                NaN                  NaN
#
#   Answer.ref.2_location Answer.ref.2_pages Answer.ref.2_publisher  \
# 0                   NaN                NaN                    NaN
# 1                   NaN                NaN                    NaN
# 2                   NaN                NaN                    NaN
# 3               Dresden               none                   none
# 4                   NaN                NaN                    NaN
#
#   Answer.ref.2_textfull  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
#                                                                         Answer.ref.2_title  \
# 0                                                                                      NaN
# 1                                                                                      NaN
# 2                                                                                      NaN
# 3  Helmut Lehmann's John Raes Werk, seine  philosophischen und methodologischen Grundlagen
# 4                                                                                      NaN
#
#   Answer.ref.2_vol Answer.ref.2_year Answer.ref.3_author  \
# 0              NaN               NaN                 NaN
# 1              NaN               NaN                 NaN
# 2              NaN               NaN                 NaN
# 3             none              1937          J. S. Mill
# 4              NaN               NaN                 NaN
#
#   Answer.ref.3_chapter_title Answer.ref.3_issue Answer.ref.3_journal  \
# 0                        NaN                NaN                  NaN
# 1                        NaN                NaN                  NaN
# 2                        NaN                NaN                  NaN
# 3                       none                NaN                  NaN
# 4                        NaN                NaN                  NaN
#
#   Answer.ref.3_location Answer.ref.3_pages Answer.ref.3_publisher  \
# 0                   NaN                NaN                    NaN
# 1                   NaN                NaN                    NaN
# 2                   NaN                NaN                    NaN
# 3                  none            97, 129                   none
# 4                   NaN                NaN                    NaN
#
#   Answer.ref.3_textfull               Answer.ref.3_title Answer.ref.3_vol  \
# 0                   NaN                              NaN              NaN
# 1                   NaN                              NaN              NaN
# 2                   NaN                              NaN              NaN
# 3                   NaN  Principles of Political Economy             none
# 4                   NaN                              NaN              NaN
#
#   Answer.ref.3_year Answer.ref.4_author Answer.ref.4_chapter_title  \
# 0               NaN                 NaN                        NaN
# 1               NaN                 NaN                        NaN
# 2               NaN                 NaN                        NaN
# 3              none               James                        NaN
# 4               NaN                 NaN                        NaN
#
#   Answer.ref.4_issue Answer.ref.4_journal Answer.ref.4_location  \
# 0                NaN                  NaN                   NaN
# 1                NaN                  NaN                   NaN
# 2                NaN                  NaN                   NaN
# 3               none            Economica                   NaN
# 4                NaN                  NaN                   NaN
#
#   Answer.ref.4_pages Answer.ref.4_publisher Answer.ref.4_textfull  \
# 0                NaN                    NaN                   NaN
# 1                NaN                    NaN                   NaN
# 2                NaN                    NaN                   NaN
# 3                254                    NaN                   NaN
# 4                NaN                    NaN                   NaN
#
#                                  Answer.ref.4_title Answer.ref.4_vol  \
# 0                                               NaN              NaN
# 1                                               NaN              NaN
# 2                                               NaN              NaN
# 3  John Rae and John  Stuart Mill: A Correspondence                X
# 4                                               NaN              NaN
#
#   Answer.ref.4_year Answer.ref.5_author Answer.ref.5_chapter_title  \
# 0               NaN                 NaN                        NaN
# 1               NaN                 NaN                        NaN
# 2               NaN                 NaN                        NaN
# 3              1943   Charles W. Mixter                       none
# 4               NaN                 NaN                        NaN
#
#   Answer.ref.5_issue Answer.ref.5_journal Answer.ref.5_location  \
# 0                NaN                  NaN                   NaN
# 1                NaN                  NaN                   NaN
# 2                NaN                  NaN                   NaN
# 3                NaN                  NaN              New York
# 4                NaN                  NaN                   NaN
#
#   Answer.ref.5_pages Answer.ref.5_publisher Answer.ref.5_textfull  \
# 0                NaN                    NaN                   NaN
# 1                NaN                    NaN                   NaN
# 2                NaN                    NaN                   NaN
# 3               none                   none                   NaN
# 4                NaN                    NaN                   NaN
#
#                    Answer.ref.5_title Answer.ref.5_vol Answer.ref.5_year  \
# 0                                 NaN              NaN               NaN
# 1                                 NaN              NaN               NaN
# 2                                 NaN              NaN               NaN
# 3  The Sociological Theory of Capital             none              1905
# 4                                 NaN              NaN               NaN
#
#   Answer.ref.6_author Answer.ref.6_chapter_title Answer.ref.6_issue  \
# 0                 NaN                        NaN                NaN
# 1                 NaN                        NaN                NaN
# 2                 NaN                        NaN                NaN
# 3                 NaN                        NaN                NaN
# 4                 NaN                        NaN                NaN
#
#   Answer.ref.6_journal Answer.ref.6_location Answer.ref.6_pages  \
# 0                  NaN                   NaN                NaN
# 1                  NaN                   NaN                NaN
# 2                  NaN                   NaN                NaN
# 3                  NaN                   NaN                NaN
# 4                  NaN                   NaN                NaN
#
#   Answer.ref.6_publisher Answer.ref.6_textfull Answer.ref.6_title  \
# 0                    NaN                   NaN                NaN
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
#
#   Answer.ref.6_vol Answer.ref.6_year Answer.ref.7_author  \
# 0              NaN               NaN                 NaN
# 1              NaN               NaN                 NaN
# 2              NaN               NaN                 NaN
# 3              NaN               NaN                 NaN
# 4              NaN               NaN                 NaN
#
#   Answer.ref.7_chapter_title Answer.ref.7_location  Answer.ref.7_pages  \
# 0                        NaN                   NaN                 NaN
# 1                        NaN                   NaN                 NaN
# 2                        NaN                   NaN                 NaN
# 3                        NaN                   NaN                 NaN
# 4                        NaN                   NaN                 NaN
#
#   Answer.ref.7_publisher Answer.ref.7_textfull Answer.ref.7_title  \
# 0                    NaN                   NaN                NaN
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
#
#   Answer.ref.7_vol  Answer.ref.7_year Answer.ref.8_author Answer.ref.8_issue  \
# 0              NaN                NaN                 NaN                NaN
# 1              NaN                NaN                 NaN                NaN
# 2              NaN                NaN                 NaN                NaN
# 3              NaN                NaN                 NaN                NaN
# 4              NaN                NaN                 NaN                NaN
#
#   Answer.ref.8_journal Answer.ref.8_pages Answer.ref.8_publisher  \
# 0                  NaN                NaN                    NaN
# 1                  NaN                NaN                    NaN
# 2                  NaN                NaN                    NaN
# 3                  NaN                NaN                    NaN
# 4                  NaN                NaN                    NaN
#
#   Answer.ref.8_textfull Answer.ref.8_title Answer.ref.8_vol  \
# 0                   NaN                NaN              NaN
# 1                   NaN                NaN              NaN
# 2                   NaN                NaN              NaN
# 3                   NaN                NaN              NaN
# 4                   NaN                NaN              NaN
#
#    Answer.ref.8_year  Answer.ref0.1  Answer.ref0.2  Answer.ref0.3  \
# 0                NaN          False           True          False
# 1                NaN          False          False           True
# 2                NaN          False          False           True
# 3                NaN          False           True          False
# 4                NaN          False          False           True
#
#    Answer.ref0.4  Answer.ref0.5  Answer.ref0.6  Answer.ref0.7  Approve  \
# 0          False          False          False          False      NaN
# 1          False          False          False          False      NaN
# 2          False          False          False          False      NaN
# 3          False          False          False          False      NaN
# 4          False          False          False          False      NaN
#
#                             HITId  Input.ID       Input.authors  Input.issue  \
# 0  3421H3BMAHC4AFXNR95VXICNLF39JR   1883824   Paul A. Samuelson            1
# 1  3L7SUC0TU1PCFTFVUAZUKZ3BM540MA   1883824   Paul A. Samuelson            1
# 2  31MCUE39CRH84BI62UJI9SHLTVC3G0   1880619     Howard S. Ellis            3
# 3  379OL9DBTZ9U54SMD96Y75RBYJBY99   1880611  Joseph J. Spengler            3
# 4  3EGKVCRQG3NDTX7JBTKUYBM1MJEYBJ   1880611  Joseph J. Spengler            3
#
#   Input.journal  Input.page  \
# 0           QJE          20
# 1           QJE          24
# 2           QJE           0
# 3           QJE           0
# 4           QJE           9
#
#                                                                                    Input.pdf_url  \
# 0  'https://myawsbucket-1231.s3.eu-west-3.amazonaws.com/QJE_shards/1883824_wo_cover_page-20.pdf'
# 1  'https://myawsbucket-1231.s3.eu-west-3.amazonaws.com/QJE_shards/1883824_wo_cover_page-24.pdf'
# 2   'https://myawsbucket-1231.s3.eu-west-3.amazonaws.com/QJE_shards/1880619_wo_cover_page-0.pdf'
# 3   'https://myawsbucket-1231.s3.eu-west-3.amazonaws.com/QJE_shards/1880611_wo_cover_page-0.pdf'
# 4   'https://myawsbucket-1231.s3.eu-west-3.amazonaws.com/QJE_shards/1880611_wo_cover_page-9.pdf'
#
#                                                                                            Input.title  \
# 0  A Modern Treatment of the Ricardian Economy: I. The Pricing of Goods and of Labor and Land Services
# 1  A Modern Treatment of the Ricardian Economy: I. The Pricing of Goods and of Labor and Land Services
# 2                                   [Accelerated Investment as a Force in Economic Development]: Reply
# 3                                                             John Rae on Economic Development: A Note
# 4                                                             John Rae on Economic Development: A Note
#
#    Input.vol  Input.year  Reject  RequesterFeedback  WorkTimeInSeconds  \
# 0         73        1959     NaN                NaN                 70
# 1         73        1959     NaN                NaN                127
# 2         73        1959     NaN                NaN                105
# 3         73        1959     NaN                NaN                509
# 4         73        1959     NaN                NaN                 53
#
#          WorkerId num_refs
# 0  A2ZTHO3A0JXRPM     None
# 1  A2ZTHO3A0JXRPM     None
# 2  A2ZTHO3A0JXRPM     None
# 3  A2ZTHO3A0JXRPM     None
# 4  A2ZTHO3A0JXRPM     None

# %%
for i in range(0,30,1):
    for j in range(1,8,1):
        print("\'Answer.ref"+str(i)+"."+str(j)+"\':"+"\'Answer."+str(i)+"."+str(j)+"\',")
# Out:
# 'Answer.ref0.1':'Answer.0.1',
# 'Answer.ref0.2':'Answer.0.2',
# 'Answer.ref0.3':'Answer.0.3',
# 'Answer.ref0.4':'Answer.0.4',
# 'Answer.ref0.5':'Answer.0.5',
# 'Answer.ref0.6':'Answer.0.6',
# 'Answer.ref0.7':'Answer.0.7',
# 'Answer.ref1.1':'Answer.1.1',
# 'Answer.ref1.2':'Answer.1.2',
# 'Answer.ref1.3':'Answer.1.3',
# 'Answer.ref1.4':'Answer.1.4',
# 'Answer.ref1.5':'Answer.1.5',
# 'Answer.ref1.6':'Answer.1.6',
# 'Answer.ref1.7':'Answer.1.7',
# 'Answer.ref2.1':'Answer.2.1',
# 'Answer.ref2.2':'Answer.2.2',
# 'Answer.ref2.3':'Answer.2.3',
# 'Answer.ref2.4':'Answer.2.4',
# 'Answer.ref2.5':'Answer.2.5',
# 'Answer.ref2.6':'Answer.2.6',
# 'Answer.ref2.7':'Answer.2.7',
# 'Answer.ref3.1':'Answer.3.1',
# 'Answer.ref3.2':'Answer.3.2',
# 'Answer.ref3.3':'Answer.3.3',
# 'Answer.ref3.4':'Answer.3.4',
# 'Answer.ref3.5':'Answer.3.5',
# 'Answer.ref3.6':'Answer.3.6',
# 'Answer.ref3.7':'Answer.3.7',
# 'Answer.ref4.1':'Answer.4.1',
# 'Answer.ref4.2':'Answer.4.2',
# 'Answer.ref4.3':'Answer.4.3',
# 'Answer.ref4.4':'Answer.4.4',
# 'Answer.ref4.5':'Answer.4.5',
# 'Answer.ref4.6':'Answer.4.6',
# 'Answer.ref4.7':'Answer.4.7',
# 'Answer.ref5.1':'Answer.5.1',
# 'Answer.ref5.2':'Answer.5.2',
# 'Answer.ref5.3':'Answer.5.3',
# 'Answer.ref5.4':'Answer.5.4',
# 'Answer.ref5.5':'Answer.5.5',
# 'Answer.ref5.6':'Answer.5.6',
# 'Answer.ref5.7':'Answer.5.7',
# 'Answer.ref6.1':'Answer.6.1',
# 'Answer.ref6.2':'Answer.6.2',
# 'Answer.ref6.3':'Answer.6.3',
# 'Answer.ref6.4':'Answer.6.4',
# 'Answer.ref6.5':'Answer.6.5',
# 'Answer.ref6.6':'Answer.6.6',
# 'Answer.ref6.7':'Answer.6.7',
# 'Answer.ref7.1':'Answer.7.1',
# 'Answer.ref7.2':'Answer.7.2',
# 'Answer.ref7.3':'Answer.7.3',
# 'Answer.ref7.4':'Answer.7.4',
# 'Answer.ref7.5':'Answer.7.5',
# 'Answer.ref7.6':'Answer.7.6',
# 'Answer.ref7.7':'Answer.7.7',
# 'Answer.ref8.1':'Answer.8.1',
# 'Answer.ref8.2':'Answer.8.2',
# 'Answer.ref8.3':'Answer.8.3',
# 'Answer.ref8.4':'Answer.8.4',
# 'Answer.ref8.5':'Answer.8.5',
# 'Answer.ref8.6':'Answer.8.6',
# 'Answer.ref8.7':'Answer.8.7',
# 'Answer.ref9.1':'Answer.9.1',
# 'Answer.ref9.2':'Answer.9.2',
# 'Answer.ref9.3':'Answer.9.3',
# 'Answer.ref9.4':'Answer.9.4',
# 'Answer.ref9.5':'Answer.9.5',
# 'Answer.ref9.6':'Answer.9.6',
# 'Answer.ref9.7':'Answer.9.7',
# 'Answer.ref10.1':'Answer.10.1',
# 'Answer.ref10.2':'Answer.10.2',
# 'Answer.ref10.3':'Answer.10.3',
# 'Answer.ref10.4':'Answer.10.4',
# 'Answer.ref10.5':'Answer.10.5',
# 'Answer.ref10.6':'Answer.10.6',
# 'Answer.ref10.7':'Answer.10.7',
# 'Answer.ref11.1':'Answer.11.1',
# 'Answer.ref11.2':'Answer.11.2',
# 'Answer.ref11.3':'Answer.11.3',
# 'Answer.ref11.4':'Answer.11.4',
# 'Answer.ref11.5':'Answer.11.5',
# 'Answer.ref11.6':'Answer.11.6',
# 'Answer.ref11.7':'Answer.11.7',
# 'Answer.ref12.1':'Answer.12.1',
# 'Answer.ref12.2':'Answer.12.2',
# 'Answer.ref12.3':'Answer.12.3',
# 'Answer.ref12.4':'Answer.12.4',
# 'Answer.ref12.5':'Answer.12.5',
# 'Answer.ref12.6':'Answer.12.6',
# 'Answer.ref12.7':'Answer.12.7',
# 'Answer.ref13.1':'Answer.13.1',
# 'Answer.ref13.2':'Answer.13.2',
# 'Answer.ref13.3':'Answer.13.3',
# 'Answer.ref13.4':'Answer.13.4',
# 'Answer.ref13.5':'Answer.13.5',
# 'Answer.ref13.6':'Answer.13.6',
# 'Answer.ref13.7':'Answer.13.7',
# 'Answer.ref14.1':'Answer.14.1',
# 'Answer.ref14.2':'Answer.14.2',
# 'Answer.ref14.3':'Answer.14.3',
# 'Answer.ref14.4':'Answer.14.4',
# 'Answer.ref14.5':'Answer.14.5',
# 'Answer.ref14.6':'Answer.14.6',
# 'Answer.ref14.7':'Answer.14.7',
# 'Answer.ref15.1':'Answer.15.1',
# 'Answer.ref15.2':'Answer.15.2',
# 'Answer.ref15.3':'Answer.15.3',
# 'Answer.ref15.4':'Answer.15.4',
# 'Answer.ref15.5':'Answer.15.5',
# 'Answer.ref15.6':'Answer.15.6',
# 'Answer.ref15.7':'Answer.15.7',
# 'Answer.ref16.1':'Answer.16.1',
# 'Answer.ref16.2':'Answer.16.2',
# 'Answer.ref16.3':'Answer.16.3',
# 'Answer.ref16.4':'Answer.16.4',
# 'Answer.ref16.5':'Answer.16.5',
# 'Answer.ref16.6':'Answer.16.6',
# 'Answer.ref16.7':'Answer.16.7',
# 'Answer.ref17.1':'Answer.17.1',
# 'Answer.ref17.2':'Answer.17.2',
# 'Answer.ref17.3':'Answer.17.3',
# 'Answer.ref17.4':'Answer.17.4',
# 'Answer.ref17.5':'Answer.17.5',
# 'Answer.ref17.6':'Answer.17.6',
# 'Answer.ref17.7':'Answer.17.7',
# 'Answer.ref18.1':'Answer.18.1',
# 'Answer.ref18.2':'Answer.18.2',
# 'Answer.ref18.3':'Answer.18.3',
# 'Answer.ref18.4':'Answer.18.4',
# 'Answer.ref18.5':'Answer.18.5',
# 'Answer.ref18.6':'Answer.18.6',
# 'Answer.ref18.7':'Answer.18.7',
# 'Answer.ref19.1':'Answer.19.1',
# 'Answer.ref19.2':'Answer.19.2',
# 'Answer.ref19.3':'Answer.19.3',
# 'Answer.ref19.4':'Answer.19.4',
# 'Answer.ref19.5':'Answer.19.5',
# 'Answer.ref19.6':'Answer.19.6',
# 'Answer.ref19.7':'Answer.19.7',
# 'Answer.ref20.1':'Answer.20.1',
# 'Answer.ref20.2':'Answer.20.2',
# 'Answer.ref20.3':'Answer.20.3',
# 'Answer.ref20.4':'Answer.20.4',
# 'Answer.ref20.5':'Answer.20.5',
# 'Answer.ref20.6':'Answer.20.6',
# 'Answer.ref20.7':'Answer.20.7',
# 'Answer.ref21.1':'Answer.21.1',
# 'Answer.ref21.2':'Answer.21.2',
# 'Answer.ref21.3':'Answer.21.3',
# 'Answer.ref21.4':'Answer.21.4',
# 'Answer.ref21.5':'Answer.21.5',
# 'Answer.ref21.6':'Answer.21.6',
# 'Answer.ref21.7':'Answer.21.7',
# 'Answer.ref22.1':'Answer.22.1',
# 'Answer.ref22.2':'Answer.22.2',
# 'Answer.ref22.3':'Answer.22.3',
# 'Answer.ref22.4':'Answer.22.4',
# 'Answer.ref22.5':'Answer.22.5',
# 'Answer.ref22.6':'Answer.22.6',
# 'Answer.ref22.7':'Answer.22.7',
# 'Answer.ref23.1':'Answer.23.1',
# 'Answer.ref23.2':'Answer.23.2',
# 'Answer.ref23.3':'Answer.23.3',
# 'Answer.ref23.4':'Answer.23.4',
# 'Answer.ref23.5':'Answer.23.5',
# 'Answer.ref23.6':'Answer.23.6',
# 'Answer.ref23.7':'Answer.23.7',
# 'Answer.ref24.1':'Answer.24.1',
# 'Answer.ref24.2':'Answer.24.2',
# 'Answer.ref24.3':'Answer.24.3',
# 'Answer.ref24.4':'Answer.24.4',
# 'Answer.ref24.5':'Answer.24.5',
# 'Answer.ref24.6':'Answer.24.6',
# 'Answer.ref24.7':'Answer.24.7',
# 'Answer.ref25.1':'Answer.25.1',
# 'Answer.ref25.2':'Answer.25.2',
# 'Answer.ref25.3':'Answer.25.3',
# 'Answer.ref25.4':'Answer.25.4',
# 'Answer.ref25.5':'Answer.25.5',
# 'Answer.ref25.6':'Answer.25.6',
# 'Answer.ref25.7':'Answer.25.7',
# 'Answer.ref26.1':'Answer.26.1',
# 'Answer.ref26.2':'Answer.26.2',
# 'Answer.ref26.3':'Answer.26.3',
# 'Answer.ref26.4':'Answer.26.4',
# 'Answer.ref26.5':'Answer.26.5',
# 'Answer.ref26.6':'Answer.26.6',
# 'Answer.ref26.7':'Answer.26.7',
# 'Answer.ref27.1':'Answer.27.1',
# 'Answer.ref27.2':'Answer.27.2',
# 'Answer.ref27.3':'Answer.27.3',
# 'Answer.ref27.4':'Answer.27.4',
# 'Answer.ref27.5':'Answer.27.5',
# 'Answer.ref27.6':'Answer.27.6',
# 'Answer.ref27.7':'Answer.27.7',
# 'Answer.ref28.1':'Answer.28.1',
# 'Answer.ref28.2':'Answer.28.2',
# 'Answer.ref28.3':'Answer.28.3',
# 'Answer.ref28.4':'Answer.28.4',
# 'Answer.ref28.5':'Answer.28.5',
# 'Answer.ref28.6':'Answer.28.6',
# 'Answer.ref28.7':'Answer.28.7',
# 'Answer.ref29.1':'Answer.29.1',
# 'Answer.ref29.2':'Answer.29.2',
# 'Answer.ref29.3':'Answer.29.3',
# 'Answer.ref29.4':'Answer.29.4',
# 'Answer.ref29.5':'Answer.29.5',
# 'Answer.ref29.6':'Answer.29.6',
# 'Answer.ref29.7':'Answer.29.7',

# %%
# this function:
# - removes all leading and trailing non-alphabet characters, in case there is some sort of punctuation copied
# - remove + signs
# - strips leading "the" if the second field is set to True
def strip_and_convert(str_, strip_the):
    #print(str_)
    if pd.isna(str_)==True:
        return "None"
    temp=unidecode(str_)
    try:
        l = [x.isalpha() for x in temp].index(True)
        m = [x.isalpha() for x in temp[::-1]].index(True)
        temp=temp[l:len(str_)-m]
    except:
        print(temp)
        temp="none"
    #temp=re.sub('^"(.*)"$','(.*)', temp)
    if (temp[0:4].lower()=="the ")&(strip_the==True):
        temp=temp[4:]
    temp=re.sub(' +', ' ', temp)
    temp=re.sub(' ,', ', ', temp)
    temp=temp.strip()
    return temp

# the following three functions expect to recieve a row of the data from mturk and the number of the reference on the page.
# after which it will return that reference as a json dictionary.
# Please see sample entry from from Mturk to see the fields expected for each type of data entry.
def process_article(x, num):
    article_dict={
        "type": "article",
        "author": x["Answer.ref."+str(num)+"_author"],
        "title": x["Answer.ref."+str(num)+"_title"],
        "journal": strip_and_convert(x["Answer.ref."+str(num)+"_journal"], True),
        "year": x["Answer.ref."+str(num)+"_year"],
        "volume": x["Answer.ref."+str(num)+"_vol"],
        "issue": x["Answer.ref."+str(num)+"_issue"],
        "pages": x["Answer.ref."+str(num)+"_pages"],  
    }
    '''
    Journals.append({"journal":strip_and_convert(x["Answer.ref."+str(num)+"_journal"]),
                     "author": x["Answer.ref."+str(num)+"_author"],
                     "title": x["Answer.ref."+str(num)+"_title"],
                     "m":len(Journals)})
    '''
    
    Journals.append(strip_and_convert(x["Answer.ref."+str(num)+"_journal"], True))
    return article_dict

def process_book(x, num):
    book_dict={
        "type": "book",
        "author": x["Answer.ref."+str(num)+"_author"],
        "title": x["Answer.ref."+str(num)+"_title"],
        "chapter_title": x["Answer.ref."+str(num)+"_chapter_title"],
        "year": x["Answer.ref."+str(num)+"_year"],
        "volume": x["Answer.ref."+str(num)+"_vol"],
        "location": x["Answer.ref."+str(num)+"_location"],
        "publisher": x["Answer.ref."+str(num)+"_publisher"],
        "pages": x["Answer.ref."+str(num)+"_pages"],  
    }
    Book.append(strip_and_convert(x["Answer.ref."+str(num)+"_title"], False))
    return book_dict

def process_other(x, num):
    other_dict={
        "type": "other",
        "author": x["Answer.ref."+str(num)+"_author"],
        "title": x["Answer.ref."+str(num)+"_title"],
        "year": x["Answer.ref."+str(num)+"_year"],
        "publisher": x["Answer.ref."+str(num)+"_publisher"],
        "textfull": x["Answer.ref."+str(num)+"_textfull"],  
    }
    return other_dict

# function to merge dictionaries
def Merge(dict1, dict2):
    return(dict2|dict1)

# %%
nA=0
ref=0
article=0
book=0
other=0
a=0
all_ref={}

# these fields are used by the previous block of functions
Journals=[]
Book=[]

# Clean out each reference
for j in All.index:
    count=0
    
    if(pd.isna(All.iloc[j]["RequesterFeedback"])==False):
        All.at[j, "rej_flag"]=True
    else:
        All.at[j, "rej_flag"]=False
        
    for i in range(0,5,1):
        item=None
        temp={
            "HITId": All.iloc[j]["HITId"],
            "ID": All.iloc[j]["Input.ID"],
            "page_o": All.iloc[j]["Input.page"],
            "year_o": All.iloc[j]["Input.year"],
            "journal_o": All.iloc[j]["Input.journal"],
            "authors_o": All.iloc[j]["Input.authors"],
            "title_o": All.iloc[j]["Input.title"],
            "volume_o": All.iloc[j]["Input.vol"],
            "issue_o": All.iloc[j]["Input.issue"],
        }

        
        if pd.isna(All.iloc[j]["Answer."+str(i)+".1"]):
            continue
        elif All.iloc[j]["Answer."+str(i)+".1"]==True:
            nA=nA+1
        elif All.iloc[j]["Answer."+str(i)+".2"]==True:
            article=article+1
            count=count+1
            item=process_article(All.iloc[j],i)
        elif All.iloc[j]["Answer."+str(i)+".3"]==True:
            book=book+1
            count=count+1
            item=process_book(All.iloc[j],i)
        elif All.iloc[j]["Answer."+str(i)+".4"]==True:
            other=other+1
            count=count+1
            item=process_other(All.iloc[j],i)
        elif All.iloc[j]["Answer."+str(i)+".5"]==True:
            ref=ref+1
            
        if(pd.isna(All.iloc[j]["RequesterFeedback"])==False)&(item != None):
            temp["rejected"]=True
            print(j)
            print(temp|item)
        if item != None:
            a=a+1
            all_ref[a]=temp|item
    
        #print(i)
        #if item!=None:
            #print(Merge(item, temp))
            #print(temp|item)
    All.at[j,"num_refs"]=count

#NB change this into switch statement, horrible if ladder is good enough for now
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Work/Refs Danae/lib/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/Work/Refs Danae/lib/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Work/Refs Danae/lib/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Answer.0.1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[533], line 37
#      23 item=None
#      24 temp={
#      25     "HITId": All.iloc[j]["HITId"],
#      26     "ID": All.iloc[j]["Input.ID"],
#    (...)
#      33     "issue_o": All.iloc[j]["Input.issue"],
#      34 }
# ---> 37 if pd.isna(All.iloc[j]["Answer."+str(i)+".1"]):
#      38     continue
#      39 elif All.iloc[j]["Answer."+str(i)+".1"]==True:
#
# File ~/Work/Refs Danae/lib/lib/python3.11/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/Work/Refs Danae/lib/lib/python3.11/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~/Work/Refs Danae/lib/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Answer.0.1'

# %%
temp=pd.DataFrame(all_ref).transpose()

# %%
temp[['type', 'author', 'title', 'year', 'publisher',
       'textfull', 'chapter_title', 'volume', 'location', 'pages', 'journal',
       'issue', #'rejected'
     ]].head(50)
# Out:
#        type  \
# 1     other
# 2      book
# 3      book
# 4      book
# 5   article
# 6   article
# 7     other
# 8   article
# 9   article
# 10  article
# 11     book
# 12  article
# 13     book
# 14     book
# 15     book
# 16  article
# 17     book
# 18     book
# 19  article
# 20  article
# 21  article
# 22  article
# 23    other
# 24     book
# 25     book
# 26     book
# 27     book
# 28     book
# 29    other
# 30     book
# 31    other
# 32    other
# 33    other
# 34    other
# 35    other
# 36    other
# 37  article
# 38    other
# 39    other
# 40    other
# 41    other
# 42    other
# 43  article
# 44    other
# 45    other
# 46    other
# 47    other
# 48    other
# 49    other
# 50    other
#
#                                                                          author  \
# 1                                                                  P. M. Sweezy
# 2                                                                 joan robinson
# 3                                                                Seymour Harris
# 4                                                       Charles P. Kindleberger
# 5                                                                  J. M. Keynes
# 6                                                                   stuart wood
# 7                                                                   stuart wood
# 8                                                                   Stuart wood
# 9                                                              Augusto Graziani
# 10                                                                    anonymous
# 11                                                               james maitland
# 12                                                                    E. Gilboy
# 13                                                                  Colin clark
# 14                                                                 j. tinbergen
# 15                                                                 J. Tinbergen
# 16                                                                  J. Meuldijk
# 17                                                                  J. Einarsen
# 18                                                                         none
# 19                                                                  P. de wolff
# 20                                                                  J. R. hicks
# 21                                                                 T. Pallander
# 22                                                                  J. R. Hicks
# 23                                                                    P. Lorenz
# 24                                             Centraal Bureau v. d. Statistiek
# 25                                                                    e. welter
# 26                                                           frederick macaulay
# 27                                                                irving fisher
# 28                                                                   P. Douglas
# 29                                                                         none
# 30                                                             Ralph G. Hawtrey
# 31                                        Federal Coordinator of Transportation
# 32                                                                Oscar Leiding
# 33                                                                Oscar Leiding
# 34                                                                         none
# 35                                                                         none
# 36                                                                         none
# 37                                                               H. R. Northrup
# 38                                                                         none
# 39                                                                         none
# 40                                                                         none
# 41                                                                         none
# 42                                                                      Behncke
# 43                                                              J. L. nicholson
# 44                                                                       Puffer
# 45                                                                         none
# 46                                                                         none
# 47                                                                J. B. Eastman
# 48                                                                         none
# 49  Chairman of the Legislative Committee of the Interstate Commerce Commission
# 50                                                                         none
#
#                                                                                                                                                           title  \
# 1                                                                                                                              Theory of Capitalist Development
# 2                                                                                                                            essays in the theory of employment
# 3                                              Exchange Depreciation; its Theory and its History, 1931-35, with Some Consideration of Related Domestic Policies
# 4                                                                                                                    postwar economic problems ed. S. E. Harris
# 5                                                                                                                  the balance of payments of the united states
# 6                                                                                                                                  a critique of wages theories
# 7                                                                                                                 studii sulla teorica economica delle macchine
# 8                                                                                                    note on professor graziani's economic  theory of machinery
# 9                                                                                                                               the economic theory of machines
# 10                                                                                                                                                         note
# 11                                                                                                       an enquiry into the nature and origin of public wealth
# 12                                                                                                                                                         none
# 13                                                                                                                                   national income and outlay
# 14                                                                                                               statistical testing of business CYCLE THEORIES
# 15                                                                                                               Statistical testing of business cycle theories
# 16                                                                        Der englische Schiffbau wahrend der Periode 1870-1912 und das Problem des Ersatzbaues
# 17                                                                                                                                          reinvestment cycles
# 18                                                                                      The dynamics of automobile demand, edited by General Motors Corporation
# 19                                                                                                        De vraag naar personenauto's  in de Vereenigde Staten
# 20                                                                                                                                  mr. keynes and the classics
# 21                                                                      Keynes' allmanna teori och dess tillampning inom  rante-, multiplikator- och pristerien
# 22                                                                                                 Mr. Hawtrey on bank rates and the long-term rate of interest
# 23                                                                                                                                                         none
# 24                                                                       Statistische en Econometrische Onderzoekingen, ed. by Centraal Bureau v. d. Statistiek
# 25                                                                                                               die ursachen des kapitalmangels in deutschland
# 26                                                                                       some theoretical problems suggested by the movements of interest rates
# 27                                                                                                                                       the theory of interest
# 28                                                                                                                                          the theory of wages
# 29                                                                                                                     Anuario de la Industria Textil espaniola
# 30                                                                                                                                          currency and credit
# 31                                                                                          Hours, Wages and Working Conditions in Scheduled Air Transportation
# 32                                                                                                                                        pilot union president
# 33                                                                                                                                        pilot union president
# 34                                                                                              Agreement between American Export Airlines, Inc. and . . . ALPA
# 35                                                                                     Supplemental Agreement between American Overseas Airlines, Inc. and ALPA
# 36                                                                                                                             ALPA-Pan American-Grace contract
# 37                                                                                                  the railway labor act and railway labor disputes in wartime
# 38                                                                                                             Employment Opportunities in Aviation Occupations
# 39                                                                                                                                                       Report
# 40                                                                                                                                               CAB Statistics
# 41                                                                                                                    Reports to Airline Negotiating Conference
# 42                                                                                                                                                         none
# 43                                                                                                                        possibilities for lower airline costs
# 44                                                                                                                                           Air Transportation
# 45                                                                                                                                                         none
# 46                                                                                                                  TWA Emergency Board, Carrier Exhibit No. 42
# 47                                                                                                                                                         none
# 48                                                                                                          Annual Report of the Interstate Commerce Commission
# 49                                                                  letter from the Chairman of the Legislative Committee of the Interstate Commerce Commission
# 50  testimony of Commissioner J. B. Eastman in Committee on Interstate Commerce, Long and Short Haul, Senate Report No. 1768, 75th Congress, 3d Session, part 2
#
#     year                              publisher  \
# 1   none                                   none
# 2   1937                                   none
# 3   1936               Harvard University Press
# 4   none                                   none
# 5   1946                                    NaN
# 6   1890                                    NaN
# 7   1891                         fratelli bocca
# 8   1891                                    NaN
# 9   1891                                    NaN
# 10  1894                                    NaN
# 11  1804                                   none
# 12  1939                                    NaN
# 13  1937                                   none
# 14  1939                      league of nations
# 15  1939                      league of nations
# 16  1940                                    NaN
# 17  1938                                   none
# 18  1939             General Motors Corporation
# 19  1936                                    NaN
# 20  1937                                    NaN
# 21  1942                                    NaN
# 22  1939                                    NaN
# 23  none                                   none
# 24  1943                                   none
# 25  1931                                   none
# 26  1938                                   none
# 27  1930                                   none
# 28  1934                                   none
# 29  1945                                   none
# 30  1919                                   none
# 31  1936  Federal Coordinator of Transportation
# 32  1943                          air transport
# 33  1944                          air transport
# 34  1944                                   none
# 35  1946                                   none
# 36  1943                                   none
# 37  1946                                    NaN
# 38  1946             Bureau of Labor Statistics
# 39  none                    TWA Emergency Board
# 40  none                        Emergency Board
# 41  1946                                   none
# 42  none                    TWA Emergency Board
# 43  1946                                    NaN
# 44  none                                   none
# 45  none                                   none
# 46  none                Civil Aeronautics Board
# 47  1940                        the Railway Age
# 48  1940         Interstate Commerce Commission
# 49  1939                  House Committee Print
# 50  1938                                   none
#
#                                                                                                                                                                                                                              textfull  \
# 1                                                                                                                                                                             P. M. Sweezy (Theory of Capitalist Development, p. 183)
# 2                                                                                                                                                                                                                                 NaN
# 3                                                                                                                                                                                                                                 NaN
# 4                                                                                                                                                                                                                                 NaN
# 5                                                                                                                                                                                                                                 NaN
# 6                                                                                                                                                                                                                                 NaN
# 7                                                                                                                                                                                            stuart wood, Turin: Fratelli Bocca, 1891
# 8                                                                                                                                                                                                                                 NaN
# 9                                                                                                                                                                                                                                 NaN
# 10                                                                                                                                                                                                                                NaN
# 11                                                                                                                                                                                                                                NaN
# 12                                                                                                                                                                                                                                NaN
# 13                                                                                                                                                                                                                                NaN
# 14                                                                                                                                                                                                                                NaN
# 15                                                                                                                                                                                                                                NaN
# 16                                                                                                                                                                                                                                NaN
# 17                                                                                                                                                                                                                                NaN
# 18                                                                                                                                                                                                                                NaN
# 19                                                                                                                                                                                                                                NaN
# 20                                                                                                                                                                                                                                NaN
# 21                                                                                                                                                                                                                                NaN
# 22                                                                                                                                                                                                                                NaN
# 23  P. Lorenz (Eine Differ-entialgleichung der Wirtschaftsforschung und ihr Integral, Blatter far Ver-sicherungsmathematik und verwandte Gebiete, Beilage zur Zeitschrift fur die gesammte Vers.-Wissenschaft, Bd. zg. Heft 3, p. 212
# 24                                                                                                                                                                                                                                NaN
# 25                                                                                                                                                                                                                                NaN
# 26                                                                                                                                                                                                                                NaN
# 27                                                                                                                                                                                                                                NaN
# 28                                                                                                                                                                                                                                NaN
# 29                                                                                                                                                                         Anuario de la Industria Textil espaniola, Barcelona, 1945.
# 30                                                                                                                                                                                                                                NaN
# 31                                                                                                        Federal Coordinator of Transportation, Hours, Wages and Working Conditions in Scheduled Air Transportation, 1936, pp. 98-11
# 32                                                                                                                                                    Oscar Leiding, "Pilot Union President," Air Transport, November, December, 1943
# 33                                                                                                                                                              Oscar Leiding, "Pilot Union President," Air Transport, January, 1944.
# 34                                                                                                                                        Agreement between American Export Airlines, Inc. and . . . ALPA, December 1, 1944, pp. 3-4;
# 35                                                                                                                                 Supplemental Agreement between American Overseas Airlines, Inc. and ALPA, March 21, 1946, pp. 2-3.
# 36                                                                                                                                                                       ALPA-Pan American-Grace contract, November 15, 1943; pp. 8-9
# 37                                                                                                                                                                                                                                NaN
# 38                                                                                                          "Employment Opportunities in Aviation Occupations," Bulletin No. 837-2, U. S. Bureau of Labor Statistics, 1946, pp. 31-32
# 39                                                                                                                                                                                            TWA Emergency Board, Report, pp. 32-33;
# 40                                                                                                                                                         CAB Statistics, diagramed in TWA Emergency Board, Carriers Exhibit No. 63.
# 41                                                                                                                                                                                    Reports to Airline Negotiating Conference. 1946
# 42                                                                                                                                                                      President Behncke, TWA Emergency Board,\r Vol. I, pp. 306 ff.
# 43                                                                                                                                                                                                                                NaN
# 44                                                                                                                                                                                             Puffer, Air Transportation, pp. 567-58
# 45                                                                                                                                                                                                        Pilot Exhibits Nos. 10-1 4.
# 46                                                                                                                                    TWA Emergency Board, Carrier Exhibit No. 42, based on data compiled by Civil Aeronautics Board.
# 47                                                                                                                                                           J. B. Eastman in the Railway Age, vol. 108, pp. 717-718 (April 20, 1940)
# 48                                                                                                                                                                 Annual Report of the Interstate Commerce Commission, 1940, p. 131.
# 49                                                                                         letter from the Chairman of the Legislative Committee of the Interstate Commerce Commission, House Committee Print, p. 5 (March 20, 1939).
# 50                                                      testimony of Commissioner J. B. Eastman in Committee on Interstate Commerce, Long and Short Haul, Senate Report No. 1768, 75th Congress, 3d Session, part 2, pp. 30-60 (1938)
#
#                                                  chapter_title volume  \
# 1                                                          NaN    NaN
# 2                                       disguised unemployment   none
# 3                                                         none   none
# 4                                       Monetary stabilization   none
# 5                                                          NaN   none
# 6                                                          NaN      I
# 7                                                          NaN    NaN
# 8                                                          NaN     II
# 9                                                          NaN     II
# 10                                                         NaN     II
# 11                                                        none   none
# 12                                                         NaN   none
# 13                                                        none   none
# 14  business cycles in the united states of america, 1919-1932     II
# 15         a method and its application to investment activity      I
# 16                                                         NaN     52
# 17                                                        none   none
# 18                                                        none   none
# 19                                                         NaN   none
# 20                                                         NaN      V
# 21                                                         NaN   XLIV
# 22                                                         NaN      X
# 23                                                         NaN    NaN
# 24                                                        none   none
# 25                                                        none   none
# 26                                                        none   none
# 27                                                        none   none
# 28                                                        none   none
# 29                                                         NaN    NaN
# 30                                               chapter X, XI   none
# 31                                                         NaN    NaN
# 32                                                         NaN    NaN
# 33                                                         NaN    NaN
# 34                                                         NaN    NaN
# 35                                                         NaN    NaN
# 36                                                         NaN    NaN
# 37                                                         NaN  XXXVI
# 38                                                         NaN    NaN
# 39                                                         NaN    NaN
# 40                                                         NaN    NaN
# 41                                                         NaN    NaN
# 42                                                         NaN    NaN
# 43                                                         NaN   none
# 44                                                         NaN    NaN
# 45                                                         NaN    NaN
# 46                                                         NaN    NaN
# 47                                                         NaN    NaN
# 48                                                         NaN    NaN
# 49                                                         NaN    NaN
# 50                                                         NaN    NaN
#
#      location    pages  \
# 1         NaN      NaN
# 2        none       99
# 3        none     none
# 4        none     none
# 5         NaN    172ff
# 6         NaN  426-461
# 7         NaN      NaN
# 8         NaN  522-530
# 9         NaN  838-841
# 10        NaN      574
# 11  edinburgh     none
# 12        NaN     none
# 13     london      212
# 14     geneva     none
# 15     geneva     none
# 16        NaN      524
# 17       oslo     none
# 18   new york     none
# 19        NaN       18
# 20        NaN      147
# 21        NaN      233
# 22        NaN       27
# 23        NaN      NaN
# 24  the hague        6
# 25   tubingen     none
# 26   new york      206
# 27   new york     none
# 28   new york     none
# 29        NaN      NaN
# 30       none     none
# 31        NaN      NaN
# 32        NaN      NaN
# 33        NaN      NaN
# 34        NaN      NaN
# 35        NaN      NaN
# 36        NaN      NaN
# 37        NaN  324-343
# 38        NaN      NaN
# 39        NaN      NaN
# 40        NaN      NaN
# 41        NaN      NaN
# 42        NaN      NaN
# 43        NaN   452-58
# 44        NaN      NaN
# 45        NaN      NaN
# 46        NaN      NaN
# 47        NaN      NaN
# 48        NaN      NaN
# 49        NaN      NaN
# 50        NaN      NaN
#
#                                                            journal  \
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                 economic journal
# 6   annals of the american academy of political and social science
# 7                                                              NaN
# 8   annals of the american academy of political and social science
# 9   annals of the american academy of political and social science
# 10                                    journal of political economy
# 11                                                             NaN
# 12                                   review of economic statistics
# 13                                                             NaN
# 14                                                             NaN
# 15                                                             NaN
# 16                                     Weltwirtschaftliches Archiv
# 17                                                             NaN
# 18                                                             NaN
# 19                                    De Nederlandsche Conjunctuur
# 20                                                    econometrica
# 21                                                 Ekon. tidskrift
# 22                manchester school of economic and social studies
# 23                                                             NaN
# 24                                                             NaN
# 25                                                             NaN
# 26                                                             NaN
# 27                                                             NaN
# 28                                                             NaN
# 29                                                             NaN
# 30                                                             NaN
# 31                                                             NaN
# 32                                                             NaN
# 33                                                             NaN
# 34                                                             NaN
# 35                                                             NaN
# 36                                                             NaN
# 37                                        american economic review
# 38                                                             NaN
# 39                                                             NaN
# 40                                                             NaN
# 41                                                             NaN
# 42                                                             NaN
# 43                                   law and contemporary problems
# 44                                                             NaN
# 45                                                             NaN
# 46                                                             NaN
# 47                                                             NaN
# 48                                                             NaN
# 49                                                             NaN
# 50                                                             NaN
#
#             issue
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5            june
# 6            none
# 7             NaN
# 8            none
# 9            none
# 10      september
# 11            NaN
# 12           none
# 13            NaN
# 14            NaN
# 15            NaN
# 16           none
# 17            NaN
# 18            NaN
# 19       november
# 20           none
# 21           none
# 22           none
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37           june
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42            NaN
# 43  winter-spring
# 44            NaN
# 45            NaN
# 46            NaN
# 47            NaN
# 48            NaN
# 49            NaN
# 50            NaN

# %%
        ref_type={"none":[1, "None"], 
          "reference":[5,"Reference list found"], 
          "article":[2, "Article"], 
          "book":[3, "Book"], 
          "other": [4, "Other"], 
         }

# %%
ref_type={"none":[1, "None"], 
          "reference":[5,"Reference list found"], 
          "article":[2, "Article"], 
          "book":[3, "Book"], 
          "other": [4, "Other"], 
         }

def TurkYourLifeAway():
    for i in pages:
        page
        path=get_path(i)
