# %% [markdown]
# # Merged dataset field description
#
# This is a description of fields in the Merged dataset that combines JPE masterlist, pivot list, Scopus data pre-2016. The Merged dataset is stored in JPE_M_sco_du.xlsx.
#
#     'stable_url' : JSTOR url for article
#     'Jstor_authors' : Author names recorded by JSTOR
#     'Jstor_title' : Title of article recorded by JSTOR
#     'Jstor_abstract' : abstract recorded by JSTOR nb: this is blank at the moment
#     'content_type' : Article type determined during cleaning. Includes MISC for miscellaneous, Reviews, Note, Comment, Rejoinder and Article categorizations
#     'issue_url' : url of issue article belongs to on JSTOR
#     'pages' : pages as recorded by JSTOR
#     'year' : Year of publication recorded by JSTOR
#     'volume' : Volume of article recorded by JSTOR
#     'issue' : issue of article recorded by JSTOR
#     'Jstor_journal' : journal name JSTOR
#     'type' : Type of issue determined during cleaning. S for special issue. N for normal issue
#     'scopus_authors' : Author names recorded by Scopus
#     'scopus_title' : Title recorded by Scopus
#     'scopus_journal' : Journal name recorded by Scopus
#     'DOI' : DOI recorded by scopus
#     'affiliations' : affiliations of authors as recorded by scopus
#     'scopus_abstract' : abstract of article recorded by scopus
#     'citations' : citations of article recorded by scopus
#     'document type' : Article type recorded by scopus, may differ from that in cleaning
#     'index keywords' : from scopus
#     'author keywords' : from scopus
#     'footnotes' : footnotes scraped from metadata panel.
#     'raw' : raw text data scraped from JSTOR metadata panel.
#     'references' : citations scraped from JSTOR metadata panel during data collection.

# %%
Merged=pd.read_excel('C:\\Users\\sjwu1\\Journal_Data\\datadumps\\JPE_M_sco_du.xlsx')

# %% [markdown]
# ## The Tesseract library
#
# I use Tesseract, a popular parsing library and the python binding of it pyTesseract to parse JPE documents in this section. I am  following the code and technique from this article on how to read a multi-column pdf. The fitz python module is a lightweight pdf reader, it will require the installation of pyMupdf. OpenCV python module and the module/class cv2 from it is used to apply otsu's thresholding technique to lift/determine paragraph edges.
#
# https://towardsdatascience.com/read-a-multi-column-pdf-with-pytesseract-in-python-1d99015f887a

# %%
import fitz

# for OCR using PyTesseract
import cv2                              # pre-processing images
import pytesseract                      # extracting text from images
import numpy as np
import matplotlib.pyplot as plt         # displaying output images
from PIL import Image

# %% [markdown]
# Set path to where pdfs of articles are.

# %%
path='C:\\Users\\sjwu1\\Journal_Data\\JPE_data'
temp=path+'\\dummy.pdf'

# %% [markdown]
# Read in the merged pdf containing jstor, scopus and datadump metadata.

# %%
Merged=pd.read_excel('C:\\Users\\sjwu1\\Journal_Data\\datadumps\\JPE_M_sco_du.xlsx')

# %% [markdown]
# Set the zoom factor to zoom into the pdf. This is to get a higher resolution image. I have chosen 2x zoom for both vertically and horizontally.

# %%
zoom_x = 2.0 # horizontal zoom
zoom_y = 2.0 # vertical zoom
mat = fitz.Matrix(zoom_x, zoom_y)

# %% [markdown]
# ### The getNumberofPages() function
# Given a text string from jstor of the page numbers of an article, this gives the number of pages expected in the article. Because some articles' pdfs are downloaded from scopus sometimes they are missing a front page. On the otherhand sometimes jstor has a coverpage that is not accounted for. This function returns the number of pages so that the first page of an article can be correctly identified.

# %%
def getNumberofPages(text):
    if pd.isna(text)==False:
        if re.search('\d',text):
            temp=text.split(',')
            pages=0
            print(temp)
            for m in temp:
                if '-' in m:
                    t=str(m).split('-')
                    pages=pages+int(re.sub('\D','',t[1]))-int(re.sub('\D','',t[0]))+1
                else:
                    pages+=1
            return pages
    return 1


print(getNumberofPages('2014-2016, 30'))
print(getNumberofPages('20-40'))
# Out:
# ['2014-2016', ' 30']
# 4
# ['20-40']
# 21

# %% [markdown]
# ### The converter() function
# This function takes a string and replaces all non-ascii characters with a placeholder. In regex, a placeholder is represented by a '.'. Specific to JPE, a lower case 'L' and a upper case 'I' look the same to tesseract because of the font. Hence, upper case 'I's are replaced with a placeholder. I found that for middle name initials, tesseract may mistake the letter for something else  hence again, we replace it with a placeholder.
#
# An alternative solution is to use fuzzy matching.

# %%
import string
def converter(teststring):
    for i in range(len(teststring)):
        if teststring[i] == '.':
            teststring=teststring[0:i-1]+'.'+teststring[i:]
    
    teststring=teststring.replace('I','.')
            
    for i in teststring:
        if (i not in string.ascii_lowercase) & (i not in string.ascii_uppercase) & (i !=' '):
            teststring=teststring.replace(i,'.')
    return teststring

# %% [markdown]
# ### The generate_pngs() function
# This function looks for the block of text that contains author names, assuming that the block also contains affiliations. If affiliations are not found, then the parsed text is returned. Only the first page of the article and sometimes the JSTOR cover page is parsed.
#
# Given a pdf file path (SCANNED_FILE), the number of pages (pages), zoom matrix (mat), path to pdf file folder (path), a value for how tightly to draw mask (k_val). A higher k_val results in a mask that covers more of the page ie: segments the page less. You can uncomment the lines of code for plots inside the function observe the mask. Lastly, a string or regex pattern that would match the lead author's name.

# %%
def generate_pngs(SCANNED_FILE, pages, mat, path, k_val, author):
    doc = fitz.open(SCANNED_FILE)
    parsed={}
    count=doc.page_count-pages
    if count<0:
        count=1
    for page in doc:
        if (page.number == count):
            png = path+"\\pages_png\\" + SCANNED_FILE.split('\\')[-1].split('.')[0] + '_page-%i.png' % page.number
            if os.path.exists(png)==False:
                pix = page.get_pixmap(matrix=mat)
                print(png)
                pix.save(png)

            parsed[page.number]=[]

            original_image = cv2.imread(png)
            # convert the image to grayscale
            gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

            #plt.figure(figsize=(25, 15))
            #plt.imshow(gray_image, cmap='gray')
            #plt.show()

            # Performing OTSU threshold
            ret, threshold_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)

            #plt.figure(figsize=(25, 15))
            #plt.imshow(threshold_image, cmap='gray')
            #plt.show()

            rectangular_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (k_val, k_val))

            # Applying dilation on the threshold image
            dilated_image = cv2.dilate(threshold_image, rectangular_kernel, iterations = 1)

            #plt.figure(figsize=(25, 15))
            #plt.imshow(dilated_image)
            #plt.show()

            # Finding contours
            contours, hierarchy = cv2.findContours(dilated_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

            # Creating a copy of the image
            copied_image = original_image.copy()

            mask = np.zeros(original_image.shape, np.uint8)
            i=1
            # Looping through the identified contours
            # Then rectangular part is cropped and passed on to pytesseract
            # pytesseract extracts the text inside each contours
            # Extracted text is then written into a text file
            for cnt in reversed(contours):
                x, y, w, h = cv2.boundingRect(cnt)
                print(i)
                # Cropping the text block for giving input to OCR
                cropped = copied_image[y:y + h, x:x + w]
                # Apply OCR on the cropped image
                text = pytesseract.image_to_string(cropped, lang='lat', config='--oem 3 --psm 1')
                print(text)
                parsed[page.number].append(text)
                print(re.search(author.upper(),text.upper()))
                if re.search('AUTHOR\(S\)', text.upper()) is not None:
                    count+=1
                    break
                if re.search(author.upper(),text.upper()) is not None:
                    return {'found': text}
                #masked = cv2.drawContours(mask, [cnt], 0, (255, 255, 255), -1)
                print()
                i=i+1
            #plt.figure(figsize=(25, 15))
            #plt.imshow(masked, cmap='gray')
            #plt.show()
    return {'raw': parsed}

# %% [markdown]
# ### Testing the generate_pngs() function
# I use the getNumberofPages() and converter() functions as inputs.

# %%
# replace with you own file
SCANNED_FILE = path+'\\1830926.pdf'

t0=time.time()        
affiliations=generate_pngs(SCANNED_FILE, getNumberofPages('339-354'), mat, path, 50, converter('Michael D. Intriligator'))
t1=time.time()
total=t1-t0
print(total)
affiliations

# %% [markdown]
# ### Extracting affiliations from JPE
# First create an empty dictionary

# %%
dict={}

#lower case all letters in both upper and lower
counts=Merged[(Merged['year']>1940) & (Merged['content_type']!='MISC') & (Merged['content_type']!='Review')]
counts.shape
# Out:
# (4430, 25)

# %% [markdown]
# This for loop, provided the content_type is not miscellaneous or a review, stores metadata of a paper via the JSTOR ID in the dictionary dict.
#
# JSTOR_id: {
#
#     'affiliations': {'found': affiliations_text_if_found},
#     'content_type': content_type,
#     'authors': [author1, author2, author3 ...],
#     'stable_url': stable_url]
#    }
#
# Note: if affiliations are not found then the 'affiliations' field will contain a dictionary of form.
#
# 'raw': {
#
#     '0': [parsed_text_on_page_0 separated by commas],
#     '1': [parsed_text_on_page_1 separated by commas] ...
#    }

# %%
t0=time.time()

for i in Merged[(Merged['year']>=1940) & (Merged['content_type']!='MISC') & (Merged['content_type']!='Review')].index:
    if Merged.iloc[i]['Jstor_authors'] is not NaN: 
        if "Suggested by" not in Merged.iloc[i]['Jstor_authors']:
            authors=str(Merged.iloc[i]['Jstor_authors']).replace(' and ',', ').replace("  ",' ').split(',')
            filepath=path+'\\'+Merged.iloc[i]['stable_url'].split('/')[-1]+'.pdf'
            if os.path.exists(filepath)==True:
                print(Merged.iloc[i]['year'])
                first_author=converter(authors[0])
                print(first_author)
                n_pages=getNumberofPages(Merged.iloc[i]['pages'])
                if pd.isna(n_pages)==False:
                    affiliations=generate_pngs(filepath, n_pages, mat, path, 52, first_author.strip())
                    dict[Merged.iloc[i]['stable_url'].split('/')[-1]]={'affiliations':affiliations, 'content_type':Merged.iloc[i]['content_type'], 'authors':authors, 'stable_url': Merged.iloc[i]['stable_url']}
            else:
                dict[Merged.iloc[i]['stable_url'].split('/')[-1]]='PDF not available, download at '+ Merged.iloc[i]['stable_url']
t1=time.time()
total=t1-t0
print(total)
print(i)

# %% [markdown]
# Save the dictionary containing affiliations inside a json file.

# %%
import json
with open(path+'//JPE_affiliation_output_aff2.json','w') as fp:
    json.dump(dict, fp)

# %%
import json
# print pretty to view dictionary content
print(json.dumps(dict, sort_keys=False, indent=4))
print(len(dict.keys()))

# %% [markdown]
# ### Extracting references
# JPE has references at the end in a dedicated references section from 1966 onwards. Hence the generate_refs function looks for a keyword 'References' using fuzzy matching (less that 3 character difference) and returns everything following it. If it is not found then the function returns the parsed text of the last 5 pages of the document.

# %%
import time
import regex
def generate_refs(SCANNED_FILE, mat, path, k_val, keyword):
    doc = fitz.open(SCANNED_FILE)
    parsed={}
    references={}
    found=0
    for page in reversed(doc):
        if (page.number >= doc.page_count-5):
            png = path+"\\pages_png\\" + SCANNED_FILE.split('\\')[-1].split('.')[0] + '_page-%i.png' % page.number
            if os.path.exists(png)==False:
                pix = page.get_pixmap(matrix=mat)
                print(png)
                pix.save(png)

            parsed[page.number]=[]
            references[page.number]=[]

            original_image = cv2.imread(png)
            # convert the image to grayscale
            gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

            #plt.figure(figsize=(25, 15))
            #plt.imshow(gray_image, cmap='gray')
            #plt.show()

            # Performing OTSU threshold
            ret, threshold_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)

            #plt.figure(figsize=(25, 15))
            #plt.imshow(threshold_image, cmap='gray')
            #plt.show()

            rectangular_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (k_val, k_val))

            # Applying dilation on the threshold image
            dilated_image = cv2.dilate(threshold_image, rectangular_kernel, iterations = 1)

            #plt.figure(figsize=(25, 15))
            #plt.imshow(dilated_image)
            #plt.show()

            # Finding contours
            contours, hierarchy = cv2.findContours(dilated_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

            # Creating a copy of the image
            copied_image = original_image.copy()

            mask = np.zeros(original_image.shape, np.uint8)
            i=1
            # Looping through the identified contours
            # Then rectangular part is cropped and passed on to pytesseract
            # pytesseract extracts the text inside each contours
            # Extracted text is then written into a text file
            for cnt in contours:
                x, y, w, h = cv2.boundingRect(cnt)
                # Cropping the text block for giving input to OCR
                cropped = copied_image[y:y + h, x:x + w]
                # Apply OCR on the cropped image
                text = pytesseract.image_to_string(cropped, lang='lat', config='--oem 3 --psm 1')
                #print(i)
                #print(text)
                parsed[page.number].append(text)
                #print(re.search(keyword.upper(),text.upper()))
                if regex.search(keyword, text.upper()) is not None:
                    print('found')
                    return {'found': parsed}
                #masked = cv2.drawContours(mask, [cnt], 0, (255, 255, 255), -1)
                i=i+1
    return {'raw': parsed}

# %% [markdown]
# ### Testing the generate_pngs() function

# %%
t0=time.time()        
refs=generate_refs(path+'\\26549911.pdf', mat, path, 40, '\n(REFERENCES){e<=3}\n')
t1=time.time()
total=t1-t0
print(total)
refs
# Out:
# found
# 4.572999000549316
# {'found': {48: ['This content downloaded from.\n137.158.158.62 on Wed, 30 Mar 2022 16:36:52 UTC\nAll use subject to https;//about jstor.org/terms\n',
# %% [markdown]
# create the empty dictionary

# %%
dict_ref={}

# %% [markdown]
# This for loop, provided the content_type is not miscellaneous or a review, stores the references extracted via tesseract and metadata of a paper via the JSTOR ID in the dictionary dict.
#
# JSTOR_id: {
#
#     'references': {
#         'found': {
#             'page_no': [Text containing or following references keyword separated by commas],
#             'page_no': [Text containing or following references keyword separated by commas] ...
#             }
#          },
#     'content_type': content_type,
#     'authors': [author1, author2, author3 ...],
#     'stable_url': stable_url]
#     }
#
# Note: if references are not found then the 'references' field will contain a dictionary of form.
#
# 'raw': {
#
#     'page_no': [parsed_text_on_page_no separated by commas],
#     'page_no': [parsed_text_on_page_no separated by commas] ...
#     }

# %%
t0=time.time()

for i in Merged[(Merged['year']>1965) & (Merged['year']<=1970) & (Merged['content_type']!='MISC') & (Merged['content_type']!='Review')].index:
    if Merged.iloc[i]['Jstor_authors'] is not NaN: 
        if "Suggested by" not in Merged.iloc[i]['Jstor_authors']:
            authors=str(Merged.iloc[i]['Jstor_authors']).replace(' and ',', ').replace("  ",' ').split(',')
            filepath=path+'\\'+Merged.iloc[i]['stable_url'].split('/')[-1]+'.pdf'
            if os.path.exists(filepath)==True:
                print(Merged.iloc[i][['year','issue','volume', 'stable_url']])
                if pd.isna(n_pages)==False:
                    references=generate_refs(filepath, mat, path, 52, '(REFERENCES){e<=3}\n')
                    dict_ref[Merged.iloc[i]['stable_url'].split('/')[-1]]={'references':references, 'content_type':Merged.iloc[i]['content_type'], 'authors':authors, 'stable_url': Merged.iloc[i]['stable_url']}
            else:
                dict_ref[Merged.iloc[i]['stable_url'].split('/')[-1]]='PDF not available, download at '+ Merged.iloc[i]['stable_url']
t1=time.time()
total=t1-t0
print(total)
print(i)
# Out:
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830621
# Name: 3824, dtype: object
# ['1213-1227']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830622
# Name: 3825, dtype: object
# ['1228-1263']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830623
# Name: 3826, dtype: object
# ['1264-1291']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830624
# Name: 3827, dtype: object
# ['1292-1309']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830625
# Name: 3828, dtype: object
# ['1310-1324']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830626
# Name: 3829, dtype: object
# ['1325-1339']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830627
# Name: 3830, dtype: object
# ['1340-1354']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830628
# Name: 3831, dtype: object
# ['1355-1361']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830629
# Name: 3832, dtype: object
# ['1362-1366']
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830630
# Name: 3833, dtype: object
# ['1367-1371']
# found
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830631
# Name: 3834, dtype: object
# ['1372-1377']
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830632
# Name: 3835, dtype: object
# ['1378-1379']
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830635
# Name: 3838, dtype: object
# ['1385-1386']
# year                                          1970
# issue                                            6
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830636
# Name: 3839, dtype: object
# ['1386']
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830876
# Name: 3842, dtype: object
# ['1017-1027']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830877
# Name: 3843, dtype: object
# ['1028-1040']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830878
# Name: 3844, dtype: object
# ['1041-1060']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830879
# Name: 3845, dtype: object
# ['1061-1068']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830880
# Name: 3846, dtype: object
# ['1069-1092']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830881
# Name: 3847, dtype: object
# ['1093-1105']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830882
# Name: 3848, dtype: object
# ['1106-1114']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830883
# Name: 3849, dtype: object
# ['1115-1141']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830884
# Name: 3850, dtype: object
# ['1142-1149']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830885
# Name: 3851, dtype: object
# ['1150-1162']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830886
# Name: 3852, dtype: object
# ['1163-1167']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830887
# Name: 3853, dtype: object
# ['1168-1184']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830888
# Name: 3854, dtype: object
# ['1185-1190']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830889
# Name: 3855, dtype: object
# ['1191-1194']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830890
# Name: 3856, dtype: object
# ['1195-1202']
# found
# year                                          1970
# issue                                            5
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830894
# Name: 3860, dtype: object
# ['1212']
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829811
# Name: 3863, dtype: object
# ['805-814']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829812
# Name: 3864, dtype: object
# ['815-825']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829813
# Name: 3865, dtype: object
# ['826-856']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829814
# Name: 3866, dtype: object
# ['857-889']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829815
# Name: 3867, dtype: object
# ['890-905']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829816
# Name: 3868, dtype: object
# ['906-947']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829817
# Name: 3869, dtype: object
# ['948-965']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829818
# Name: 3870, dtype: object
# ['966-1006']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829819
# Name: 3871, dtype: object
# ['1007-1016']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829920
# Name: 3875, dtype: object
# ['616']
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829921
# Name: 3876, dtype: object
# ['617-625']
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829922
# Name: 3877, dtype: object
# ['626-654']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829923
# Name: 3878, dtype: object
# ['655-684']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829924
# Name: 3879, dtype: object
# ['685-701']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829925
# Name: 3880, dtype: object
# ['702-716']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829926
# Name: 3881, dtype: object
# ['717-724']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829927
# Name: 3882, dtype: object
# ['725-728']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829928
# Name: 3883, dtype: object
# ['729-744']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829929
# Name: 3884, dtype: object
# ['745-763']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829930
# Name: 3885, dtype: object
# ['764-767']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829931
# Name: 3886, dtype: object
# ['768-773']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829932
# Name: 3887, dtype: object
# ['774-777']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829933
# Name: 3888, dtype: object
# ['778-782']
# found
# year                                          1970
# issue                                            4
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829934
# Name: 3889, dtype: object
# ['783-792']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829644
# Name: 3897, dtype: object
# ['431-455']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829645
# Name: 3898, dtype: object
# ['456-488']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829646
# Name: 3899, dtype: object
# ['489-525']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829647
# Name: 3900, dtype: object
# ['526-536']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829648
# Name: 3901, dtype: object
# ['537-539']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829649
# Name: 3902, dtype: object
# ['540-545']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829650
# Name: 3903, dtype: object
# ['546-564']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829651
# Name: 3904, dtype: object
# ['565-571']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829652
# Name: 3905, dtype: object
# ['572-585']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829653
# Name: 3906, dtype: object
# ['586-597']
# found
# year                                          1970
# issue                                            3
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829654
# Name: 3907, dtype: object
# ['598-607']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830684
# Name: 3913, dtype: object
# ['193-238']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830685
# Name: 3914, dtype: object
# ['239-267']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830686
# Name: 3915, dtype: object
# ['268-273']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830687
# Name: 3916, dtype: object
# ['274-278']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830688
# Name: 3917, dtype: object
# ['279-290']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830689
# Name: 3918, dtype: object
# ['291-305']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830690
# Name: 3919, dtype: object
# ['306-310']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830691
# Name: 3920, dtype: object
# ['311-329']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830692
# Name: 3921, dtype: object
# ['330-337']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830693
# Name: 3922, dtype: object
# ['338-352']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830694
# Name: 3923, dtype: object
# ['353-355']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830695
# Name: 3924, dtype: object
# ['356-376']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830696
# Name: 3925, dtype: object
# ['377-394']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830697
# Name: 3926, dtype: object
# ['395-403']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830698
# Name: 3927, dtype: object
# ['404-417']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830699
# Name: 3928, dtype: object
# ['418-420']
# found
# year                                          1970
# issue                                            2
# volume                                          78
# stable_url    https://www.jstor.org/stable/1830700
# Name: 3929, dtype: object
# ['421-423']
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829616
# Name: 3936, dtype: object
# ['1-26']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829617
# Name: 3937, dtype: object
# ['27-34']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829618
# Name: 3938, dtype: object
# ['35-59']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829619
# Name: 3939, dtype: object
# ['60-67']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829620
# Name: 3940, dtype: object
# ['68-81']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829621
# Name: 3941, dtype: object
# ['82-83']
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829622
# Name: 3942, dtype: object
# ['84-96']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829623
# Name: 3943, dtype: object
# ['97-105']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829624
# Name: 3944, dtype: object
# ['106-108']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829625
# Name: 3945, dtype: object
# ['109-111']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829626
# Name: 3946, dtype: object
# ['112-132']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829627
# Name: 3947, dtype: object
# ['133-135']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829628
# Name: 3948, dtype: object
# ['135-136']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829629
# Name: 3949, dtype: object
# ['137']
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829630
# Name: 3950, dtype: object
# ['137-138']
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829631
# Name: 3951, dtype: object
# ['138-139']
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829632
# Name: 3952, dtype: object
# ['140-151']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829633
# Name: 3953, dtype: object
# ['152-157']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829634
# Name: 3954, dtype: object
# ['158-164']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829635
# Name: 3955, dtype: object
# ['165-174']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829636
# Name: 3956, dtype: object
# ['175-177']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829637
# Name: 3957, dtype: object
# ['178-180']
# found
# year                                          1970
# issue                                            1
# volume                                          78
# stable_url    https://www.jstor.org/stable/1829638
# Name: 3958, dtype: object
# ['181-184']
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837201
# Name: 3965, dtype: object
# ['873-891']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837202
# Name: 3966, dtype: object
# ['892-896']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837203
# Name: 3967, dtype: object
# ['897-915']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837204
# Name: 3968, dtype: object
# ['916-920']
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837205
# Name: 3969, dtype: object
# ['921-931']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837206
# Name: 3970, dtype: object
# ['932-936']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837207
# Name: 3971, dtype: object
# ['937-952']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837208
# Name: 3972, dtype: object
# ['953-956']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837209
# Name: 3973, dtype: object
# ['957-971']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837210
# Name: 3974, dtype: object
# ['972-975']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837211
# Name: 3975, dtype: object
# ['976-1004']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837212
# Name: 3976, dtype: object
# ['1005-1010']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837213
# Name: 3977, dtype: object
# ['1011-1013']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837214
# Name: 3978, dtype: object
# ['1014-1027']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837215
# Name: 3979, dtype: object
# ['1028-1035']
# found
# year                                          1969
# issue                                            6
# volume                                          77
# stable_url    https://www.jstor.org/stable/1837216
# Name: 3980, dtype: object
# ['1036-1039']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829964
# Name: 3988, dtype: object
# ['721-754']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829965
# Name: 3989, dtype: object
# ['755-764']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829966
# Name: 3990, dtype: object
# ['765-777']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829967
# Name: 3991, dtype: object
# ['778-794']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829968
# Name: 3992, dtype: object
# ['795-816']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829969
# Name: 3993, dtype: object
# ['817-826']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829970
# Name: 3994, dtype: object
# ['827-833']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829971
# Name: 3995, dtype: object
# ['834-844']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829972
# Name: 3996, dtype: object
# ['845-850']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829973
# Name: 3997, dtype: object
# ['851-856']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829974
# Name: 3998, dtype: object
# ['857-861']
# found
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829975
# Name: 3999, dtype: object
# ['862']
# year                                          1969
# issue                                            5
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829976
# Name: 4000, dtype: object
# ['863']
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829320
# Name: 4008, dtype: object
# ['573-574']
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829321
# Name: 4009, dtype: object
# ['575-585']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829322
# Name: 4010, dtype: object
# ['586-627']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829323
# Name: 4011, dtype: object
# ['628-652']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829324
# Name: 4012, dtype: object
# ['653-664']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829325
# Name: 4013, dtype: object
# ['665-683']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829326
# Name: 4014, dtype: object
# ['684-697']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829327
# Name: 4015, dtype: object
# ['698-719']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829439
# Name: 4018, dtype: object
# ['453-470']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829440
# Name: 4019, dtype: object
# ['471-477']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829441
# Name: 4020, dtype: object
# ['478-483']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829442
# Name: 4021, dtype: object
# ['484-486']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829443
# Name: 4022, dtype: object
# ['487-488']
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829444
# Name: 4023, dtype: object
# ['489-493']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829445
# Name: 4024, dtype: object
# ['494-503']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829446
# Name: 4025, dtype: object
# ['504-511']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829447
# Name: 4026, dtype: object
# ['512-523']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829448
# Name: 4027, dtype: object
# ['524-527']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829449
# Name: 4028, dtype: object
# ['528-531']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829450
# Name: 4029, dtype: object
# ['532-544']
# found
# year                                          1969
# issue                                            4
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829451
# Name: 4030, dtype: object
# ['545-558']
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828905
# Name: 4039, dtype: object
# ['295-305']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828906
# Name: 4040, dtype: object
# ['306-328']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828907
# Name: 4041, dtype: object
# ['329-348']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828908
# Name: 4042, dtype: object
# ['349-362']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828909
# Name: 4043, dtype: object
# ['363-391']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828910
# Name: 4044, dtype: object
# ['392-398']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828911
# Name: 4045, dtype: object
# ['399-407']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828912
# Name: 4046, dtype: object
# ['408-417']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828913
# Name: 4047, dtype: object
# ['418-429']
# found
# year                                          1969
# issue                                            3
# volume                                          77
# stable_url    https://www.jstor.org/stable/1828914
# Name: 4048, dtype: object
# ['430-433']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829763
# Name: 4056, dtype: object
# ['153-180']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829764
# Name: 4057, dtype: object
# ['181-198']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829765
# Name: 4058, dtype: object
# ['199-218']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829766
# Name: 4059, dtype: object
# ['219-236']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829767
# Name: 4060, dtype: object
# ['237-241']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829768
# Name: 4061, dtype: object
# ['242-244']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829769
# Name: 4062, dtype: object
# ['245-248']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829770
# Name: 4063, dtype: object
# ['249-273']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829771
# Name: 4064, dtype: object
# ['274-285']
# found
# year                                          1969
# issue                                            2
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829772
# Name: 4065, dtype: object
# ['286-290']
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829062
# Name: 4070, dtype: object
# ['1-20']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829063
# Name: 4071, dtype: object
# ['21-34']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829064
# Name: 4072, dtype: object
# ['35-48']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829065
# Name: 4073, dtype: object
# ['49-59']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829066
# Name: 4074, dtype: object
# ['60-65']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829067
# Name: 4075, dtype: object
# ['66-84']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829068
# Name: 4076, dtype: object
# ['85-98']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829069
# Name: 4077, dtype: object
# ['99-117']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829070
# Name: 4078, dtype: object
# ['118-121']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829071
# Name: 4079, dtype: object
# ['122-129']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829072
# Name: 4080, dtype: object
# ['130-137']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829073
# Name: 4081, dtype: object
# ['138-140']
# found
# year                                          1969
# issue                                            1
# volume                                          77
# stable_url    https://www.jstor.org/stable/1829074
# Name: 4082, dtype: object
# ['141-147']
# found
# year                                          1968
# issue                                            6
# volume                                          76
# stable_url    https://www.jstor.org/stable/1830153
# Name: 4089, dtype: object
# ['1107-1122']
# found
# year                                          1968
# issue                                            6
# volume                                          76
# stable_url    https://www.jstor.org/stable/1830154
# Name: 4090, dtype: object
# ['1123-1151']
# found
# year                                          1968
# issue                                            6
# volume                                          76
# stable_url    https://www.jstor.org/stable/1830155
# Name: 4091, dtype: object
# ['1152-1169']
# found
# year                                          1968
# issue                                            6
# volume                                          76
# stable_url    https://www.jstor.org/stable/1830156
# Name: 4092, dtype: object
# ['1170-1198']
# found
# year                                          1968
# issue                                            6
# volume                                          76
# stable_url    https://www.jstor.org/stable/1830157
# Name: 4093, dtype: object
# ['1199-1208']
# found
# year                                          1968
# issue                                            6
# volume                                          76
# stable_url    https://www.jstor.org/stable/1830158
# Name: 4094, dtype: object
# ...
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829545
# Name: 4351, dtype: object
# ['49-62']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829546
# Name: 4352, dtype: object
# ['63-70']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829547
# Name: 4353, dtype: object
# ['71-76']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829548
# Name: 4354, dtype: object
# ['77-85']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829549
# Name: 4355, dtype: object
# ['86-90']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829550
# Name: 4356, dtype: object
# ['91-92']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829551
# Name: 4357, dtype: object
# ['93-96']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829552
# Name: 4358, dtype: object
# ['96-97']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829553
# Name: 4359, dtype: object
# ['98-99']
# found
# year                                          1967
# issue                                            1
# volume                                          75
# stable_url    https://www.jstor.org/stable/1829554
# Name: 4360, dtype: object
# ['100-101']
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828738
# Name: 4375, dtype: object
# ['543-555']
# found
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828739
# Name: 4376, dtype: object
# ['556-572']
# found
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828740
# Name: 4377, dtype: object
# ['573-586']
# found
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828741
# Name: 4378, dtype: object
# ['587-599']
# found
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828742
# Name: 4379, dtype: object
# ['600-623']
# found
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828743
# Name: 4380, dtype: object
# ['624-628']
# found
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828744
# Name: 4381, dtype: object
# ['629-631']
# found
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828745
# Name: 4382, dtype: object
# ['632-634']
# found
# year                                          1966
# issue                                            6
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828746
# Name: 4383, dtype: object
# ['635-636']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829592
# Name: 4392, dtype: object
# ['425-450']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829593
# Name: 4393, dtype: object
# ['451-465']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829594
# Name: 4394, dtype: object
# ['466-480']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829595
# Name: 4395, dtype: object
# ['481-499']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829596
# Name: 4396, dtype: object
# ['500-505']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829597
# Name: 4397, dtype: object
# ['506-511']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829598
# Name: 4398, dtype: object
# ['512-518']
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829599
# Name: 4399, dtype: object
# ['519-523']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829600
# Name: 4400, dtype: object
# ['524-525']
# found
# year                                          1966
# issue                                            5
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829601
# Name: 4401, dtype: object
# ['526-528']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829150
# Name: 4415, dtype: object
# ['315-332']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829151
# Name: 4416, dtype: object
# ['333-352']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829152
# Name: 4417, dtype: object
# ['353-367']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829153
# Name: 4418, dtype: object
# ['368-378']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829154
# Name: 4419, dtype: object
# ['379-395']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829155
# Name: 4420, dtype: object
# ['396-400']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829156
# Name: 4421, dtype: object
# ['401-402']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829157
# Name: 4422, dtype: object
# ['403-405']
# found
# year                                          1966
# issue                                            4
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829158
# Name: 4423, dtype: object
# ['406']
# year                                          1966
# issue                                            3
# volume                                          74
# stable_url    https://www.jstor.org/stable/1861768
# Name: 4439, dtype: object
# ['221-237']
# found
# year                                          1966
# issue                                            3
# volume                                          74
# stable_url    https://www.jstor.org/stable/1861769
# Name: 4440, dtype: object
# ['238-249']
# found
# year                                          1966
# issue                                            3
# volume                                          74
# stable_url    https://www.jstor.org/stable/1861770
# Name: 4441, dtype: object
# ['250-264']
# found
# year                                          1966
# issue                                            3
# volume                                          74
# stable_url    https://www.jstor.org/stable/1861771
# Name: 4442, dtype: object
# ['265-273']
# year                                          1966
# issue                                            3
# volume                                          74
# stable_url    https://www.jstor.org/stable/1861772
# Name: 4443, dtype: object
# ['274-277']
# found
# year                                          1966
# issue                                            3
# volume                                          74
# stable_url    https://www.jstor.org/stable/1861773
# Name: 4444, dtype: object
# ['278-280']
# found
# year                                          1966
# issue                                            3
# volume                                          74
# stable_url    https://www.jstor.org/stable/1861774
# Name: 4445, dtype: object
# ['281-285']
# found
# year                                          1966
# issue                                            3
# volume                                          74
# stable_url    https://www.jstor.org/stable/1861775
# Name: 4446, dtype: object
# ['286-290']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828834
# Name: 4466, dtype: object
# ['111-131']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828835
# Name: 4467, dtype: object
# ['132-157']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828836
# Name: 4468, dtype: object
# ['158-167']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828837
# Name: 4469, dtype: object
# ['168-176']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828838
# Name: 4470, dtype: object
# ['177-187']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828839
# Name: 4471, dtype: object
# ['188-194']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828840
# Name: 4472, dtype: object
# ['195-199']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828841
# Name: 4473, dtype: object
# ['200-205']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828842
# Name: 4474, dtype: object
# ['206-207']
# found
# year                                          1966
# issue                                            2
# volume                                          74
# stable_url    https://www.jstor.org/stable/1828843
# Name: 4475, dtype: object
# ['208']
# found
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829196
# Name: 4490, dtype: object
# ['1-17']
# found
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829197
# Name: 4491, dtype: object
# ['18-33']
# found
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829198
# Name: 4492, dtype: object
# ['34-45']
# found
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829199
# Name: 4493, dtype: object
# ['46-54']
# found
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829200
# Name: 4494, dtype: object
# ['55-68']
# found
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829201
# Name: 4495, dtype: object
# ['69-71']
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829202
# Name: 4496, dtype: object
# ['72-76']
# found
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829203
# Name: 4497, dtype: object
# ['77-80']
# found
# year                                          1966
# issue                                            1
# volume                                          74
# stable_url    https://www.jstor.org/stable/1829204
# Name: 4498, dtype: object
# ['81-83']
# found
# 2086.818669319153
# 4498

# %% [markdown]
# Save references as a json file.

# %%
import json
with open(path+'//JPE_refs_output_1966_1970.json','w') as fp:
    json.dump(dict_ref, fp)

# %%
inv=Merged[(Merged['year']<=1966) & (Merged['year']>=1940)&(Merged['content_type']!='MISC')&(Merged['content_type']!='Review')&(Merged['content_type']!='Discussion')]
inv.shape
# Out:
# (1139, 25)

# %% [markdown]
# ### Consider references for years pre-1965 (inclusive)
# References are expected to be found in the footnotes from 1940 to 1965 (inclusive). Pdfminer.six is able to detect the size of the font through xml analysis. Use heuristics such as references are at the bottom of the page and of a different font type and size.

# %%
from io import StringIO
from pdfminer.high_level import extract_text_to_fp
from pdfminer.layout import LAParams
from pdfminer.high_level import extract_text
from pdfminer.layout import LTTextContainer, LTChar,LTLine,LAParams
# suppress logs
import logging 
logging.propagate = False
logging.getLogger().setLevel(logging.ERROR)
from pdfminer.high_level import extract_pages
#https://stackoverflow.com/questions/29762706/warnings-on-pdfminer

# %%
output_string = StringIO()
filepath=path+'\\2138780.pdf'
filepath='D:\\docs\\Masters\\Data\\ECTA_data\\1906861.pdf'
with open(filepath, 'rb') as fin:
    extract_text_to_fp(fin, output_string, laparams=LAParams(), output_type='html', codec=None)

# %%
for page_layout in extract_pages(filepath):
    for element in page_layout:
        print(element)
# Out:
# <LTTextBoxHorizontal(0) 50.000,621.788,514.684,713.788 'The Possibilities and Limitations of Objective Sampling in Strengthening Agricultural\nStatistics\nAuthor(s): Charles F. Sarle\nSource: Econometrica, Vol. 8, No. 1 (Jan., 1940), pp. 45-61\nPublished by: The Econometric Society\nStable URL: http://www.jstor.org/stable/1906861 .\nAccessed: 15/01/2015 07:49\n'>
# <LTTextBoxHorizontal(1) 50.000,578.830,476.530,601.613 'Your use of the JSTOR archive indicates your acceptance of the Terms & Conditions of Use, available at .\nhttp://www.jstor.org/page/info/about/policies/terms.jsp\n'>
# <LTTextBoxHorizontal(2) 50.000,518.830,552.980,565.613 ' .\nJSTOR is a not-for-profit service that helps scholars, researchers, and students discover, use, and build upon a wide range of\ncontent in a trusted digital archive. We use information technology and tools to increase productivity and facilitate new forms\nof scholarship. For more information about JSTOR, please contact support@jstor.org.\n'>
# <LTTextBoxHorizontal(3) 50.000,494.613,55.500,505.613 ' .\n'>
# <LTTextBoxHorizontal(4) 115.000,138.830,558.820,148.830 'The Econometric Society is collaborating with JSTOR to digitize, preserve and extend access to Econometrica.\n'>
# <LTTextBoxHorizontal(5) 50.000,73.830,134.170,83.830 'http://www.jstor.org \n'>
# <LTTextBoxHorizontal(6) 163.840,10.264,431.160,26.264 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(img0) 50.000,767.000,275.000,798.000 matrix=[225.00,0.00,0.00,31.00, (50.00,767.00)]>
# <LTLine 50.000,729.000,562.000,729.000>
# <LTLine 126.140,650.670,246.840,650.670>
# <LTLine 115.270,637.330,275.390,637.330>
# <LTRect 275.390,638.610,280.890,648.510>
# <LTLine 50.000,615.000,562.000,615.000>
# <LTRect 471.030,590.610,476.530,600.510>
# <LTLine 50.000,577.670,270.280,577.670>
# <LTRect 50.000,554.610,55.500,564.510>
# <LTRect 50.000,494.610,55.500,504.510>
# <LTFigure(img1) 50.000,86.000,110.000,151.590 matrix=[60.00,0.00,0.00,65.59, (50.00,86.00)]>
# <LTRect 0.000,0.000,595.000,36.000>
# <LTLine 278.050,9.330,374.720,9.330>
# <LTTextBoxHorizontal(0) 47.160,590.950,349.550,601.790 'THE  POSSIBILITIES  AND  LIMITATIONS  OF  OBJECTIVE \n'>
# <LTTextBoxHorizontal(1) 61.860,579.490,118.250,589.490 'SAMPLING \n'>
# <LTTextBoxHorizontal(2) 126.240,579.070,332.400,589.670 'IN  STRENGTHENING  AGRICULTURAL \n'>
# <LTTextBoxHorizontal(3) 165.120,567.370,231.530,577.370 'STATISTICS* \n'>
# <LTTextBoxHorizontal(4) 142.680,549.010,245.152,559.550 'By  CHARLES  F.  SARLE \n'>
# <LTTextBoxHorizontal(5) 40.440,460.030,358.270,541.790 'THERE  IS  NOTHING  NEW  or startling  in  the  fact  that  much  better  agri- \ncultural  statistics  are  needed  than  can  be  secured  with  the  facilities \nand  techniques  now  available.  The  type  of  agricultural  statistics  de- \nmanded,  at  any  one  time  has  reflected  the  nature  of  the  current  agri- \ncultural  problems  in  much  the  same  way  as  the  economic  theories  in \nthe  past  have  reflected  the  current  business  and  economic  conditions \nof the  times. \n'>
# <LTTextBoxHorizontal(6) 39.300,327.790,357.170,458.150 'During  the  several  decades  prior to  the  1860\'s representative  farm- \ners of  the  nation  began  to  demand  timely  agricultural  statistics  show- \ning the  "condition"  of the growing crops in various parts of the country, \nproduction  of  crops  at  harvest,  and  numbers  of  livestock  on  farms. \nThey  wanted  these  agricultural  statistics  and  they  wanted  them  to \nbe issued  by  a neutral  agency  such  as the  Government  rather than  by \ntrade  agencies.  Farmers  believed  that  crop  reports  as  then  issued  by \ntrade  interests  were  juggled  for  the  benefit  of  the  buyers  and  specu- \nlators.  They  believed  that  reports  of  a  big  crop were put  out  before  a \ncrop was  sold  by  the  farmers, only  to  be followed  by  reports of a much \nsmaller  production  after  the  crop  had  left  the  farmers\'  hands. \n'>
# <LTTextBoxHorizontal(7) 39.060,244.030,355.700,326.390 'The  state  and county  agricultural societies that  flourished during this \nperiod  before  the  Civil  War attempted  (without  success)  to  make  and \nissue  current  crop  reports.  Co-ordination  was  difficult  and  it  was  im- \npossible  to  get  a  sufficient  number  of  farmers  to  report  regularly  and \nconsistently.  One of  the  major  tasks  in  1862 of  the  newly  established \ngovernment  agency  that  later  became  the  Department  of  Agriculture \nwas  the  issuance  of  official  crop  reports. \n'>
# <LTTextBoxHorizontal(8) 38.520,95.987,355.570,242.630 'During  the  half  century  ending  with  the  World War this  nation  was \na  heavy  exporter  of  farm  products-cotton,  wheat,  cattle,  and  hogs. \nThe  demand  for agricultural  statistics  appears to  have been reasonably \nwell  satisfied  with  the  annual  estimates  of  crop production  and inven- \ntory  numbers  of  livestock  on  farms  January  1. The  need  for forecasts \nof crop production  during the  growing  season  was met  by  the  monthly \nreports  of  the  "condition"  or  appearance  of  the  crop.  These  rather \ncrude  statistics  presumably  reflected  the  direction  of  year-to-year \nchange in  agricultural  production  and  gave  a  rough  approximation  of \nthe  extent  of  the  change.  The  trade  early  developed  a  simple  method \nfor  translating  the  condition  reports  into  forecasts  of  crop  yield  and \n*  Paper presented at  Colorado Springs,  July  10,  1939,  before  Cowles  Com- \n'>
# <LTTextBoxHorizontal(9) 38.700,85.967,322.317,95.687 'mission Fifth  Annual Research Conference on Economics  and Statistics. \n'>
# <LTTextBoxHorizontal(10) 189.840,68.590,202.340,78.590 '45 \n'>
# <LTTextBoxHorizontal(11) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 35.280,592.510,47.780,602.510 '46 \n'>
# <LTTextBoxHorizontal(1) 152.040,593.641,230.348,600.881 'CHARLES  F.  SARLE \n'>
# <LTTextBoxHorizontal(2) 35.280,556.630,350.040,579.830 'production-a  method  that  was  later  (1915)  adopted  by  the  Depart- \nment. \n'>
# <LTTextBoxHorizontal(3) 35.520,460.510,352.100,556.010 'Prices  received  by  farmers  for  crops  as  of  December  1  each  year \nwere  estimated  and  used  in  calculating  the  value  of  crop production, \nfor  each  crop  and  for  the  total  of  all  crops.  Likewise  the  prices  of \nlivestock  as  of  January  1 were  estimated  and  used  in  calculating  live- \nstock  values.  Furthermore,  an inquiry  concerning wage  rates paid farm \nrates,  with  and  without  board,  and  day  rates, \nlaborers--monthly \nwith  and  without  board-was  made  19 times  during  the  period  from \n1866 to  1909 inclusive,  and  annually  thereafter. \n'>
# <LTTextBoxHorizontal(4) 35.880,340.630,352.440,459.950 'It  was not  until  about  1910 that  Nat  C. Murray,  a foresighted  statis- \ntician  in  the  Department  of  Agriculture,  succeeded  in  starting  a \nmonthly  inquiry  on  prices  received  by  farmers  for  42  agricultural \nproducts  sold  from  the  farm.  In  fact,  one  of  the  reasons  for  starting \nthis  price-reporting  service  was  to  provide  useful  employment  for the \nclerks  during  the  slack  time  between  monthly  crop  reports.  Annual \ninquiries  relating  to  prices  paid  by  farmers,  land  values,  rents,  etc., \nwere begun  about  this  time.  One is inclined  to  wonder  just  what  post- \nwar economists,  statisticians,  and legislators  would  have  done without \nthese  prewar data  in  calculating  price indexes  and  "parity  prices." \n'>
# <LTTextBoxHorizontal(5) 36.720,220.690,353.490,340.190 'During  that  first  half  century  of  official  agricultural  statistics  the \nmethods  of  sampling  employed  were  relatively  simple.  Voluntary  cor- \nrespondents  were  asked  to  report  on  the  situation  in  their  immediate \nlocality.  The  sample  data  represented  their  judgment  as  to  a  given \nphenomenon  yield  per  acre  for  a  crop  at  harvest,  condition  of  a \ngrowing  crop in  per  cent  of  "normal,"  the  current  year\'s  acreage  of  a \ncrop  or  numbers  of  a  given  class  of  livestock  as  a  percentage  of  last \nyear\'s,  prices  received  or paid,  prevailing  wage  rates,  and  so  on.  The \nbest  and  most  public-spirited  farmers  were  encouraged  to  serve  as \nvoluntary  unpaid  reporters. \n'>
# <LTTextBoxHorizontal(6) 37.440,160.690,353.180,220.190 'Accumulative  bias  in  the  reports  on  acreage  and  livestock  numbers \nbecame  apparent  when  current  estimates  in  census  years  were  com- \npared with  census  data.  The  year-to-year  estimates  of  change  applied \nto  the  previous  census  as  a  base  failed  to  keep  abreast  of  the  rapidly \nexpanding  agricultural  plant  during  the  decades  from  1870 to  1900. \n'>
# <LTTextBoxHorizontal(7) 37.560,64.930,353.530,160.190 'Improvements  in  methods  of  sampling  and  estimating  during  this \npre-World-War  period  were  made  primarily  by:  (1)  increasing  the \nsize  of  the  sample,  (2)  increasing  the  number  of  state  agents  and \nextending  their  employment  from  part-time  to  full-time,  (3)  and  em- \nploying  a  few  crop  specialists  on  a  regional  basis.  The  township  list \nof  reporters  was  set  up  in  1897,  thereby  greatly  increasing  the  size \nof the  samples  over the  size of samples  obtained  from county  reporters. \nThat  is,  the  objective  was  to  have  an  active  reporter in  each  agricul- \n'>
# <LTTextBoxHorizontal(8) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 149.880,595.141,239.033,602.261 'OBJECTIVE  SAMPLING \n'>
# <LTTextBoxHorizontal(1) 342.960,594.250,355.460,604.250 '47 \n'>
# <LTTextBoxHorizontal(2) 38.700,474.670,355.500,580.970 'tural  township  reporting  for  his  locality  in  addition  to  a  reporter  in \neach  county  reporting  for  the  entire  county.  The  original  plan  called \nfor several  subreporters  to  report to  the  county  reporter on  conditions \nin the  parts  of the  county  where they  lived-a  plan  that  never  seemed \nto  work  out  very  well  in  practice.  Furthermore,  it  was  impossible  to \npersuade  more than  50 to  possibly  75 per  cent  of the  county  reporters \nto  respond  in  any  one  month.  There  was  obviously  a  limit  to  the \namount  of  service  these  people  would  give  without  financial  com- \npensation. \n'>
# <LTTextBoxHorizontal(3) 38.880,378.190,355.950,472.790 'The  part-time  state  agents  frequently  were men  on  the  agricultural \nstaffs  of  agricultural  colleges  and  experiment  stations  whose  regular \nduties  kept  them  in  touch  with  agricultural  conditions  in  their  respec- \ntive  states.  Others  were  men  with  political  connections.  The  regional \nmen  usually  were full-time  reporters who  traveled  over  several  states. \nBoth  state  agents  and  regional  men  had  small  lists  of  crop  corre- \nspondents  reporting directly  to  them.  It  was  not  until  1913 that  state \ncrop and  livestock  estimators  were  brought  under  Civil  Service. \n'>
# <LTTextBoxHorizontal(4) 38.580,329.770,358.350,376.790 'The  entire  system  of  sampling  and  estimating  was  highly  subjective \nin nature, in that  the observations  were opinions expressed in quantita- \ntive  terms  and  the  sample  was  obtained  from  voluntary  crop  corre- \nspondents  who  were  willing  to  serve  without  pay. \n'>
# <LTTextBoxHorizontal(5) 38.880,258.130,355.650,328.670 'The  World War with  its  problems  of producing  food for civilian  and \narmy  consumption,  as well  as for export  to  the  Allies,  gave  rise to  the \ndemand for more accurate  estimates  of agricultural  production  and for \nquantitative  forecasts  of  crop production  from the  monthly  condition \nreports.  In  April,  1918  an  inquiry  on  the  supply  of  and  demand  for \nfarm labor in  percentage  of  normal  was  started. \n'>
# <LTTextBoxHorizontal(6) 38.640,89.830,358.890,256.670 'The  economic  and  social  maladjustments  in  American  agriculture \ngrowing  out  of  the  World  War further  increased  the  demand  for more \nand  better  statistics,  especially  those  relating  to  economic  aspects  of \nagriculture.  Estimates  of  the  annual  production  of  livestock  and  live- \nstock products  and estimates  of farm income  were started  in the  1920\'s. \nEstimates  of  farm  employment  were  begun  from  samples  of  the  indi- \nvidual farms of crop reporters. The agricultural statistics  of the  Depart- \nment  began  to  be  used  in  many  Tays never  anticipated  by  those  who \ncompiled them  and who were responsible  for their  accuracy.  Statistical \neconomic  analyses  were  made  to  determine  the  factors  that  influence \nprices,  supply,  consumption,  and  exports  of  agricultural  products.  It \nwas  during  the  1920\'s  that  "Big  Business"  began  to  demand  agricull- \ntural  statistics  of  production  and  income  by  counties  as  a  basis  for \ndetermining  sales  programs,  and  quotas. \n'>
# <LTTextBoxHorizontal(7) 39.240,65.470,354.820,88.430 'Acute  distress  arising  from  the  economic  effects  of  the  world-wide \ndepression  of  the  1930\'s has  given  rise to  many  "action"  programs by \n'>
# <LTTextBoxHorizontal(8) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 39.120,592.270,51.620,602.270 '48 \n'>
# <LTTextBoxHorizontal(1) 156.000,592.741,233.948,599.801 'CHARLES  F.  SARLE \n'>
# <LTTextBoxHorizontal(2) 39.000,544.030,354.790,578.510 'Federal  and  state  agencies,  designed  to  alleviate  directly  distress  con- \nditions  of agriculture.  The  administration  of these  programs has called \nfor  unexpected  uses  of  available  agricultural  statistics. \n'>
# <LTTextBoxHorizontal(3) 38.940,448.330,355.180,542.630 'County  quotas  for  cotton  and wheat  acreages  had  to  be  established \nalmost  overnight  and,  to  determine  them,  average  yields  per  acre  for \nthe  country  had to be ascertained. A little  later, county  quotas  for corn \nand  hogs  had  to  be  established.  Crop and  livestock  statisticians  were \ndrafted  for service in  connection  with  the  operation  of these  programs. \nOther  programs,  authorized  by  Congress,  called  for  more  and  better \nstatistics  concerning  farm  tenure,  taxation,  credit,  and  movement  of \nthe  farm  population. \n'>
# <LTTextBoxHorizontal(4) 49.560,436.030,353.580,446.630 'Within  the  last  year  the  estimates  of  employment  on  farms  have \n'>
# <LTTextBoxHorizontal(5) 38.640,340.030,354.510,434.690 'been  used  along  with  estimates  of  nonfarm  and  city  employment- \nfor  making  estimates  of  monthly  employment  by  states.  These  esti- \nmates  of  employment  have  been  used  for  making  estimates  of  unem- \nployment  by  subtracting  the  number  of  employed  from  estimates  of \nthe  total  labor  force.  These  estimates  of  unemployment  are  one  of \nthe  factors  used  in  ascertaining  the  work-relief  needs  among  states. \nBillions  of  dollars  are allocated  among  states  largely  on  the  basis  of \nthese  crude  estimates  of  employment  and  unemployment. \n'>
# <LTTextBoxHorizontal(6) 38.520,256.570,354.240,338.870 'With  all  this  increase  in  the  uses  made  of  statistics  during  recent \nyears  little  or  no  provision  has  been  made  for improving  the  existing \nmethods  and  facilities  available  for  making  agricultural  statistics. \nWhat  can  be  done  to  strengthen  agricultural  statistics  to  meet  these \never-increasing  demands? As in the  past,  the  answer lies in the  further \ndevelopment  and use of objective, as contrasted  with  subjective, methods \nof  sampling  and  estimating. \n'>
# <LTTextBoxHorizontal(7) 37.740,220.390,353.800,255.110 'The  terms  objective  and  subjective  apply  (1)  to  the  nature  of  the \nindividual  observations,  (2)  to  the  method  of  sampling  followed  in \ntaking  the  observations,  and  (3)  to  the  methods  of estimation  used. \n'>
# <LTTextBoxHorizontal(8) 36.840,64.690,354.180,219.110 'Three kinds of observations  are made in obtaining  sample data relat- \ning to  agriculture:  (1) the judgment type of  data-the \nreporter is asked \nto  estimate  for his locality such items  as the  condition  or yield  per acre \nor change in acreage from last  year for a particular  crop, or the  change \nin  number  of  different  kinds  of  livestock,  or  the  prices  being  paid  or \nreceived  by  farmers,  (2)  the  individual farm  type of data \nthe  reporter \nis  asked  to  report,  for the farm  he operates,  the  acreage in  the  various \ncrops,  production,  or numbers  of  livestock,  and  (3)  the  direct count or \nmeasurement data-where \nthe  phenomenon  is  sampled  by  either  the \ncrop reporter or the  state  crop estimator  himself.  The  measurement  of \nthe  acreage  or field frontages  of the  various  crops along  selected  high- \nways  by  the  crop-meter,  stand  and  boll  counts  for  cotton,  and  head \nsampling  of  wheat,  are all  examples  of  direct  observational  data. \n'>
# <LTTextBoxHorizontal(9) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 150.240,591.661,239.393,598.901 'OBJECTIVE  SAMPLING \n'>
# <LTTextBoxHorizontal(1) 342.900,590.530,355.400,600.530 '49 \n'>
# <LTTextBoxHorizontal(2) 38.880,506.890,354.980,578.030 'The method  of sampling followed may  be subjective  in that  the selec- \ntion  of persons  reporting  or farms obtained  in  the  sample  is  controlled \nlargely  by  psychological  factors  as is  the  case  of  the  returns  from  un- \npaid  voluntary  crop correspondents.  The  method  may  be  objective  in \nthat  the  selection  of  observations  is  predetermined  by  the  statistician \naccording  to  sound  principles  of  sampling  design. \n'>
# <LTTextBoxHorizontal(3) 38.460,423.550,355.100,505.970 'The  method  of  estimation  may  be  subjective  when  the  statistician \ndepends  largely  on  his  (more  or less  snap)  judgment  in  giving  proper \nweight  to  two  or more indications  in  making  an  estimate  or objective \nwhen  the  statistician  sets  up predetermined  weights  based on evidence \nas  to  past  behavior,  statistical  precision  of  the  sample  indications,  or \nother  well-reasoned  criteria  for  combining  two  or more  indications  in \nmaking  an  estimate. \n'>
# <LTTextBoxHorizontal(4) 37.620,326.530,354.030,421.910 "During  the  decade from  1910 to  1920 under the  stimulus  of demands \nfor  more  accurate  statistics  arising  from  the  World  War,  the  idea  of \nasking  the  crop reporter for information  concerning  his  own  farm was \ntried out  in connection  with  acreages in the  various  crops and numbers \nof  livestock  on  farms-the \nindividual  farm inquiry  as  contrasted  with \nthe  judgment  inquiry  applying  to  the  locality.  By  the  middle  1920's \nthe  judgment  sample  on year-to-year  change in  acreages  and numbers \nof  livestock  was  replaced  entirely  by  the  individual  farm  sample. \n">
# <LTTextBoxHorizontal(5) 37.860,219.430,354.110,325.970 "At  first  the  reporter  was  asked  to  state  the  acreage  of  the  different \ncrops,  or  numbers  of  different  kinds  of  livestock  on  his  farm  for  the \ncurrent year and the year previous.  It  was soon found that  this  current- \nto-historic  comparison  was  subject  to  both  memory bias-a \nforgetting \nof  the  acreages  in  some  of  the  minor  crops,  and  to  cash-crop bias  a \ntendency  so to  state  the  acreages for the  2 years as to  minimize  the  cur- \nrent  year's  acreage  in  relation  to  the  acreage  in  the  previous  year. \nThe  annual  June acreage survey,  now used  in estimating  planted  acre- \nages,  is  an  inquiry  of  this  kind. \n">
# <LTTextBoxHorizontal(6) 37.020,122.890,352.810,218.150 'In  1924 the  rural-carrier acreage and livestock  surveys  were started. \nThe  rural  mail  carriers  distribute  schedules  to  farmers  along  their \nroutes.  The  size  of  sample  was  greatly  increased.  Only  data  for  the \ncurrent  year  were  obtained.  The  ratios  of  the  acreages  of  the  various \ncrops to  all  crop land  or to  all farm land  were used  from year  to  year, \nor from the  current year  to  the  census  or base  year,  in  making  annual \nestimates  of  crop  acreages.  In  this  way  the  influence  of  any  constant \nbias  found  in  the  current-to-historic  comparison  was  avoided. \n'>
# <LTTextBoxHorizontal(7) 36.960,87.790,352.600,122.270 'In  the  case  of  the  livestock  surveys,  the  year-to-year  relationship \nof  the  average  number  per  farm  was  used  in  estimating  changes  in \nnumbers  of  livestock. \n'>
# <LTTextBoxHorizontal(8) 36.900,62.830,352.830,85.970 'By  1929,  the  method  of  matching  reports  from  the  same  farms  for \n2 successive  years  was  adopted  to  get  an additional  indication  of year- \n'>
# <LTTextBoxHorizontal(9) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 36.540,591.190,49.040,601.190 '50 \n'>
# <LTTextBoxHorizontal(1) 153.600,591.721,231.728,598.841 'CHARLES  F.  SARLE \n'>
# <LTTextBoxHorizontal(2) 36.300,531.310,352.480,577.430 'to-year  change  for  both  crop  acreages  and  numbers  of  livestock. \nStratification  of  the  sample  by  size  of  farms  and  weighting  by  census \ndistribution  of farms by  size also were tried out,  but  the  results  did not \nappear  to  justify  the  increased  work  required. \n'>
# <LTTextBoxHorizontal(3) 36.000,399.550,353.310,529.430 'It  took  approximately  60  years  of  experience  in  crop  reporting  to \nprove  the  very  limited  utility  of  the  judgment  sample  of  year-to-year \nchange  in  acreage  and  livestock  numbers  and  to  adopt  methods  of \nusing  the  individual  farm  sample.  The  judgment  type  of  inquiry, \nhowever,  has  proven  satisfactory  as  a  basis  for  estimating  prices  and \nwage  rates  and fairly  satisfactory  in  estimating  yield  per acre of  crops \nat  harvest  and  condition  of  the  growing  crops.  The  more  intelligent, \nwell-informed,  and observant  the  voluntary  reporter, the  more reliable \nare  the  observations  in  the  case  of  a  judgment  type  of  sample.  This \nselection  of  better-than-average  farmers  for  reporting  on  judgment \ninquiries  is  an  advantage. \n'>
# <LTTextBoxHorizontal(4) 36.000,243.250,353.750,397.550 'When  these  same  reporters,  however,  are asked  to  report  crop acre- \nages  and livestock  numbers  for the  farms they  operate,  this  character- \nistic  of  selectivity  results  in  a  biased  sample.  It  is  selective,  or  repre- \nsentative,  only  of  those  classes  of  farmers  who  will  voluntarily  reply \nto  a  questionnaire  they  receive  in  the  mail  or  a  schedule  that  is  left \nin  their  mail  box  by  the  rural  carrier.  A  large  number  of  farmers \nnonresident  or  "suit-case"  farmers in  parts  of  the  wheat  belt,  tenants \nthat  move  frequently,  farmers  with  a poor  education  or  who  are  not \nfamiliar  with  the  English  language,  and  those  of  a  highly  suspicious \nnature-seldom  become  regular  crop  reporters  and  are  not  likely  to \nrespond  to  the  rural-carrier surveys.  Farms  operated  by  such  farmers \nare  seldom  represented  in  the  individual-farm  samples  relating  to \nacreages  and  livestock  numbers. \n'>
# <LTTextBoxHorizontal(5) 36.480,170.950,353.580,241.430 'It  is  true  that  drought,  floods,  and  powerful  economic  forces  are \nlikely  to  have  somewhat  similar  effects  on  all  classes  of  farms  and \nfarmers but  the  fact  remains that  the  established  methods  of sampling \nthat  are  available  to  the  Department  of  Agriculture  are  subjective \nrather than  objective;  consequently  the  samples  obtained  are selective \nand  not  representative  of  all  kinds  and  classes  of  farms. \n'>
# <LTTextBoxHorizontal(6) 47.340,158.950,350.900,169.310 'What  has been done  and what  can be done in the  way  of developing \n'>
# <LTTextBoxHorizontal(7) 36.720,147.130,180.560,157.190 'objective  methods  of  sampling? \n'>
# <LTTextBoxHorizontal(8) 36.360,63.310,353.640,145.550 'In  the  days  before  good  roads  formed  a  network  over  the  agricul- \ntural  areas  and  before  automobiles  became  cheap  enough  for  state \nagricultural  statisticians  to  own,  travel  was  limited  to  the  railroads. \nA  resourceful  statistician  conceived  the  idea  of  getting  a  measure  of \nthe  frontage  of the  fields in the  different crops by  counting  and record- \ning  the  number  of  telegraph  poles  for  each  crop  along  the  railroad \nright of way  as he rode along on the train.  By  going over the same route \n'>
# <LTTextBoxHorizontal(9) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 151.200,592.321,240.473,599.561 'OBJECTIVE  SAMPLING \n'>
# <LTTextBoxHorizontal(1) 344.520,591.070,357.020,601.070 '51 \n'>
# <LTTextBoxHorizontal(2) 39.780,508.390,356.300,578.870 'for 2 successive  years  he  obtained  data  that  would  furnish  an  indica- \ntion  of  change  in  acreage  of  the  various  crops  found  along  the  route. \nThese  were  objective  observations  and  although  the  routes  might  not \nbe representative,  he was able to  obtain  a sample of all farms along the \nroute-provided  of course he could identify  the  crops in  the  field  as he \nsped  along. \n'>
# <LTTextBoxHorizontal(3) 39.300,387.550,356.230,506.870 'Later  the  automobile  was  substituted  for  the  train  and  telephone \npoles  along  the  highways  were  counted  or the  number  of  fields  in  the \nvarious  crops were  counted.  Later, about  1925,  one  of  the  field statis- \nticians,  D.  A.  McCandliss,  invented  the  "crop-meter"  for  measuring \nthe  frontages  in  the  various  crops on  one  side  of  the  highway;  later  a \n"double-bank"  machine  was  perfected  that  permitted  both  sides  of \nthe  road  to  be  "metered"  at  the  same time.  Two  men in  a  car  are  re- \nquired to measure both  sides of the  road simultaneously-one \nto punch \nthe  buttons  on  the  crop-meter  and  the  other  to  drive  the  car  and  to \ncheck  the  identification  of  the  crops  made  by  the  first  man. \n'>
# <LTTextBoxHorizontal(4) 39.060,303.670,355.360,386.990 'The measurement  of the frontage  of a given  crop along a "representa- \ntive"  route  taken  in  the  current  year  is  compared  with  the  measure- \nments  over  the  same  route  for  the  same  crop  taken  in  the  previous \nyear  or in  the  census  year  or in  both  years,  in  obtaining  an indication \nof  change  in  acreage.  The  observational  data  are  objective  but  the \nselection  of  the  representative  route  involves  the  use  of judgment  and \nconsequently  is  subjective  and is  liable  to  bias  the  sample. \n'>
# <LTTextBoxHorizontal(5) 39.240,232.390,354.940,302.990 'A  study  is  being  made  to  test  the  basic  assumptions  involved  in \nusing  the  crop-meter  data  as  a  basis  for  estimating  acreage  change. \nAerial photographic  survey  data  for  acreage in  19 counties  located  in \n10 North  Central States  are being used for the purpose of this  and other \nsampling  studies  relating  to  acreage.  Data  for  only  1 year  have  been \navailable  for study  thus  far. \n'>
# <LTTextBoxHorizontal(6) 38.880,195.550,355.110,231.230 'An  intensive  application  of  the  crop-meter  method  of  sampling  is \nbeing  made in  a number  of  cotton  counties  where  complete  AAA  acre- \nage measurements  will  be  available  for checking  the  sample. \n'>
# <LTTextBoxHorizontal(7) 38.400,88.270,355.070,195.110 'The  crop-meter  sample  has  proved  to  give  a  valuable  indication  of \nyear-to-year  change  in  the  acreage  of  a  crop  that  changes  greatly \nfrom year  to  year in  an important  commercial  producing  area, such  as \npotatoes  on the  Eastern  Shore of  Virginia.  The  crop-meter  sample  has \ngiven  a  reliable  indication  of  the  acreage  of  cotton  in  South  Carolina \nand  has  been  used  for  a  number  of  years  for  cotton  in  other  states. \nBut  in  some  areas,  such  as  the  lowlands  of  river  valleys,  the  cropping \npractices  and  selection  of crops along  the  highways  might  not  be at  all \nrepresentative  of  those  away  from  the  roads. \n'>
# <LTTextBoxHorizontal(8) 38.520,63.610,352.510,87.110 'The  crop-meter  cannot  be  used  in  estimating  changes  in  livestock \nnumbers.  The  samples  of  individual  farms  obtained  from  voluntary \n'>
# <LTTextBoxHorizontal(9) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 42.000,592.090,54.500,602.090 '52 \n'>
# <LTTextBoxHorizontal(1) 158.760,593.161,236.888,600.221 'CHARLES  F.  SARLE \n'>
# <LTTextBoxHorizontal(2) 41.760,543.730,357.010,578.870 'crop correspondents  and  by  the  help  of the  rural mail  carriers are not \nsufficiently  representative  to  meet  present-day  demands  for  accuracy \nand  for geographic  detail  involved  in  county  estimates. \n'>
# <LTTextBoxHorizontal(3) 41.160,424.090,357.960,542.870 'The  logical  way  out  of  this  difficulty  in  getting  selectivity  of  acre- \nage  and  livestock  samples  is  to  provide  for  an  enumerative sample  or \nsample  census  each  year.  Paid  enumerators  would  obtain  acreages  of \nthe  various  crops and the  number  of the  different  kinds  and  classes  of \nlivestock  from  a  sample  of  individual  farms  by  personal  interview. \nDependable  statistical  methods  could  be  used  in  designing  a  sample \nthat  would  be  representative  of  all  kinds  of  farms  in  an  area.  This \nmethod  of  conducting  an  enumerative  sample  has  been  tried  experi- \nmentally  with  good results,  but it is much more expensive  than  obtain- \ning  a  sample  by  mail  or with  the  help  of  the  rural carrier. \n'>
# <LTTextBoxHorizontal(4) 40.200,268.510,356.510,423.110 'When  samples  are used  instead  of  a  complete  enumeration,  there  is \nalways  the  problem  of  having  a  sample  large  enough  to  give  "service- \nable  accuracy"  to  the  average  or  other  statistics  calculated  from  the \nsample,  assuming,  of  course,  that  the  sample  is  not  selective  and  is \nfree from bias.  Data  relating  to  the  acreage of a given  crop or numbers \nof a particular  class of livestock  on individual  farms vary  greatly  from \nfarm  to  farm  even  in  the  same  locality  and  from  year  to  year  on  the \nsame  farm.  For  statistical  purposes  the  acreage  of  a  crop  on  some \nfarms may  be  "zero," on others it  may  be hundreds or even  thousands \nof  acres.  Some  farms  may  not  grow the  crop at  all one  year  and  may \nhave  a  substantial  acreage  of  that  crop  in  another  year.  Variability \nin  acreage of a crop has no well-defined  limits  established  by  nature  as \nis  the  case  with  yield  per  acre  of  a  crop. \n'>
# <LTTextBoxHorizontal(5) 39.720,64.930,356.590,267.350 'The problem of making reliable estimates  of yield per acre for various \ncrops  does  not  involve  so  many  serious  difficulties  as  the  problem  of \nestimating  acreage.  The  well-informed  crop  correspondent  is  usually \nwell  qualified to  estimate  the yield  per acre for a given  crop on  his own \nfarm  and  usually  on a  number  of farms  in  the  neighborhood.  It  is  en- \ntirely  practicable,  therefore,  to  use these  "judgment"  (for the  locality) \nreports  on  yield  as  the  direct  basis  for  annual  estimates  of  yield  per \nacre. However,  the  figures for yields  per acre derived  from  census  data \nserve  as a useful  check in  census  years  and as a measure  of bias that  is \napplied  to  the  current year\'s  sample.  Any  incompleteness  in the  census \ncoverage  of farms is  not  likely  to  be serious,  in  so far as yield  per acre \nis  concerned,  unless  the  enumerator  consistently  fails  to  get  either  the \nlower-  or the  higher-yielding  farms  in  his  district.  But  the  nearer the \ntime  of  taking  the  census  to  the  completion  of  harvest,  the  more  re- \nliable  are the  census data  on yield  per acre. Late fall would  be the ideal \nfarmers  have \ntime  to  take  the  Federal  census  of  agriculture-before \nmoved  to  other  farms. \n'>
# <LTTextBoxHorizontal(6) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 151.740,593.161,241.193,600.281 'OBJECTIVE  SAMPLING \n'>
# <LTTextBoxHorizontal(1) 345.060,592.870,357.560,602.870 '53 \n'>
# <LTTextBoxHorizontal(2) 40.440,448.630,357.430,579.350 'The  problem  of  selectivity  of  the  sample  is  much  less  serious  with \nthe  judgment  inquiry  on yields  than  with  the  individual-farm  inquiry \non  acreage.  Selectivity,  however,  must  be  guarded  against.  In  recent \nyears  the  regular  judgment  inquiry  on  yields  has  been  supplemented \nby  an individual-farm  inquiry  on  acreage  and production,  from which \na  figure  for  yield  per  acre  is  derived.  As  might  be  expected,  such  an \ninquiry  is  selective  of  the  more  productive  farms  in  most  states  and \nthe  yields  obtained  are  used  primarily  in  a  relative  way  to  indicate \nyear-to-year  changes. Judgment  yield inquiries obtained  from operators \nof  grain  elevators  also  are  used  in  some  states  to  supplement  the  re- \nturns  from  regular  crop reporters. \n'>
# <LTTextBoxHorizontal(3) 40.680,376.630,356.500,447.290 'The  yield-per-acre  data,  whether  from the  judgment  inquiry  for the \nlocality  or  from  the  individual-farm  inquiry,  are  much  less  variable \nthan  are  acreage  data.  Nature  sets  up  limits  to  the  variation  in  yield \nper acre.  Consequently,  the  size  of  sample  need  not  be nearly  so large \nfor a given  degree of precision  as with  samples  of crop acreages or live- \nstock  numbers  on  individual  farms. \n'>
# <LTTextBoxHorizontal(4) 40.200,316.570,356.740,375.230 'The  greatest  weakness  or  source  of  error in  the  data  and  methods \nnow  in  use  in  estimating  yield  per  acre  is  the  cash-crop  bias  (under- \nstatement)  that  appears  in  the  sample  data  for  certain,  if  not  all, \ncommercial  crops.  This  cash-crop  bias  is  not  consistent  from  year  to \nyear  in  the  same  state  or among  states  in  the  same  year. \n'>
# <LTTextBoxHorizontal(5) 40.080,196.870,356.560,315.230 'To  meet  the  problem  of  cash-crop  bias  in  yield  sample  data  the \nDepartment  of Agriculture  is  experimenting  with  preharvest  field sur- \nveys  for  cotton,  wheat,  corn,  and  apples.  There  is  a  need  for  further \ndevelopment  and use of such methods  based on physical  measurements \nof yield  taken  from representative  fields whereby  the  factor  of  human \nbias  is  held  to  a  minimum  or  is  eliminated.  Additional  trained  crop \nestimators  are  needed  to  obtain  a  sample  of  sufficient  size,  as  these \nof  ear  in  the \nsurveys  involve  actual  counts  and  measurements-size \ncase  of  corn,  head  samples  for wheat,  boll  counts  and  size  of  bolls  for \nin  commercial  fields  over  wide  areas. \ncotton-made \n'>
# <LTTextBoxHorizontal(6) 39.600,76.990,355.700,195.350 'In  the  summer  of  1938  a  survey  of  wheat  was  made  immediately \npreceding the  harvest  in  five  crop-reporting districts  in Eastern  North \nDakota.  East-and-west  and  north-and-south  routes  were  selected  in \neach  district.  Wheat  fields  were selected  every  2 miles  of wheat  front- \nage  on one  side  of the  road  along  these  routes.  A  crop-meter  was  used \nto  measure  the  wheat  frontage.  Two  head  samples  were  taken  from \neach  field  from  a  strip  not  over  125  paces  wide  that  paralleled  the \nhighway.  In  all  232  fields  were  sampled.  Seven  varieties  were  found, \nalthough  444  of the  total  of 464 samples were of three varieties-Ceres, \nThatcher,  and  Durum. \n'>
# <LTTextBoxHorizontal(7) 50.040,65.110,355.500,75.950 'The  head  samples  were  threshed  later  and  the  yield  data  were \n'>
# <LTTextBoxHorizontal(8) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 42.960,592.510,55.460,602.510 '54 \n'>
# <LTTextBoxHorizontal(1) 159.840,592.381,237.848,599.561 'CHARLES  F.  SARLE \n'>
# <LTTextBoxHorizontal(2) 42.540,507.430,358.890,578.510 'analyzed  to  determine  sources  of  variability.  The  greatest  source  of \nvariability  was  variety,  the  next  largest  source  was  the  geographic \ndistricts.  The  variability  among  fields  was  significantly  greater  than \nthe  variability  within  fields,  indicating  that  maximum  efficiency  in \nsampling  could  be  obtained  by  increasing  the  number  of  fields  rather \nthan  by  increasing  the  number  of  observations  within  fields. \n'>
# <LTTextBoxHorizontal(3) 42.180,424.150,358.120,506.990 'The  yield  obtained  from the  objectively  taken  sample  was  generally \nhigher  than  the  yield  reported  by  agricultural  correspondents.  This \ndifference  is  no  doubt  due  in  part  to  losses  in  grain  that  occur  in \nharvesting  and  threshing  or  combining.  A  similar  preharvest  survey \nis  now  (1939)  being  taken  extending  from  Oklahoma  to  the  Canadian \nborder.  Quality  characteristics  of  protein  percentage  and  test  weight \nper  bushel  also  are being  ascertained. \n'>
# <LTTextBoxHorizontal(4) 41.700,315.790,358.740,422.870 'Estimates  of  production  are  made  by  multiplying  the  estimates  of \nharvested  acreage  by  estimates  of  yield  per  acre.  In  the  case  of  a \nnumber  of  commercial  crops,  marketing  or  processing  records  are \nobtained  and used in truing up estimates  of production  for the  previous \nyear.  A  complete  record of the  quantity  of  cotton  ginned  each  year  is \nmade  by  the  Census  Bureau.  Reasonably  complete  information  is \nobtained  on  total  annual  sales  of such  crops  as  tobacco,  peanuts,  rice, \nsugar, and crops for canning. Railroad shipments  and mill-door receipts \nare  obtained  for  wheat,  rye,  and  flax in  a  number  of  States. \n'>
# <LTTextBoxHorizontal(5) 41.220,208.990,358.110,315.230 'When  the  total  quantity  of a crop sold is  considered  along with  esti- \nrmates of farm utilization  for seed,  carry-over on the farm into  the  next \nseason,  and other farm uses,  an estimate  of production  can be made  for \na crop that  is independent  of the  production  estimate  based on acreage \nand yield  per acre. These estimates  based on sales are useful in assisting \nthe  crop  estimator  in  finding  and  measuring  bias  in  the  sample  data \nand  methods  used  in  making  the  current  estimates.  Every  effort  is \nmade  to  obtain  data  on  sales,  market  movement,  and  processing  of \ncommercial  crops. \n'>
# <LTTextBoxHorizontal(6) 127.560,189.061,263.841,196.541 'FORECASTING  CROP  PRODUCTION \n'>
# <LTTextBoxHorizontal(7) 41.220,136.690,357.440,183.470 'The  first  official forecasts  of  crop production  for  most  of  the  major \ncrops are made in connection  with the  July  crop report. The production \nof  fall-sown  winter  wheat  and  rye  is  forecast  several  months  earlier, \nand  cotton  on  August  1 each  year. \n'>
# <LTTextBoxHorizontal(8) 40.860,88.750,357.710,135.590 'The  forecasts  of  crop production,  exclusive  of  tree  and  bush  crops, \nare made in  two  or three  steps:  (1)  estimates  of acres planted,  (2)  cur- \nrent  estimates  of  abandonment  of  acreage  since  planting  for  certain \ncrops,  and  (3)  forecasts  of  yield  per  acre. \n'>
# <LTTextBoxHorizontal(9) 40.320,64.270,357.670,87.470 'Forecasts  of yield  per acre before harvest  are based  primarily  on re- \nports  of  the  condition,  or promise  of yield,  of  the  crop  "in per  cent  of \n'>
# <LTTextBoxHorizontal(10) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 149.280,592.921,238.493,599.981 'OBJECTIVE  SAMPLING \n'>
# <LTTextBoxHorizontal(1) 342.360,592.630,354.860,602.630 '55 \n'>
# <LTTextBoxHorizontal(2) 38.160,519.910,355.240,578.570 'normal"  obtained  on  the  first  of  each  month  from  the  regular  crop \ncorrespondents of the  Department.  Later in the growing season a report \non  the  probable  yield  per acre also is  obtained.  Both  of these  samples \nare judgment  inquiries  based  on the  mass  opinion  of the  reporters and \nthey  apply  to  the  locality  in  which  the  crop  reporter  lives. \n'>
# <LTTextBoxHorizontal(3) 38.280,375.790,355.520,518.630 'The  condition  reports  are not  so likely  to  be  selective  as  are the  re- \nports  on  yield  per  acre  or  acreage.  The  condition  data  also  are  less \nvariable.  The  very  nature  of  the  condition  inquiry  leads  to  less  varia- \nbility  in  the  individual  observations.  Normal  yields  may  vary  con- \nsiderably  from one  area to  another,  even  within  a county.  A  condition \nof  50  per  cent  would  mean  a  yield  of  20  bushels  of  corn  in  one  area \nand perhaps 25 or 30 bushels in another.  In fact,  the greatest  variability \nordinarily  shown  by  a  condition  sample  is  about  equal  to  the  smallest \nvariability  found  with  judgment  yield  sample  data  (the  reports  on \nyield).  The  most  variable  yield  samples  seldom  exceed  the  variability \nof  the  least  variable  samples  of  individual  farms  on  acreage  or  live- \nstock  numbers. \n'>
# <LTTextBoxHorizontal(4) 38.880,243.670,356.100,374.270 'A  forecast  of  yield  per  acre  is  made  on  the  basis  of  the  statistical \nrelationship  between  the  reported  condition  for  a  given  date  and  the \nfinal  yield  per  acre  shown  for  a  period  of  15 or  more  past  years.  The \nrelationship  between  November  1  condition  and  final  yield  per  acre \nfor  cotton  for  the  period  from  1922  to  1936  for  the  United  States  is \nshown  in  Figure  1. The  average  relationship  in  this  case is  best  meas- \nured by a straight  line,  called a regression line. If the  currently reported \ncondition  is,  say,  60 per  cent,  then  a forecast  of  a yield  of  172 pounds \nper  acre is  indicated  by  the  regression  line.  The  years  1937  and  1938 \ndo  not  fit  in  with  the  relationship  shown  for  the  previous  years.  This \ninteresting  point  will  be  considered  a  little  later. \n'>
# <LTTextBoxHorizontal(5) 39.480,123.370,356.420,242.270 "One of the  fundamental  difficulties in using the  reported condition  of \nthe  crop as  a basis  of  forecasting  yield  lies  in  the  subjective  nature  of \nthe  mass  judgment  of  a  large  number  of  crop  re- \nthe  sample  data \nporters.  There  are times  when  one or more serious insect  pests  or plant \ndiseases  are present  in  a crop but  are not  sufficiently  in  evidence  to  be \nreadily recognized  by anyone  not  well trained in entomology  and plant \npathology.  Stem  rust  in  wheat  is  a  good  example  of  a  disease  that  is \nnot  readily  recognized  in  its  early  stages  of  infestation.  Under  such \ncondition,  the  crop  reporters'  estimates  of  condition  are  likely  to  be \nentirely  too  high  in  terms  of  the  final  yield  of  the  crop. \n">
# <LTTextBoxHorizontal(6) 39.600,63.370,356.130,122.150 'One way  to  meet  this  difficulty  is  to  have  crop  estimators,  trained \nin  the  identification  of insect  pests  and plant  diseases  and  experienced \nin  estimating  damage  to  yields  resulting  therefrom,  make  frequent \nfield inspections  of the  growing  crop in important  commercial  produc- \ning  areas. \n'>
# <LTTextBoxHorizontal(7) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 40.560,592.030,53.060,602.030 '56 \n'>
# <LTTextBoxHorizontal(1) 157.800,591.841,236.168,598.961 'CHARLES  F.  SARLE \n'>
# ...
# <LTTextBoxHorizontal(4) 35.460,352.450,351.440,446.630 'For  about  10 years,  during August  and September,  the  Department \nof  Agriculture  has  been  making  boll  counts  and  measurements  on \ncotton  in  commercial  fields along  several  thousand  miles  of routes  laid \nout  through  the  Cotton  Belt.  For  the  last  2  or  3 years,  field  observa- \ntions  have  been  made  on  corn  in  the  major  Corn  Belt  States  during \nSeptember.  The  results  obtained  suggest  the  feasibility  of  developing \nobjective  methods  of forecasting the  yield  of  these  two  crops based  on \nactual  field  observation. \n'>
# <LTTextBoxHorizontal(5) 35.760,184.210,351.460,350.750 'In  a number of states,  studies  have  been made of the  relationship  of \nweather  factors  to  the  yield  per acre of various  crops using  averages  of \nweather  data  and  yields  for  the  entire  state.  Although  some  of  these \nstudies  have  shown a high relationship  for the period of years  covered, \nthe  forecasting  formulas  developed  have  not  proved  very  satisfactory \nwhen actually  used for forecasting  in seasons not included  in the  study. \nDuring  the  last  2  years,  research  of  a  more  intensive  nature  has \nbeen  undertaken  using  weather  and  yield  data  from  the  agricultural \nexperiment  stations.  Moreover,  special  field-plot  experiments  designed \nfor the  purpose  of  studying  the  effect  of  weather  and  soil  moisture  on \ngrowth  and  yield  of  wheat,  corn,  and  cotton  have  been  started-one \non  winter  wheat  at  Manhattan,  Kansas,  one  on  corn  at  Ames,  Iowa, \nand another  on cotton  at  Florence,  South  Carolina.  Methods  are being \ndeveloped  for doing  this  type  of  crop-weather  research \n'>
# <LTTextBoxHorizontal(6) 35.880,124.690,352.460,182.630 'Five  or  six  years  of  crop-weather  field  experiments  at  some  6 to  10 \nstations  for a given  crop would form an excellent  basis for ascertaining \nthe  direct  and  indirect  influence  of  weather  on  crop growth  and  yield \nper  acre  and  perhaps  would  make  it  possible  to  develop  objective \nmethods  of  forecasting  yield  per  acre  from  weather. \n'>
# <LTTextBoxHorizontal(7) 35.580,64.390,351.760,122.630 'One  of  the  inherent  difficulties  in  forecasting  the  yield  per  acre  in \nadvance  of  harvest  is  that  the  growing  and  maturing  crop  is  always \nsubject  to  the  hazard  of  damage  either  directly  from  weather  or  in- \ndirectly  from  disease  and insects  which  are, in  turn,  largely  controlled \nby  weather.  On the  other hand,  the  yield  of a  crop with  indeterminate \n'>
# <LTTextBoxHorizontal(8) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 146.640,591.864,241.552,599.984 'OBJECTIVE  SAMPLING \n'>
# <LTTextBoxHorizontal(1) 340.080,591.970,352.580,601.970 '59 \n'>
# <LTTextBoxHorizontal(2) 35.760,555.310,351.770,578.150 'fruiting  habits,  like  cotton,  can  be  greatly  increased  even  late  in  the \nseason  by  unusually  favorable  weather. \n'>
# <LTTextBoxHorizontal(3) 35.880,495.430,353.150,554.270 'The  earlier in  the  growing  season  the  forecast  is  made  the  greater  is \nthe  hazard of  subsequent  weather.  It  is  not  surprising,  therefore,  that \nearly  season  condition  usually  is  not  sufficiently  related  to  final yield \nto justify  its  use in forecasting.  For many  years,  the  condition  of cotton \nwas  obtained  as  of  May  25.  In  Figure  2 it  will  be  seen  that  the  rela- \n'>
# <LTTextBoxHorizontal(4) 65.280,463.404,321.332,471.944 'RELATION  OF  MAY 25  UNITED  STATES  COTTON  CONDITION \n'>
# <LTTextBoxHorizontal(5) 82.320,454.464,295.684,462.944 'TO  FINAL  YIELD  PER  ACRE  FOR  PERIOD  1900-1921 \n'>
# <LTTextBoxHorizontal(6) 42.000,443.918,70.836,449.918 'BIOARDS \n'>
# <LTTextBoxHorizontal(7) 45.240,428.618,65.886,439.958 'FINAL \nYIELD \n'>
# <LTTextBoxHorizontal(8) 60.480,404.415,66.730,409.415 '80 \n'>
# <LTTextBoxHorizontal(9) 54.300,396.213,193.450,407.213 '200~~~~~~~~~~~~~~~~~~~~0 \n'>
# <LTTextBoxHorizontal(10) 48.840,371.221,61.090,378.221 '180 \n'>
# <LTTextBoxHorizontal(11) 48.780,341.521,61.030,348.521 '160 \n'>
# <LTTextBoxHorizontal(12) 48.960,315.158,59.460,321.158 '140 \n'>
# <LTTextBoxHorizontal(13) 110.940,377.715,118.580,382.715 "'20 \n">
# <LTTextBoxHorizontal(14) 205.920,384.352,212.032,388.352 "'13 \n">
# <LTTextBoxHorizontal(15) 85.440,365.558,107.604,371.618 'Par_ li_ e \n'>
# <LTTextBoxHorizontal(16) 80.640,360.158,99.810,366.158 'Simple \n'>
# <LTTextBoxHorizontal(17) 75.960,353.581,115.762,360.581 "regression'~. \n">
# <LTTextBoxHorizontal(53) 41.040,264.292,117.280,268.652 'U  S.  DEPARTMENT Of  AGRICULTURE \n'>
# <LTTextBoxHorizontal(54) 233.760,264.832,255.680,268.892 'NEG. 35350 \n'>
# <LTTextBoxHorizontal(55) 263.340,264.892,347.892,269.012 'BUREAU  OF  AGRICULTURAL ECONOMICS \n'>
# <LTTextBoxHorizontal(56) 182.760,247.635,211.410,253.595 'VleuRrm  2 \n'>
# <LTTextBoxHorizontal(57) 37.320,147.190,354.660,230.150 'to  be \ntionship  of  condition  with  final  yield  was  too  low  (r=0.38) \nstatistically  significant  and that  condition  at that  time  would  be value- \nless in  forecasting  yield.  The  dotted  line  on this  chart is the  regression \nline when the  change in condition  from May  25 to October is taken  into \nconsideration.  The  dashed  line is the  "par" line formerly  used in inter- \npreting  condition.  No  condition  data  are  now  obtained  nor  are  fore- \ncasts  made  of  the  cotton  yield  per acre before August  1. \n'>
# <LTTextBoxHorizontal(58) 38.400,87.190,354.820,146.270 'If  accurate  forecasts  of  yield  per  acre  are  to  be  made  early  in  the \ngrowing  season,  it  will  be  necessary:  (l)  to  know  the  relationship \nbetween  weather  and  yield  per  acre,  and  (2)  to  know  how  to  forecast \nthe  weather,  or at  least  the  extremes  of weather,  for several  months  in \nadvance. \n'>
# <LTTextBoxHorizontal(59) 39.120,63.070,354.180,86.270 'A  research  program  in  meteorology  that  has  practically  doubled \nthe  scanty  knowledge  in  this  field has  been  under  way  during  the  last \n'>
# <LTTextBoxHorizontal(60) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTTextBoxHorizontal(61) 271.740,303.578,391.422,335.798 'Equation of simple \n~~~~~~~~~~~~~~~~regression \nY  94.12 +1.125X \nr=.38  Syx=20.1 \n'>
# <LTTextBoxHorizontal(62) 306.120,321.578,316.956,327.578 'line \n'>
# <LTTextBoxHorizontal(63) 276.960,284.521,285.710,291.521 '90 \n'>
# <LTTextBoxHorizontal(64) 306.180,284.521,314.930,291.521 '95 \n'>
# <LTTextBoxHorizontal(65) 334.260,284.701,346.510,291.701 '100 \n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 43.680,588.670,56.180,598.670 '60 \n'>
# <LTTextBoxHorizontal(1) 160.680,589.321,239.168,596.321 'CHARLES  F.  SARLE \n'>
# <LTTextBoxHorizontal(2) 43.440,546.850,353.120,569.030 '2  years.  It  will  take  time  and  a great  deal  of investigation  to  develo \ndependable  methods  of  long-range  weather  forecasting. \n'>
# <LTTextBoxHorizontal(3) 139.320,525.421,254.772,532.421 'CONCLUDING  OBSERVATIONS \n'>
# <LTTextBoxHorizontal(4) 43.080,448.930,353.990,518.990 'The  ever-increasing  demand  for  more  and  better  statistics  relatin \nto  agriculture  in its  many  phases  can be met  by  the  two  governmentf \nagencies  responsible  for  these  statistics  (the  Agricultural  Marketin \nService  of the  U.  S.  Department  of Agriculture  and the  Bureau  of th \nCensus  of  the  Department  of  Commerce)  by  the  development  an \npractical  use  of  objective  methods  of  sampling  and  estimation. \n'>
# <LTTextBoxHorizontal(5) 53.520,436.930,353.340,446.930 'Three  specific  suggestions  for  using  objective  sampling  methods  i \n'>
# <LTTextBoxHorizontal(6) 42.840,412.990,348.160,434.990 'strengthening  agricultural  statistics  were  made  by  the  writer  in \nprevious  paper,1 as follows: \n'>
# <LTTextBoxHorizontal(7) 53.640,401.170,352.910,411.170 '(1)  Use a split schedule in Census enumerations  to broaden the scor \n'>
# <LTTextBoxHorizontal(8) 42.600,388.990,306.090,399.110 'of  basic  agricultural  statistics  by  from  50  to  200  per  cent. \n'>
# <LTTextBoxHorizontal(9) 42.120,340.990,351.250,387.110 '(2)  Take  a rotating partial  census in intercensal  years  in  commerci \nfruit  and  truck  areas  to  obtain  more  reliable  and  more  useful  bas \nstatistics  regarding these  specialty  crops than  is possible  in  connectic \nwith  a general  enumeration. \n'>
# <LTTextBoxHorizontal(10) 42.480,304.870,353.420,338.990 '(3)  Take  a  nation-wide  annual  enumerative  sample  of  individu~ \nfarms  covering  crop  acreages  and  production,  livestock  numbers  an \nproduction,  etc. \n'>
# <LTTextBoxHorizontal(11) 52.740,292.990,352.600,303.110 'The  need for these  improved  methods  has been developed  more ful] \n'>
# <LTTextBoxHorizontal(12) 42.060,245.110,350.560,291.110 'in  the  present  paper,  in  which  a  critical  description  has  been  given, \nsome  of the  more important  methods  of  sampling  and  estimating  no \nused  by  the  U.  S. Department  of Agriculture  and of some of the  resul \nobtained  in  developing  more objective  sampling  methods. \n'>
# <LTTextBoxHorizontal(13) 41.640,161.170,352.410,243.710 'In  looking  into  the  future  it  is  not  difficult  to  visualize  a  return  i \nthe  county  statistical  reporter as the  source of much of the  sample dal \non  which  estimates  concerning  agriculture  would  be  based.  He  wou: \nnot  be  asked  to  render  his  service  free  of  charge.  He  would  be  giv( \npart-time  employment  and  would  lose  his  job  if  he  failed  to  ma] \nthe  required  reports  regularly  and  well.  Very  little  of  the  data  I \nwould  submit  would  be  based  on  his  judgment  or  opinion  alone. \n'>
# <LTTextBoxHorizontal(14) 41.280,89.230,353.610,159.350 'Once or twice  a year  he would  take  an  enumerative  sample  of inc \nobjectively  designed  sample  of  repr \nvidual  farms  in  his  county-an \nsentative  farms.  He  would  obtain  information  concerning  these  farin \nas  operating  units-crop \nacreages,  production,  and  sales;  numbei \nproduction,  and sales of livestock.  Each month  he would have various \ntaking  of  head  samples  of  wheat  in  one  mont \nassigned  duties-the \n'>
# <LTTextBoxHorizontal(15) 54.060,70.907,350.391,80.147 '1 "Development  of Partial  and  Sample Census  Methods,"  Proceedings of I \n'>
# <LTTextBoxHorizontal(16) 41.280,61.007,254.700,70.187 'Farm Economic Association Meeting, December,  1938. \n'>
# <LTTextBoxHorizontal(17) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# <LTTextBoxHorizontal(0) 149.160,590.521,238.253,597.641 'OBJECTIVE  SAMPLING \n'>
# <LTTextBoxHorizontal(1) 342.600,589.450,355.100,599.450 '61 \n'>
# <LTTextBoxHorizontal(2) 38.160,517.810,354.580,576.230 'cotton-boll  counts or ear counts for corn in another month,  and perhaps \ndepth  of soil moisture  another  month.  Each  month  he would  report on \nprices  received  and  paid  by  farmers,  numbers  of  persons  employed, \nand  perhaps  rate  of  egg  and  milk  production,  as  well,  on  sample \nfarms  within  the  county. \n'>
# <LTTextBoxHorizontal(3) 37.860,469.810,354.580,516.350 'He  also  might  obtain  a  record  of  purchases  of  farm  products  by \nlocal  buyers  and  processors  and  shipments  out  of  the  county  by  rail \nand  truck  of  agricultural  products  to  be  used  with  other  data  in \nestimating  farm  income  by  counties. \n'>
# <LTTextBoxHorizontal(4) 37.560,421.750,353.700,468.350 'Such  a  program  would  be  more  expensive  than  the  present  system \nof voluntary  unpaid  correspondents,  but  the  resulting  statistics  would \nbe worth  many  times  the  increased  cost  in  the  more  efficient  adminis- \ntration  of  state  and  Federal  action  programs  alone. \n'>
# <LTTextBoxHorizontal(5) 49.320,403.870,227.810,414.470 'United States Department of Agriculture \n'>
# <LTTextBoxHorizontal(6) 107.390,6.733,282.485,17.213 'This content downloaded from 128.235.251.160 on Thu, 15 Jan 2015 07:49:50 AM\nAll use subject to JSTOR Terms and Conditions\n'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>

# %%
for page_layout in extract_pages(filepath):
    for element in page_layout:
        print(element)
        if isinstance(element, LTTextContainer):
            for text_line in element:
                print(text_line)
                for character in text_line:
                    if isinstance(character, LTChar):
                        print(character.fontname)
                        print(character.size)
                        print(character)
# Out:
# <LTTextBoxHorizontal(0) 50.000,621.788,514.684,713.788 'The Possibilities and Limitations of Objective Sampling in Strengthening Agricultural\nStatistics\nAuthor(s): Charles F. Sarle\nSource: Econometrica, Vol. 8, No. 1 (Jan., 1940), pp. 45-61\nPublished by: The Econometric Society\nStable URL: http://www.jstor.org/stable/1906861 .\nAccessed: 15/01/2015 07:49\n'>
# <LTTextLineHorizontal 50.000,702.788,514.684,713.788 'The Possibilities and Limitations of Objective Sampling in Strengthening Agricultural\n'>
# TPZMNE+Code2000
# 11.0
# <LTChar 50.000,702.788,56.952,713.788 matrix=[1.00,0.00,0.00,1.00, (50.00,706.00)] font='TPZMNE+Code2000' adv=6.952 text='T'>
# TPZMNE+Code2000
# 11.0
# <LTChar 56.952,702.788,64.102,713.788 matrix=[1.00,0.00,0.00,1.00, (56.95,706.00)] font='TPZMNE+Code2000' adv=7.15 text='h'>
# TPZMNE+Code2000
# 11.0
# <LTChar 64.102,702.788,69.338,713.788 matrix=[1.00,0.00,0.00,1.00, (64.10,706.00)] font='TPZMNE+Code2000' adv=5.236000000000001 text='e'>
# TPZMNE+Code2000
# 11.0
# <LTChar 69.338,702.788,73.628,713.788 matrix=[1.00,0.00,0.00,1.00, (69.34,706.00)] font='TPZMNE+Code2000' adv=4.29 text=' '>
# TPZMNE+Code2000
# 11.0
# <LTChar 73.628,702.788,80.129,713.788 matrix=[1.00,0.00,0.00,1.00, (73.63,706.00)] font='TPZMNE+Code2000' adv=6.5009999999999994 text='P'>
# TPZMNE+Code2000
# 11.0
# <LTChar 80.129,702.788,85.882,713.788 matrix=[1.00,0.00,0.00,1.00, (80.13,706.00)] font='TPZMNE+Code2000' adv=5.753 text='o'>
# TPZMNE+Code2000
# 11.0
# <LTChar 85.882,702.788,90.689,713.788 matrix=[1.00,0.00,0.00,1.00, (85.88,706.00)] font='TPZMNE+Code2000' adv=4.807 text='s'>
# TPZMNE+Code2000
# 11.0
# <LTChar 90.689,702.788,95.496,713.788 matrix=[1.00,0.00,0.00,1.00, (90.69,706.00)] font='TPZMNE+Code2000' adv=4.807 text='s'>
# TPZMNE+Code2000
# 11.0
# <LTChar 95.496,702.788,99.181,713.788 matrix=[1.00,0.00,0.00,1.00, (95.50,706.00)] font='TPZMNE+Code2000' adv=3.685 text='i'>
# TPZMNE+Code2000
# 11.0
# <LTChar 99.181,702.788,105.704,713.788 matrix=[1.00,0.00,0.00,1.00, (99.18,706.00)] font='TPZMNE+Code2000' adv=6.523 text='b'>
# TPZMNE+Code2000
# 11.0
# <LTChar 105.704,702.788,109.389,713.788 matrix=[1.00,0.00,0.00,1.00, (105.70,706.00)] font='TPZMNE+Code2000' adv=3.685 text='i'>
# TPZMNE+Code2000
# 11.0
# <LTChar
# <LTChar 138.962,651.080,143.722,661.080 matrix=[1.00,0.00,0.00,1.00, (138.96,654.00)] font='TPZMNE+Code2000' adv=4.760000000000001 text='e'>
# TPZMNE+Code2000
# 10.0
# <LTChar 143.722,651.080,147.622,661.080 matrix=[1.00,0.00,0.00,1.00, (143.72,654.00)] font='TPZMNE+Code2000' adv=3.9000000000000004 text=' '>
# TPZMNE+Code2000
# 10.0
# <LTChar 147.622,651.080,153.472,661.080 matrix=[1.00,0.00,0.00,1.00, (147.62,654.00)] font='TPZMNE+Code2000' adv=5.85 text='E'>
# TPZMNE+Code2000
# 10.0
# <LTChar 153.472,651.080,158.312,661.080 matrix=[1.00,0.00,0.00,1.00, (153.47,654.00)] font='TPZMNE+Code2000' adv=4.84 text='c'>
# TPZMNE+Code2000
# 10.0
# <LTChar 158.312,651.080,163.542,661.080 matrix=[1.00,0.00,0.00,1.00, (158.31,654.00)] font='TPZMNE+Code2000' adv=5.23 text='o'>
# TPZMNE+Code2000
# 10.0
# <LTChar 163.542,651.080,170.042,661.080 matrix=[1.00,0.00,0.00,1.00, (163.54,654.00)] font='TPZMNE+Code2000' adv=6.5 text='n'>
# TPZMNE+Code2000
# 10.0
# <LTChar 170.042,651.080,175.272,661.080 matrix=[1.00,0.00,0.00,1.00, (170.04,654.00)] font='TPZMNE+Code2000' adv=5.23 text='o'>
# TPZMNE+Code2000
# 10.0
# <LTChar 175.272,651.080,184.912,661.080 matrix=[1.00,0.00,0.00,1.00, (175.27,654.00)] font='TPZMNE+Code2000' adv=9.64 text='m'>
# TPZMNE+Code2000
# 10.0
# <LTChar 184.912,651.080,189.672,661.080 matrix=[1.00,0.00,0.00,1.00, (184.91,654.00)] font='TPZMNE+Code2000' adv=4.760000000000001 text='e'>
# TPZMNE+Code2000
# 10.0
# <LTChar 189.672,651.080,194.452,661.080 matrix=[1.00,0.00,0.00,1.00, (189.67,654.00)] font='TPZMNE+Code2000' adv=4.78 text='t'>
# TPZMNE+Code2000
# 10.0
# <LTChar 194.452,651.080,199.912,661.080 matrix=[1.00,0.00,0.00,1.00, (194.45,654.00)] font='TPZMNE+Code2000' adv=5.460000000000001 text='r'>
# TPZMNE+Code2000
# 10.0
# <LTChar 199.912,651.080,203.262,661.080 matrix=[1.00,0.00,0.00,1.00, (199.91,654.00)] font='TPZMNE+Code2000' adv=3.35 text='i'>
# TPZMNE+Code2000
# 10.0
# <LTChar 203.262,651.080,208.102,661.080 matrix=[1.00,0.00,0.00,1.00, (203.26,654.00)] font='TPZMNE+Code2000' adv=4.84 text='c'>
# TPZMNE+Code2000
# 10.0
# <LTChar 208.102,651.080,212.002,661.080 matrix=[1.00,0.00,0.00,1.00, (208.10,654.00)] font='TPZMNE+Code2000' adv=3.9000000000000004 text=' '>
# TPZMNE+Code2000
# 10.0
# <LTChar 212.002,651.080,217.132,661.080 matrix=[1.00,0.00,0.00,1.00, (212.00,654.00)] font='TPZMNE+Code2000' adv=5.13 text='S'>
# TPZMNE+Code2000
# 10.0
00)] font='TPZMNE+Code2000' adv=4.29 text=' '>
# Times-Roman
# 11.0
# <LTChar 115.274,638.613,120.774,649.613 matrix=[1.00,0.00,0.00,1.00, (115.27,641.00)] font='Times-Roman' adv=5.5 text='h'>
# Times-Roman
# 11.0
# <LTChar 120.774,638.613,123.832,649.613 matrix=[1.00,0.00,0.00,1.00, (120.77,641.00)] font='Times-Roman' adv=3.0580000000000003 text='t'>
# Times-Roman
# 11.0
# <LTChar 123.832,638.613,126.890,649.613 matrix=[1.00,0.00,0.00,1.00, (123.83,641.00)] font='Times-Roman' adv=3.0580000000000003 text='t'>
# Times-Roman
# 11.0
# <LTChar 126.890,638.613,132.390,649.613 matrix=[1.00,0.00,0.00,1.00, (126.89,641.00)] font='Times-Roman' adv=5.5 text='p'>
# Times-Roman
# 11.0
# <LTChar 132.390,638.613,135.448,649.613 matrix=[1.00,0.00,0.00,1.00, (132.39,641.00)] font='Times-Roman' adv=3.0580000000000003 text=':'>
# Times-Roman
# 11.0
# <LTChar 135.448,638.613,138.506,649.613 matrix=[1.00,0.00,0.00,1.00, (135.45,641.00)] font='Times-Roman' adv=3.0580000000000003 text='/'>
# Times-Roman
# 11.0
# <LTChar 138.506,638.613,141.564,649.613 matrix=[1.00,0.00,0.00,1.00, (138.51,641.00)] font='Times-Roman' adv=3.0580000000000003 text='/'>
# Times-Roman
# 11.0
# <LTChar 141.564,638.613,149.506,649.613 matrix=[1.00,0.00,0.00,1.00, (141.56,641.00)] font='Times-Roman' adv=7.942 text='w'>
# Times-Roman
# 11.0
# <LTChar 149.506,638.613,157.448,649.613 matrix=[1.00,0.00,0.00,1.00, (149.51,641.00)] font='Times-Roman' adv=7.942 text='w'>
# Times-Roman
# 11.0
# <LTChar 157.448,638.613,165.390,649.613 matrix=[1.00,0.00,0.00,1.00, (157.45,641.00)] font='Times-Roman' adv=7.942 text='w'>
# Times-Roman
# 11.0
# <LTChar 165.390,638.613,168.140,649.613 matrix=[1.00,0.00,0.00,1.00, (165.39,641.00)] font='Times-Roman' adv=2.75 text='.'>
# Times-Roman
# 11.0
# <LTChar 168.140,638.613,171.198,649.613 matrix=[1.00,0.00,0.00,1.00, (168.14,641.00)] font='Times-Roman' adv=3.0580000000000003 text='j'>
# Times-Roman
# 11.0
# <LTChar 171.198,638.613,175.477,649.613 matrix=[1.00,0.00,0.00,1.00, (171.20,641.00)] font='Times-Roman' adv=4.279 text='s'>
# Times-Roman
# 11.0
# <LTChar 175.477,638.613,178.535,649.613 matrix=[1.00,0.00,0.00,1.00, (175.48,641.00)] font='Times-Roman' adv=3.0580000000000003 text='t'>
# Times-Roman
# 11.0
# <LTChar 178.535,638.613,184.035,649.613 matrix=[1.00,0.00,0.00,1.00, (178.54,641.00)] font='Times-Roman' adv=5.5 text='o'>
# Times-Roman
# 11.0
# <LTChar 184.035,638.613,187.698,649.613 matrix=[1.00,0.00,0.00,1.00, (184.04,641.00)] font='Times-Roman' adv=3.6630000000000003 text='r'>
# Times-Roman
# 11.0
# <LTChar 187.698,638.613,190.448,649.613 matrix=[1.00,0.00,0.00,1.00, (187.70,641.00)] font='Times-Roman' adv=2.75 text='.'>
# Times-Roman
# 11.0
# <LTChar 190.448,638.613,195.948,649.613 matrix=[1.00,0.00,0.00,1.00, (190.45,641.00)] font='Times-Roman' adv=5.5 text='o'>
# Times-Roman
# 11.0
# <LTChar 195.948,638.613,199.611,649.613 matrix=[1.00,0.00,0.00,1.00, (195.95,641.00)] font='Times-Roman' adv=3.6630000000000003 text='r'>
# Times-Roman
# 11.0
# <LTChar 199.611,638.613,205.111,649.613 matrix=[1.00,0.00,0.00,1.00, (199.61,641.00)] font='Times-Roman' adv=5.5 text='g'>
# Times-Roman
# 11.0
# <LTChar 205.111,638.613,208.169,649.613 matrix=[1.00,0.00,0.00,1.00, (205.11,641.00)] font='Times-Roman' adv=3.0580000000000003 text='/'>
# Times-Roman
# 11.0
# <LTChar 208.169,638.613,212.448,649.613 matrix=[1.00,0.00,0.00,1.00, (208.17,641.00)] font='Times-Roman' adv=4.279 text='s'>
# Times-Roman
# 11.0
# <LTChar 212.448,638.613,215.506,649.613 matrix=[1.00,0.00,0.00,1.00, (212.45,641.00)] font='Times-Roman' adv=3.0580000000000003 text='t'>
# Times-Roman
# 11.0
# <LTChar 215.506,638.613,220.390,649.613 matrix=[1.00,0.00,0.00,1.00, (215.51,641.00)] font='Times-Roman' adv=4.884 text='a'>
# Times-Roman
# 11.0
# <LTChar 220.390,638.613,225.890,649.613 matrix=[1.00,0.00,0.00,1.00, (220.39,641.00)] font='Times-Roman' adv=5.5 text='b'>
# Times-Roman
# 11.0
# <LTChar 225.890,638.613,228.948,649.613 matrix=[1.00,0.00,0.00,1.00, (225.89,641.00)] font='Times-Roman' adv=3.0580000000000003 text='l'>
# Times-Roman
# 11.0
# <LTChar 228.948,638.613,233.832,649.613 matrix=[1.00,0.00,0.00,1.00, (228.95,641.00)] font='Times-Roman' adv=4.884 text='e'>
# Times-Roman
# 11.0
# <LTChar 233.832,638.613,236.890,649.613 matrix=[1.00,0.00,0.00,1.00, (233.83,641.00)] font='Times-Roman' adv=3.0580000000000003 text='/'>
# Times-Roman
# 11.0
# <LTChar 236.890,638.613,242.390,649.613 matrix=[1.00,0.00,0.00,1.00, (236.89,641.00)] font='Times-Roman' adv=5.5 text='1'>
# Times-Roman
# 11.0
# <LTChar 242.390,638.613,247.890,649.613 matrix=[1.00,0.00,0.00,1.00, (242.39,641.00)] font='Times-Roman' adv=5.5 text='9'>
# Times-Roman
# 11.0
# <LTChar 247.890,638.613,253.390,649.613 matrix=[1.00,0.00,0.00,1.00, (247.89,641.00)] font='Times-Roman' adv=5.5 text='0'>
# Times-Roman
# 11.0
# <LTChar 253.390,638.613,258.890,649.613 matrix=[1.00,0.00,0.00,1.00, (253.39,641.00)] font='Times-Roman' adv=5.5 text='6'>
# Times-Roman
# 11.0
# <LTChar 258.890,638.613,264.390,649.613 matrix=[1.00,0.00,0.00,1.00, (258.89,641.00)] font='Times-Roman' adv=5.5 text='8'>
# Times-Roman
# 11.0
# <LTChar 264.390,638.613,269.890,649.613 matrix=[1.00,0.00,0.00,1.00, (264.39,641.00)] font='Times-Roman' adv=5.5 text='6'>
# Times-Roman
# 11.0
# <LTChar 269.890,638.613,275.390,649.613 matrix=[1.00,0.00,0.00,1.00, (269.89,641.00)] font='Times-Roman' adv=5.5 text='1'>
# Times-Roman
# 11.0
# <LTChar 275.390,638.613,278.140,649.613 matrix=[1.00,0.00,0.00,1.00, (275.39,641.00)] font='Times-Roman' adv=2.75 text=' '>
# Times-Roman
# 11.0
# <LTChar 278.140,638.613,280.890,649.613 matrix=[1.00,0.00,0.00,1.00, (278.14,641.00)] font='Times-Roman' adv=2.75 text='.'>
# <LTTextLineHorizontal 50.000,621.788,194.430,632.788 'Accessed: 15/01/2015 07:49\n'>
# TPZMNE+Code2000
# 11.0
# <LTChar 50.000,621.788,58.349,632.788 matrix=[1.00,0.00,0.00,1.00, (50.00,625.00)] font='TPZMNE+Code2000' adv=8.349 text='A'>
# TPZMNE+Code2000
# 11.0
# <LTChar 58.349,621.788,63.673,632.788 matrix=[1.00,0.00,0.00,1.00, (58.35,625.00)] font='TPZMNE+Code2000' adv=5.324 text='c'>
# TPZMNE+Code2000
# 11.0
# <LTChar 63.673,621.788,68.997,632.788 matrix=[1.00,0.00,0.00,1.00, (63.67,625.00)] font='TPZMNE+Code2000' adv=5.324 text='c'>
# TPZMNE+Code2000
# 11.0
# <LTChar 68.997,621.788,74.233,632.788 matrix=[1.00,0.00,0.00,1.00, (69.00,625.00)] font='TPZMNE+Code2000' adv=5.236000000000001 text='e'>
# TPZMNE+Code2000
# 11.0
# <LTChar 74.233,621.788,79.040,632.788 matrix=[1.00,0.00,0.00,1.00, (74.23,625.00)] font='TPZMNE+Code2000' adv=4.807 text='s'>
# TPZMNE+Code2000
# 11.0
# <LTChar 79.040,621.788,83.847,632.788 matrix=[1.00,0.00,0.00,1.00, (79.04,625.00)] font='TPZMNE+Code2000' adv=4.807 text='s'>
# TPZMNE+Code2000
# 11.0
# <LTChar 83.847,621.788,89.083,632.788 matrix=[1.00,0.00,0.00,1.00, (83.85,625.00)] font='TPZMNE+Code2000' adv=5.236000000000001 text='e'>
# TPZMNE+Code2000
# 11.0
# <LTChar 89.083,621.788,95.606,632.788 matrix=[1.00,0.00,0.00,1.00, (89.08,625.00)] font='TPZMNE+Code2000' adv=6.523 text='d'>
# TPZMNE+Code2000
# 11.0
# <LTChar 95.606,621.788,98.653,632.788 matrix=[1.00,0.00,0.00,1.00, (95.61,625.00)] font='TPZMNE+Code2000' adv=3.047 text=':'>
# TPZMNE+Code2000
# 11.0
# <LTChar 98.653,621.788,102.943,632.788 matrix=[1.00,0.00,0.00,1.00, (98.65,625.00)] font='TPZMNE+Code2000' adv=4.29 text=' '>
# TPZMNE+Code2000
# 11.0
# <LTChar
# <LTTextLineHorizontal 50.000,590.613,476.530,601.613 'Your use of the JSTOR archive indicates your acceptance of the Terms & Conditions of Use, available at .\n'>
# Times-Roman
# 10.0
# <LTChar 50.000,590.830,57.220,600.830 matrix=[1.00,0.00,0.00,1.00, (50.00,593.00)] font='Times-Roman' adv=7.22 text='Y'>
# Times-Roman
# 10.0
# <LTChar 57.220,590.830,62.220,600.830 matrix=[1.00,0.00,0.00,1.00, (57.22,593.00)] font='Times-Roman' adv=5.0 text='o'>
# Times-Roman
# 10.0
# <LTChar 62.220,590.830,67.220,600.830 matrix=[1.00,0.00,0.00,1.00, (62.22,593.00)] font='Times-Roman' adv=5.0 text='u'>
# Times-Roman
# 10.0
# <LTChar 67.220,590.830,70.550,600.830 matrix=[1.00,0.00,0.00,1.00, (67.22,593.00)] font='Times-Roman' adv=3.33 text='r'>
# Times-Roman
# 10.0
# <LTChar 70.550,590.830,73.050,600.830 matrix=[1.00,0.00,0.00,1.00, (70.55,593.00)] font='Times-Roman' adv=2.5 text=' '>
# Times-Roman
# 10.0
# <LTChar 73.050,590.830,78.050,600.830 matrix=[1.00,0.00,0.00,1.00, (73.05,593.00)] font='Times-Roman' adv=5.0 text='u'>
# Times-Roman
# 10.0
# <LTChar 78.050,590.830,81.940,600.830 matrix=[1.00,0.00,0.00,1.00, (78.05,593.00)] font='Times-Roman' adv=3.89 text='s'>
# Times-Roman
# 10.0
# <LTChar 81.940,590.830,86.380,600.830 matrix=[1.00,0.00,0.00,1.00, (81.94,593.00)] font='Times-Roman' adv=4.44 text='e'>
# Times-Roman
# 10.0
# <LTChar 86.380,590.830,88.880,600.830 matrix=[1.00,0.00,0.00,1.00, (86.38,593.00)] font='Times-Roman' adv=2.5 text=' '>
# Times-Roman
# 10.0
# <LTChar 88.880,590.830,93.880,600.830 matrix=[1.00,0.00,0.00,1.00, (88.88,593.00)] font='Times-Roman' adv=5.0 text='o'>
# Times-Roman
# 10.0
# <LTChar 93.880,590.830,97.210,600.830 matrix=[1.00,0.00,0.00,1.00, (93.88,593.00)] font='Times-Roman' adv=3.33 text='f'>
# Times-Roman
# 10.0
# <LTChar 97.210,590.830,99.710,600.830 matrix=[1.00,0.00,0.00,1.00, (97.21,593.00)] font='Times-Roman' adv=2.5 text=' '>
# Times-Roman
# 10.0
# <LTChar 99.710,590.830,102.490,600.830 matrix=[1.00,0.00,0.00,1.00, (99.71,593.00)] font='Times-Roman' adv=2.7800000000000002 text='t'>
# Times-Roman
# 10.0
# <LTChar 102.490,590.830,107.490,600.830 matrix=[1.00,0.00,0.00,1.00, (102.49,593.00)] font='Times-Roman' adv=5.0 text='h'>
# Times-Roman
# 10.0
# <LTChar 107.490,590.830,111.930,600.830 matrix=[1.00,0.00,0.00,1.00, (107.49,593.00)] font='Times-Roman' adv=4.44 text='e'>
# Times-Roman
# 10.0
# <LTChar 111.930,590.830,114.430,600.830 matrix=[1.00,0.00,0.00,1.00, (111.93,593.00)] font='Times-Roman' adv=2.5 text=' '>
# Times-Roman
# 10.0
# <LTChar 114.430,590.830,118.320,600.830 matrix=[1.00,0.00,0.00,1.00, (114.43,593.00)] font='Times-Roman' adv=3.89 text='J'>
# Times-Roman
# 10.0
# <LTChar 118.320,590.830,123.880,600.830 matrix=[1.00,0.00,0.00,1.00, (118.32,593.00)] font='Times-Roman' adv=5.5600000000000005 text='S'>
# Times-Roman
# 10.0
# ...
# Times-Roman
# 5.239999999999998
# <LTChar 155.420,11.973,157.746,17.213 matrix=[1.00,0.00,0.00,1.00, (155.42,13.11)] font='Times-Roman' adv=2.32656 text='e'>
# Times-Roman
# 5.239999999999998
# <LTChar 157.746,11.973,160.366,17.213 matrix=[1.00,0.00,0.00,1.00, (157.75,13.11)] font='Times-Roman' adv=2.62 text='d'>
# Times-Roman
# 5.239999999999998
# <LTChar 160.366,11.973,161.676,17.213 matrix=[1.00,0.00,0.00,1.00, (160.37,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 161.676,11.973,163.421,17.213 matrix=[1.00,0.00,0.00,1.00, (161.68,13.11)] font='Times-Roman' adv=1.7449200000000002 text='f'>
# Times-Roman
# 5.239999999999998
# <LTChar 163.421,11.973,165.166,17.213 matrix=[1.00,0.00,0.00,1.00, (163.42,13.11)] font='Times-Roman' adv=1.7449200000000002 text='r'>
# Times-Roman
# 5.239999999999998
# <LTChar 165.166,11.973,167.786,17.213 matrix=[1.00,0.00,0.00,1.00, (165.17,13.11)] font='Times-Roman' adv=2.62 text='o'>
# Times-Roman
# 5.239999999999998
# <LTChar 167.786,11.973,171.863,17.213 matrix=[1.00,0.00,0.00,1.00, (167.79,13.11)] font='Times-Roman' adv=4.07672 text='m'>
# Times-Roman
# 5.239999999999998
# <LTChar 171.863,11.973,173.173,17.213 matrix=[1.00,0.00,0.00,1.00, (171.86,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 173.173,11.973,175.793,17.213 matrix=[1.00,0.00,0.00,1.00, (173.17,13.11)] font='Times-Roman' adv=2.62 text='1'>
# Times-Roman
# 5.239999999999998
# <LTChar 175.793,11.973,178.413,17.213 matrix=[1.00,0.00,0.00,1.00, (175.79,13.11)] font='Times-Roman' adv=2.62 text='2'>
# Times-Roman
# 5.239999999999998
# <LTChar 178.413,11.973,181.033,17.213 matrix=[1.00,0.00,0.00,1.00, (178.41,13.11)] font='Times-Roman' adv=2.62 text='8'>
# Times-Roman
# 5.239999999999998
# <LTChar 181.033,11.973,182.343,17.213 matrix=[1.00,0.00,0.00,1.00, (181.03,13.11)] font='Times-Roman' adv=1.31 text='.'>
# Times-Roman
# 5.239999999999998
# <LTChar 182.343,11.973,184.963,17.213 matrix=[1.00,0.00,0.00,1.00, (182.34,13.11)] font='Times-Roman' adv=2.62 text='2'>
# Times-Roman
# 5.239999999999998
# <LTChar 184.963,11.973,187.583,17.213 matrix=[1.00,0.00,0.00,1.00, (184.96,13.11)] font='Times-Roman' adv=2.62 text='3'>
# Times-Roman
# 5.239999999999998
# <LTChar 187.583,11.973,190.203,17.213 matrix=[1.00,0.00,0.00,1.00, (187.58,13.11)] font='Times-Roman' adv=2.62 text='5'>
# Times-Roman
# 5.239999999999998
# <LTChar 190.203,11.973,191.513,17.213 matrix=[1.00,0.00,0.00,1.00, (190.20,13.11)] font='Times-Roman' adv=1.31 text='.'>
# Times-Roman
# 5.239999999999998
# <LTChar 191.513,11.973,194.133,17.213 matrix=[1.00,0.00,0.00,1.00, (191.51,13.11)] font='Times-Roman' adv=2.62 text='2'>
# Times-Roman
# 5.239999999999998
# <LTChar 194.133,11.973,196.753,17.213 matrix=[1.00,0.00,0.00,1.00, (194.13,13.11)] font='Times-Roman' adv=2.62 text='5'>
# Times-Roman
# 5.239999999999998
# <LTChar 196.753,11.973,199.373,17.213 matrix=[1.00,0.00,0.00,1.00, (196.75,13.11)] font='Times-Roman' adv=2.62 text='1'>
# Times-Roman
# 5.239999999999998
# <LTChar 199.373,11.973,200.683,17.213 matrix=[1.00,0.00,0.00,1.00, (199.37,13.11)] font='Times-Roman' adv=1.31 text='.'>
# Times-Roman
# 5.239999999999998
# <LTChar 200.683,11.973,203.303,17.213 matrix=[1.00,0.00,0.00,1.00, (200.68,13.11)] font='Times-Roman' adv=2.62 text='1'>
# Times-Roman
# 5.239999999999998
# <LTChar 203.303,11.973,205.923,17.213 matrix=[1.00,0.00,0.00,1.00, (203.30,13.11)] font='Times-Roman' adv=2.62 text='6'>
# Times-Roman
# 5.239999999999998
# <LTChar 205.923,11.973,208.543,17.213 matrix=[1.00,0.00,0.00,1.00, (205.92,13.11)] font='Times-Roman' adv=2.62 text='0'>
# Times-Roman
# 5.239999999999998
# <LTChar 208.543,11.973,209.853,17.213 matrix=[1.00,0.00,0.00,1.00, (208.54,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 209.853,11.973,212.473,17.213 matrix=[1.00,0.00,0.00,1.00, (209.85,13.11)] font='Times-Roman' adv=2.62 text='o'>
# Times-Roman
# 5.239999999999998
# <LTChar 212.473,11.973,215.093,17.213 matrix=[1.00,0.00,0.00,1.00, (212.47,13.11)] font='Times-Roman' adv=2.62 text='n'>
# Times-Roman
# 5.239999999999998
# <LTChar 215.093,11.973,216.403,17.213 matrix=[1.00,0.00,0.00,1.00, (215.09,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 216.403,11.973,219.605,17.213 matrix=[1.00,0.00,0.00,1.00, (216.40,13.11)] font='Times-Roman' adv=3.2016400000000003 text='T'>
# Times-Roman
# 5.239999999999998
# <LTChar 219.605,11.973,222.225,17.213 matrix=[1.00,0.00,0.00,1.00, (219.60,13.11)] font='Times-Roman' adv=2.62 text='h'>
# Times-Roman
# 5.239999999999998
# <LTChar 222.225,11.973,224.845,17.213 matrix=[1.00,0.00,0.00,1.00, (222.22,13.11)] font='Times-Roman' adv=2.62 text='u'>
# Times-Roman
# 5.239999999999998
# <LTChar 224.845,11.973,226.155,17.213 matrix=[1.00,0.00,0.00,1.00, (224.84,13.11)] font='Times-Roman' adv=1.31 text=','>
# Times-Roman
# 5.239999999999998
# <LTChar 226.155,11.973,227.465,17.213 matrix=[1.00,0.00,0.00,1.00, (226.15,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 227.465,11.973,230.085,17.213 matrix=[1.00,0.00,0.00,1.00, (227.46,13.11)] font='Times-Roman' adv=2.62 text='1'>
# Times-Roman
# 5.239999999999998
# <LTChar 230.085,11.973,232.705,17.213 matrix=[1.00,0.00,0.00,1.00, (230.08,13.11)] font='Times-Roman' adv=2.62 text='5'>
# Times-Roman
# 5.239999999999998
# <LTChar 232.705,11.973,234.015,17.213 matrix=[1.00,0.00,0.00,1.00, (232.70,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 234.015,11.973,236.053,17.213 matrix=[1.00,0.00,0.00,1.00, (234.01,13.11)] font='Times-Roman' adv=2.03836 text='J'>
# Times-Roman
# 5.239999999999998
# <LTChar 236.053,11.973,238.380,17.213 matrix=[1.00,0.00,0.00,1.00, (236.05,13.11)] font='Times-Roman' adv=2.32656 text='a'>
# Times-Roman
# 5.239999999999998
# <LTChar 238.380,11.973,241.000,17.213 matrix=[1.00,0.00,0.00,1.00, (238.38,13.11)] font='Times-Roman' adv=2.62 text='n'>
# Times-Roman
# 5.239999999999998
# <LTChar 241.000,11.973,242.310,17.213 matrix=[1.00,0.00,0.00,1.00, (241.00,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 242.310,11.973,244.930,17.213 matrix=[1.00,0.00,0.00,1.00, (242.31,13.11)] font='Times-Roman' adv=2.62 text='2'>
# Times-Roman
# 5.239999999999998
# <LTChar 244.930,11.973,247.550,17.213 matrix=[1.00,0.00,0.00,1.00, (244.93,13.11)] font='Times-Roman' adv=2.62 text='0'>
# Times-Roman
# 5.239999999999998
# <LTChar 247.550,11.973,250.170,17.213 matrix=[1.00,0.00,0.00,1.00, (247.55,13.11)] font='Times-Roman' adv=2.62 text='1'>
# Times-Roman
# 5.239999999999998
# <LTChar 250.170,11.973,252.790,17.213 matrix=[1.00,0.00,0.00,1.00, (250.17,13.11)] font='Times-Roman' adv=2.62 text='5'>
# Times-Roman
# 5.239999999999998
# <LTChar 252.790,11.973,254.100,17.213 matrix=[1.00,0.00,0.00,1.00, (252.79,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 254.100,11.973,256.720,17.213 matrix=[1.00,0.00,0.00,1.00, (254.10,13.11)] font='Times-Roman' adv=2.62 text='0'>
# Times-Roman
# 5.239999999999998
# <LTChar 256.720,11.973,259.340,17.213 matrix=[1.00,0.00,0.00,1.00, (256.72,13.11)] font='Times-Roman' adv=2.62 text='7'>
# Times-Roman
# 5.239999999999998
# <LTChar 259.340,11.973,260.796,17.213 matrix=[1.00,0.00,0.00,1.00, (259.34,13.11)] font='Times-Roman' adv=1.4567200000000002 text=':'>
# Times-Roman
# 5.239999999999998
# <LTChar 260.796,11.973,263.416,17.213 matrix=[1.00,0.00,0.00,1.00, (260.80,13.11)] font='Times-Roman' adv=2.62 text='4'>
# Times-Roman
# 5.239999999999998
# <LTChar 263.416,11.973,266.036,17.213 matrix=[1.00,0.00,0.00,1.00, (263.42,13.11)] font='Times-Roman' adv=2.62 text='9'>
# Times-Roman
# 5.239999999999998
# <LTChar 266.036,11.973,267.493,17.213 matrix=[1.00,0.00,0.00,1.00, (266.04,13.11)] font='Times-Roman' adv=1.4567200000000002 text=':'>
# Times-Roman
# 5.239999999999998
# <LTChar 267.493,11.973,270.113,17.213 matrix=[1.00,0.00,0.00,1.00, (267.49,13.11)] font='Times-Roman' adv=2.62 text='5'>
# Times-Roman
# 5.239999999999998
# <LTChar 270.113,11.973,272.733,17.213 matrix=[1.00,0.00,0.00,1.00, (270.11,13.11)] font='Times-Roman' adv=2.62 text='0'>
# Times-Roman
# 5.239999999999998
# <LTChar 272.733,11.973,274.043,17.213 matrix=[1.00,0.00,0.00,1.00, (272.73,13.11)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.239999999999998
# <LTChar 274.043,11.973,277.826,17.213 matrix=[1.00,0.00,0.00,1.00, (274.04,13.11)] font='Times-Roman' adv=3.78328 text='A'>
# Times-Roman
# 5.239999999999998
# <LTChar 277.826,11.973,282.485,17.213 matrix=[1.00,0.00,0.00,1.00, (277.83,13.11)] font='Times-Roman' adv=4.65836 text='M'>
# <LTTextLineHorizontal 144.380,6.733,245.543,11.973 'All use subject to JSTOR Terms and Conditions\n'>
# Times-Roman
# 5.240000000000001
# <LTChar 144.380,6.733,148.163,11.973 matrix=[1.00,0.00,0.00,1.00, (144.38,7.87)] font='Times-Roman' adv=3.78328 text='A'>
# Times-Roman
# 5.240000000000001
# <LTChar 148.163,6.733,149.620,11.973 matrix=[1.00,0.00,0.00,1.00, (148.16,7.87)] font='Times-Roman' adv=1.4567200000000002 text='l'>
# Times-Roman
# 5.240000000000001
# <LTChar 149.620,6.733,151.077,11.973 matrix=[1.00,0.00,0.00,1.00, (149.62,7.87)] font='Times-Roman' adv=1.4567200000000002 text='l'>
# Times-Roman
# 5.240000000000001
# <LTChar 151.077,6.733,152.387,11.973 matrix=[1.00,0.00,0.00,1.00, (151.08,7.87)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.240000000000001
# <LTChar 152.387,6.733,155.007,11.973 matrix=[1.00,0.00,0.00,1.00, (152.39,7.87)] font='Times-Roman' adv=2.62 text='u'>
# Times-Roman
# 5.240000000000001
# <LTChar 155.007,6.733,157.045,11.973 matrix=[1.00,0.00,0.00,1.00, (155.01,7.87)] font='Times-Roman' adv=2.03836 text='s'>
# Times-Roman
# 5.240000000000001
# <LTChar 157.045,6.733,159.372,11.973 matrix=[1.00,0.00,0.00,1.00, (157.05,7.87)] font='Times-Roman' adv=2.32656 text='e'>
# Times-Roman
# 5.240000000000001
# <LTChar 159.372,6.733,160.682,11.973 matrix=[1.00,0.00,0.00,1.00, (159.37,7.87)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.240000000000001
# <LTChar 160.682,6.733,162.720,11.973 matrix=[1.00,0.00,0.00,1.00, (160.68,7.87)] font='Times-Roman' adv=2.03836 text='s'>
# Times-Roman
# 5.240000000000001
# <LTChar 162.720,6.733,165.340,11.973 matrix=[1.00,0.00,0.00,1.00, (162.72,7.87)] font='Times-Roman' adv=2.62 text='u'>
# Times-Roman
# 5.240000000000001
# <LTChar 165.340,6.733,167.960,11.973 matrix=[1.00,0.00,0.00,1.00, (165.34,7.87)] font='Times-Roman' adv=2.62 text='b'>
# Times-Roman
# 5.240000000000001
# <LTChar 167.960,6.733,169.417,11.973 matrix=[1.00,0.00,0.00,1.00, (167.96,7.87)] font='Times-Roman' adv=1.4567200000000002 text='j'>
# Times-Roman
# 5.240000000000001
# <LTChar 169.417,6.733,171.743,11.973 matrix=[1.00,0.00,0.00,1.00, (169.42,7.87)] font='Times-Roman' adv=2.32656 text='e'>
# Times-Roman
# 5.240000000000001
# <LTChar 171.743,6.733,174.070,11.973 matrix=[1.00,0.00,0.00,1.00, (171.74,7.87)] font='Times-Roman' adv=2.32656 text='c'>
# Times-Roman
# 5.240000000000001
# <LTChar 174.070,6.733,175.527,11.973 matrix=[1.00,0.00,0.00,1.00, (174.07,7.87)] font='Times-Roman' adv=1.4567200000000002 text='t'>
# Times-Roman
# 5.240000000000001
# <LTChar 175.527,6.733,176.837,11.973 matrix=[1.00,0.00,0.00,1.00, (175.53,7.87)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.240000000000001
# <LTChar 176.837,6.733,178.293,11.973 matrix=[1.00,0.00,0.00,1.00, (176.84,7.87)] font='Times-Roman' adv=1.4567200000000002 text='t'>
# Times-Roman
# 5.240000000000001
# <LTChar 178.293,6.733,180.913,11.973 matrix=[1.00,0.00,0.00,1.00, (178.29,7.87)] font='Times-Roman' adv=2.62 text='o'>
# Times-Roman
# 5.240000000000001
# <LTChar 180.913,6.733,182.223,11.973 matrix=[1.00,0.00,0.00,1.00, (180.91,7.87)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.240000000000001
# <LTChar 182.223,6.733,184.262,11.973 matrix=[1.00,0.00,0.00,1.00, (182.22,7.87)] font='Times-Roman' adv=2.03836 text='J'>
# Times-Roman
# 5.240000000000001
# <LTChar 184.262,6.733,187.175,11.973 matrix=[1.00,0.00,0.00,1.00, (184.26,7.87)] font='Times-Roman' adv=2.9134400000000005 text='S'>
# Times-Roman
# 5.240000000000001
# <LTChar 187.175,6.733,190.377,11.973 matrix=[1.00,0.00,0.00,1.00, (187.18,7.87)] font='Times-Roman' adv=3.2016400000000003 text='T'>
# Times-Roman
# 5.240000000000001
# <LTChar 190.377,6.733,194.160,11.973 matrix=[1.00,0.00,0.00,1.00, (190.38,7.87)] font='Times-Roman' adv=3.78328 text='O'>
# Times-Roman
# 5.240000000000001
# <LTChar 194.160,6.733,197.655,11.973 matrix=[1.00,0.00,0.00,1.00, (194.16,7.87)] font='Times-Roman' adv=3.49508 text='R'>
# Times-Roman
# 5.240000000000001
# <LTChar 197.655,6.733,198.965,11.973 matrix=[1.00,0.00,0.00,1.00, (197.66,7.87)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.240000000000001
# <LTChar 198.965,6.733,202.167,11.973 matrix=[1.00,0.00,0.00,1.00, (198.97,7.87)] font='Times-Roman' adv=3.2016400000000003 text='T'>
# Times-Roman
# 5.240000000000001
# <LTChar 202.167,6.733,204.493,11.973 matrix=[1.00,0.00,0.00,1.00, (202.17,7.87)] font='Times-Roman' adv=2.32656 text='e'>
# Times-Roman
# 5.240000000000001
# <LTChar 204.493,6.733,206.238,11.973 matrix=[1.00,0.00,0.00,1.00, (204.49,7.87)] font='Times-Roman' adv=1.7449200000000002 text='r'>
# Times-Roman
# 5.240000000000001
# <LTChar 206.238,6.733,210.315,11.973 matrix=[1.00,0.00,0.00,1.00, (206.24,7.87)] font='Times-Roman' adv=4.07672 text='m'>
# Times-Roman
# 5.240000000000001
# <LTChar 210.315,6.733,212.353,11.973 matrix=[1.00,0.00,0.00,1.00, (210.31,7.87)] font='Times-Roman' adv=2.03836 text='s'>
# Times-Roman
# 5.240000000000001
# <LTChar 212.353,6.733,213.663,11.973 matrix=[1.00,0.00,0.00,1.00, (212.35,7.87)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.240000000000001
# <LTChar 213.663,6.733,215.990,11.973 matrix=[1.00,0.00,0.00,1.00, (213.66,7.87)] font='Times-Roman' adv=2.32656 text='a'>
# Times-Roman
# 5.240000000000001
# <LTChar 215.990,6.733,218.610,11.973 matrix=[1.00,0.00,0.00,1.00, (215.99,7.87)] font='Times-Roman' adv=2.62 text='n'>
# Times-Roman
# 5.240000000000001
# <LTChar 218.610,6.733,221.230,11.973 matrix=[1.00,0.00,0.00,1.00, (218.61,7.87)] font='Times-Roman' adv=2.62 text='d'>
# Times-Roman
# 5.240000000000001
# <LTChar 221.230,6.733,222.540,11.973 matrix=[1.00,0.00,0.00,1.00, (221.23,7.87)] font='Times-Roman' adv=1.31 text=' '>
# Times-Roman
# 5.240000000000001
# <LTChar 222.540,6.733,226.035,11.973 matrix=[1.00,0.00,0.00,1.00, (222.54,7.87)] font='Times-Roman' adv=3.49508 text='C'>
# Times-Roman
# 5.240000000000001
# <LTChar 226.035,6.733,228.655,11.973 matrix=[1.00,0.00,0.00,1.00, (226.03,7.87)] font='Times-Roman' adv=2.62 text='o'>
# Times-Roman
# 5.240000000000001
# <LTChar 228.655,6.733,231.275,11.973 matrix=[1.00,0.00,0.00,1.00, (228.65,7.87)] font='Times-Roman' adv=2.62 text='n'>
# Times-Roman
# 5.240000000000001
# <LTChar 231.275,6.733,233.895,11.973 matrix=[1.00,0.00,0.00,1.00, (231.27,7.87)] font='Times-Roman' adv=2.62 text='d'>
# Times-Roman
# 5.240000000000001
# <LTChar 233.895,6.733,235.352,11.973 matrix=[1.00,0.00,0.00,1.00, (233.89,7.87)] font='Times-Roman' adv=1.4567200000000002 text='i'>
# Times-Roman
# 5.240000000000001
# <LTChar 235.352,6.733,236.808,11.973 matrix=[1.00,0.00,0.00,1.00, (235.35,7.87)] font='Times-Roman' adv=1.4567200000000002 text='t'>
# Times-Roman
# 5.240000000000001
# <LTChar 236.808,6.733,238.265,11.973 matrix=[1.00,0.00,0.00,1.00, (236.81,7.87)] font='Times-Roman' adv=1.4567200000000002 text='i'>
# Times-Roman
# 5.240000000000001
# <LTChar 238.265,6.733,240.885,11.973 matrix=[1.00,0.00,0.00,1.00, (238.27,7.87)] font='Times-Roman' adv=2.62 text='o'>
# Times-Roman
# 5.240000000000001
# <LTChar 240.885,6.733,243.505,11.973 matrix=[1.00,0.00,0.00,1.00, (240.89,7.87)] font='Times-Roman' adv=2.62 text='n'>
# Times-Roman
# 5.240000000000001
# <LTChar 243.505,6.733,245.543,11.973 matrix=[1.00,0.00,0.00,1.00, (243.51,7.87)] font='Times-Roman' adv=2.03836 text='s'>
# <LTFigure(Fm0) 0.000,23.600,390.000,635.600 matrix=[1.00,0.00,0.00,1.00, (0.00,23.60)]>
# <LTRect 0.000,0.000,390.000,23.600>
# <LTLine 182.250,6.120,245.620,6.120>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
