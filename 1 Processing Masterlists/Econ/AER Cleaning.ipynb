# %% [markdown]
# # AER Cleaning
#
# This notebook walks through how the AER articles were sorted into categories of articles and non-articles.
#
# ## Load Libraries

# %%
from tokenize import Ignore
from numpy import NaN
import pandas as pd
import time
from os import path
from pathlib import Path
from PyPDF2 import PdfFileReader, PdfFileWriter
import re
import os
from difflib import SequenceMatcher

# %% [markdown]
# ## Load Files
#
# Replace the file paths below to match local file paths

# %%
masters = pd.read_excel("C:\\Users\\sjwu1\\Journal_Data\\Master lists\\AER_master.xlsx")
pivots = pd.read_excel("C:\\Users\\sjwu1\\Journal_Data\\pivots\\AER_pivots.xlsx")
scopus = pd.read_excel("C:\\Users\\sjwu1\\Journal_Data\\Scopus\\AER_SCOPUS.xlsx")

# %% [markdown]
# ## Create file names

# %%
authors="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\AER_authors.xlsx"
non_auth="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\AER_Nauthors.xlsx"
saveas="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\AER_processed.xlsx"
reviews="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\AER_reviews.xlsx"
misc="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\AER_misc.xlsx"
conf="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\AER_conf.xlsx"

# %% [markdown]
# ## Some random checks on the masters list
#
# My assumption is that all data without author names must be miscellaneous documents like reports by the committee, forewords, front matters etc.. The goal of this notebook is to check for certain that all the documents without author names are actually miscellaneous documents and then classify them as miscellaneous (MISC). Hence, first we group everything the data by title to see the repetitive general content that can likely be removed.
#
# Note: in both cases I've restricted to output to 20 to for sake of viewing on github - there is no scroll function for output.

# %%
pd.set_option('display.max_rows',masters.shape[0])
temp=masters['title'].str.lower().value_counts()
pd.DataFrame(temp[temp>1]).head(20)
# Out:
#                                                                           title
# new books                                                                  2015
# front matter                                                                553
# discussion                                                                  542
# back matter                                                                 444
# notes                                                                       304
# periodicals                                                                 204
# volume information                                                          112
# titles of new books                                                         107
# documents, reports, and legislation                                          89
# report of the finance committee                                              66
# report of the auditor                                                        38
# foreword                                                                     34
# minutes of the executive committee meetings                                  28
# publications of the american economic association                            24
# editors' introduction                                                        23
# report of the representative to the national bureau of economic research     21
# report of the committee on economic education                                21
# independent auditors' report                                                 18
# documents, reports and legislation                                           17
# report of the auditing committee                                             16

# %% [markdown]
# Some repetitions are due to multiple comments. Now consider this list in absence of author names.

# %%
temp2=masters[masters['authors'].isna()]['title'].str.lower().value_counts()
pd.DataFrame(temp2).head(20)
# Out:
#                                                                           title
# new books                                                                  2009
# front matter                                                                553
# back matter                                                                 443
# notes                                                                       301
# periodicals                                                                 204
# volume information                                                          112
# titles of new books                                                         107
# documents, reports, and legislation                                          72
# report of the finance committee                                              63
# report of the auditor                                                        37
# minutes of the executive committee meetings                                  27
# publications of the american economic association                            24
# report of the committee on economic education                                20
# report of the representative to the national bureau of economic research     19
# independent auditors' report                                                 18
# report of the auditing committee                                             16
# documents, reports and legislation                                           15
# announcements                                                                14
# purposes of the american economic association                                14
# report of the census advisory committee                                      14

# %% [markdown]
# There is also many reports with unique titles due to the year of the report being included in the title. Interestingly, discussions are no longer part of the table excluding non-authored articles indicating these may be non-adminstrative documents.
#
# The next block corrects for individual errors that were noted.

# %%
#Block for misspelling or renaming of data
masters.loc[8990,'title']="Back Matter"
masters.loc[10861,'title']="Back Matter"
masters.loc[16376,'title']="Foreword"
masters.loc[25807,'title']="Documents, Reports and Legislation"
masters.loc[25815,'authors']="Alexander Marx"
masters.loc[25720,'authors']="Review by: James Bonar"
masters.loc[6425,'content_type']="Discussion"
masters.loc[2284,'authors']="Victoria Ivashina and David Scharfstein"
masters.loc[503,'authors']="Jennifer L. Doleac and Benjamin Hansen"
masters.loc[22177,'authors']="Review by: W. L. Crum"
masters.loc[22176,'authors']="Review by: Gardiner C. Means"
masters.loc[24681,'authors']="Review by: Victor H. Pelz"
masters.loc[6073,'authors']='Haizhou Huang'
masters.loc[19384,'authors']='Review by: Anon'
masters.loc[6149,'content_type']="Discussion"
masters.loc[18729,'authors']='Anon'
masters.loc[14710,'authors']='Anon'
masters.loc[14710,'title']='Human Resources: The Wealth of a Nation by Eli Ginzberg: Erratum'
masters.loc[24876,'authors']='Review by: Henry Pratt Fairchild'
masters.loc[11919,'authors']='Review by: Anon'
masters.loc[23831,'authors']='Review by: Roy G. Blakey'
masters.loc[24620,'authors']='Review by: Ralph H. Blanchard'
masters.loc[27402,'authors']='Review by: Anon'
masters.loc[19927,'authors']='Anon'

# %% [markdown]
# ## Classifying Miscellaneous content

# %%
scopus.rename(columns = {'abstract':'abstract2', 'title':'title2', 'authors':'authors2'}, inplace = True)
scopus['pages2']=scopus['pages']
masters['pages']=masters['pages'].str.strip()  
masters.loc[masters.title.str.lower() == "back matter", 'pages'] = NaN  
pivots['type']=NaN

masters.loc[masters.title.str.lower() == "back matter", 'content_type'] = "MISC"  
masters.loc[masters.title.str.lower() == "front matter", 'content_type'] = "MISC"
masters.loc[masters.title.str.lower() == "volume matter", 'content_type'] = "MISC"
masters.loc[masters.title == "Announcements", 'content_type'] = "MISC"
masters.loc[masters.title == "Announcement", 'content_type'] = "MISC"
masters.loc[masters.title.str.lower() == "foreword", 'content_type'] = "MISC"
masters.loc[masters.title == "Periodicals", 'content_type'] = "MISC"
masters.loc[masters.title.str.lower() == "doctoral dissertations", 'content_type'] = "MISC"
masters.loc[masters.title == "Editorial Statement", 'content_type'] = "MISC"
masters.loc[masters.title.str.lower() == "list of members", 'content_type'] = "MISC" 
masters.loc[masters.title.str.lower() == "annual meetings", 'content_type'] = "MISC" 
masters.loc[masters.title.str.lower() == "biographical listing of members", 'content_type'] = "MISC" 
masters.loc[masters.title.str.lower() == "honorary members", 'content_type'] = "MISC" 
masters.loc[masters.title.str.lower().str.contains("preliminary announcement of the program"), 'content_type'] = "MISC"
masters.loc[masters["title"].str.contains("Distinguished Fellow"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("\[photograph\]"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("volume information"),'content_type']="MISC"
masters.loc[masters['title'].str.contains("The John Bates Clark Award"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("new books"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("new book"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("the american economic association"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("in memoriam"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("in memorium"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("memorial:"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("list of doctoral dissertations"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("notes") & masters['authors'].isna(),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("documents, reports and legislation") & masters['authors'].isna(),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("documents, reports, and legislation") & masters['authors'].isna(),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("editor") & masters["title"].str.lower().str.contains("introduction"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("classification of members"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("aer survey of members"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("annual business meeting"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("auditor") & masters["title"].str.lower().str.contains("report"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("proceedings of the") & masters["title"].str.lower().str.contains("annual meeting"),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("report of the") & masters['authors'].isna(),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("minutes of the") & masters['authors'].isna(),'content_type']="MISC"
masters.loc[masters["title"].str.lower().str.contains("minutes of business meetings") & masters['authors'].isna(),'content_type']="MISC"
masters.loc[masters["title"].str.len()<3,'content_type']='MISC'
masters.loc[masters['title'].str.match(r'^Program.*')==True,'content_type']='MISC'
masters.loc[masters['title'].str.match(r'^Business Meeting.*')==True,'content_type']='MISC'
#masters[masters['title'].str.lower().str.contains("review")]['title']
masters.loc[masters['title'].str.lower().str.match(r'the committee on.*')==True,'content_type']='MISC'
masters.loc[masters['title'].str.lower().str.match(r'^report of.* representative')==True,'content_type']='MISC'
masters.loc[masters['title'].str.lower().str.match(r'^report of.*committee on')==True,'content_type']='MISC'
masters.loc[masters['title'].str.lower().str.match(r'.*francis.*walker.*award')==True,'content_type']='MISC'
masters.loc[masters['authors'].isna() & masters['content_type'].isna(),'content_type']='MISC'

# %%
#masters[masters["title"].str.lower().str.contains('affiliation')][['title','stable_url']]
#masters[masters['title'].str.match(r'Business Meeting*')==True]
#masters[masters["title"].str.lower().str.contains("aer survey of members")][['title','stable_url']]

# %% [markdown]
# ... One last check. Note: I found that after removing most of the miscellaneous content the remainder that did not have author names were not articles.

# %%
print(masters[masters['authors'].isna() & masters['content_type'].isna()]['title'].shape[0])
pd.set_option('display.max_colwidth', None)
masters[masters['authors'].isna() & masters['content_type'].isna()][['title','stable_url']].sort_values('title')
# Out:
# 0
# Empty DataFrame
# Columns: [title, stable_url]
# Index: []

# %%
pd.set_option('display.max_rows',masters.shape[0])
print(sum(masters['content_type']=='MISC'))
#pd.DataFrame(masters['title'][masters['content_type']=='MISC']).sort_values('title')
# Out:
# 5732

# %%
masters[masters.title.str.lower().str.match(r'.*:.*') & masters.content_type.isna()].head()
# Out:
#                                stable_url  \
# 4   https://www.jstor.org/stable/26848481
# 6   https://www.jstor.org/stable/26848483
# 8   https://www.jstor.org/stable/26848485
# 9   https://www.jstor.org/stable/26848486
# 12  https://www.jstor.org/stable/26807866
#
#                                                                             authors  \
# 4   Tatyana Deryugina, Garth Heutel, Nolan H. Miller, David Molitor and Julian Reif
# 6                                                                 Sharon Traiberman
# 8                                                 Luigi Bocola and Alessandro Dovis
# 9         Mathieu Couttenier, Veronica Petrencu, Dominic Rohner and Mathias Thoenig
# 12                               Judd B. Kessler, Corinne Low and Colin D. Sullivan
#
#                                                                                                   title  \
# 4             The Mortality and Medical Costs of Air Pollution: Evidence from Changes in Wind Direction
# 6                                             Occupations and Import Competition: Evidence from Denmark
# 8                                                  Self-Fulfilling Debt Crises: A Quantitative Analysis
# 9   The Violent Legacy of Conflict: Evidence on Asylum Seekers, Crime, and Public Policy in Switzerland
# 12                         Incentivized Resume Rating: Eliciting Employer Preferences without Deception
#
#     abstract content_type                                       issue_url  \
# 4        NaN          NaN  https://www.jstor.org/stable/10.2307/e26848476
# 6        NaN          NaN  https://www.jstor.org/stable/10.2307/e26848476
# 8        NaN          NaN  https://www.jstor.org/stable/10.2307/e26848476
# 9        NaN          NaN  https://www.jstor.org/stable/10.2307/e26848476
# 12       NaN          NaN  https://www.jstor.org/stable/10.2307/e26807864
#
#         pages  year  volume issue
# 4   4178-4219  2019     109    12
# 6   4260-4301  2019     109    12
# 8   4343-4377  2019     109    12
# 9   4378-4425  2019     109    12
# 12  3713-3744  2019     109    11

# %% [markdown]
# ## Separating out other types

# %%
masters.loc[~(masters['authors'].isna()) & masters['authors'].str.lower().str.match(r'.*review by:.*'),'content_type']='Review'
masters[masters.content_type=='Review'].shape[0]
# Out:
# 7144

# %%
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*: (|a )comment(|.*)$')==True,'content_type']='Comment'
masters[masters['content_type']=='Comment'].shape[0]
# Out:
# 809

# %%
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*(:|\?) (|a )reply(| to.*)$')==True,'content_type']="Reply"
masters[masters['content_type']=='Reply'].shape[0]
# Out:
# 505

# %%
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*: (|a )discussion$')==True,'content_type']="Discussion"
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'(^|a )discussion(|.*)$')==True,'content_type']="Discussion"
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*:.*(|a )discussion(|s)$')==True,'content_type']='Discussion'
masters[masters['content_type']=='Discussion'].shape[0]
# Out:
# 592

# %%
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*(:|\?) (|a )rejoinder.*$')==True,'content_type']="Rejoinder"
masters[masters['content_type']=='Rejoinder'].shape[0]
# Out:
# 52

# %%
masters.loc[masters['content_type'].isna(),'content_type']="Article"
masters[masters['content_type']=='Article'].shape[0]
# Out:
# 12584

# %%
# block for testing regex strings
#masters[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*: (|a )discussion(|.*)$')==True] #false positive for discussion
#masters[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*: (|a )comment(|.*)$')==True] comments to specific people
#masters[masters.title.str.lower().str.match(r'^(|a )note.*')]

# %%
masters[masters.content_type=='Article'].shape[0] #articles in data set
# Out:
# 12584

# %%
masters[(masters['content_type']=='Article') & ((masters.year>1939) ==True)].shape[0] #all articles after 1940
# Out:
# 11203

# %%
masters[(masters['content_type']=='Article') & ((masters.year>1939) ==True) & ((masters.year<2011) ==True)].shape[0] #articles between 1940 and 2010
# Out:
# 9340

# %% [markdown]
# ## Consider the pivots file
#
# At times, conference papers are structured differently to normal articles. Hence, it may be necessary to distinguish conference papers from common articles. The next code block separates special issues (S) from normal issues (N)

# %%
pivots.loc[pivots.Jstor_issue_text.str.lower().str.match(r'(.*)(supplement|proceedings|annual meeting|survey)(.*)'),'type']="S"
pivots.loc[pivots.type.isna(),'type']='N'
pivots[pivots.type=='S'].head()
# Out:
#     year month  volume issue                                       issue_url  \
# 30  2017   MAY     107     5  https://www.jstor.org/stable/10.2307/i40178116
# 42  2016   MAY     106     5  https://www.jstor.org/stable/10.2307/i40158602
# 54  2015   MAY     105     5  https://www.jstor.org/stable/10.2307/i40156735
# 66  2014   MAY     104     5  https://www.jstor.org/stable/10.2307/i40112127
# 75  2013   MAY     103     3  https://www.jstor.org/stable/10.2307/i23469657
#
#                                                                                                                                 Jstor_issue_text  \
# 30    No. 5 PAPERS AND PROCEEDINGS OF THE One Hundred Twenty-Ninth Annual Meeting OF THE AMERICAN ECONOMIC ASSOCIATION MAY 2017 pp. i-xii, 1-681
# 42   No. 5 PAPERS AND PROCEEDINGS OF THE One Hundred Twenty-Eighth Annual Meeting OF THE AMERICAN ECONOMIC ASSOCIATION MAY 2016 pp. i-xiv, 1-683
# 54  No. 5 PAPERS AND PROCEEDINGS OF THE One Hundred Twenty-Seventh Annual Meeting OF THE AMERICAN ECONOMIC ASSOCIATION MAY 2015 pp. i-xiv, 1-682
# 66  No. 5 PAPERS AND PROCEEDINGS OF One Hundred Twenty-Sixth Annual Meeting OF THE AMERICAN ECONOMIC ASSOCIATION MAY 2014 pp. i-xiv, 1-608, i-ii
# 75    No. 3 PAPERS AND PROCEEDINGS OF THE One Hundred Twenty-Fifth Annual Meeting OF THE AMERICAN ECONOMIC ASSOCIATION MAY 2013 pp. i-xiv, 1-683
#
#    journal                              pivot_url  no_docs type
# 30     AER  https://www.jstor.org/stable/44250350      132    S
# 42     AER  https://www.jstor.org/stable/43860977      128    S
# 54     AER  https://www.jstor.org/stable/43821842      124    S
# 66     AER  https://www.jstor.org/stable/42920902      104    S
# 75     AER  https://www.jstor.org/stable/23469697      116    S

# %% [markdown]
# Merging the pivots with masters

# %%
result = pd.merge(masters, pivots[['issue_url','journal','type']], how="left", on=["issue_url", "issue_url"])

# %%
result.head()
# Out:
#                               stable_url  \
# 0  https://www.jstor.org/stable/26848477
# 1  https://www.jstor.org/stable/26848478
# 2  https://www.jstor.org/stable/26848479
# 3  https://www.jstor.org/stable/26848480
# 4  https://www.jstor.org/stable/26848481
#
#                                                                            authors  \
# 0                                                                              NaN
# 1                                  Marcella Alsan, Owen Garrick and Grant Graziani
# 2                                                   Drew Fudenberg and Annie Liang
# 3                          Hanno Lustig, Andreas Stathopoulos and Adrien Verdelhan
# 4  Tatyana Deryugina, Garth Heutel, Nolan H. Miller, David Molitor and Julian Reif
#
#                                                                                        title  \
# 0                                                                               Front Matter
# 1                       Does Diversity Matter for Health? Experimental Evidence from Oakland
# 2                                                  Predicting and Understanding Initial Play
# 3                                     The Term Structure of Currency Carry Trade Risk Premia
# 4  The Mortality and Medical Costs of Air Pollution: Evidence from Changes in Wind Direction
#
#    abstract content_type                                       issue_url  \
# 0       NaN         MISC  https://www.jstor.org/stable/10.2307/e26848476
# 1       NaN      Article  https://www.jstor.org/stable/10.2307/e26848476
# 2       NaN      Article  https://www.jstor.org/stable/10.2307/e26848476
# 3       NaN      Article  https://www.jstor.org/stable/10.2307/e26848476
# 4       NaN      Article  https://www.jstor.org/stable/10.2307/e26848476
#
#        pages  year  volume issue journal type
# 0        NaN  2019     109    12     AER    N
# 1  4071-4111  2019     109    12     AER    N
# 2  4112-4141  2019     109    12     AER    N
# 3  4142-4177  2019     109    12     AER    N
# 4  4178-4219  2019     109    12     AER    N

# %% [markdown]
# ## Creating counts of the data

# %%
pd.DataFrame(masters['content_type'].value_counts()) # counts by content_type
# Out:
#             content_type
# Article            12584
# Review              7144
# MISC                5732
# Comment              809
# Discussion           592
# Reply                505
# Rejoinder             52

# %%
pd.DataFrame(masters[masters.year>1939].content_type.value_counts()) # counts after 1940 (inclusive)
# Out:
#             content_type
# Article            11203
# Review              4571
# MISC                2964
# Comment              792
# Discussion           545
# Reply                489
# Rejoinder             46

# %%
pd.DataFrame(masters[(masters.year>1939) & (masters.year<2011)].content_type.value_counts()) 
# counts between 1940 and 2010 (inclusive)
# Out:
#             content_type
# Article             9340
# Review              4571
# MISC                2714
# Comment              748
# Discussion           545
# Reply                461
# Rejoinder             46

# %%
result.to_excel(saveas, index=False)

# %% [markdown]
# ## This section aims to match up Scopus records and Jstor articles
# If an article's affiliations, citations or abstracts are recorded on Scopus, I want to exclude them from the set of pdf's that are sent to docParser. Matching up the Scopus data is also useful for comparing the textual accuracy of OCR parsers. I use volume, issue, year and page numbers which are common to both the scopus data and the Jstor metadata to match articles.
#
# Then I use a sequence comparison between the journal titles of the matched articles to decide if the scopus data has been matched correctly. If the match ratio is below 70%, the title is investigated and if wrong, the scopus data for that matched article is eihter corrected or discarded. If the scopus data is missing all of affiliations, abstract and citations fields then the match is also discarded.
#
# Finally, if the document type of scopus is different to the classification done during the cleaning section, the article is reclassified according to the Scopus document type.

# %%
cleaned=pd.read_excel('C:\\Users\\sjwu1\\Journal_Data\\datadumps\\processed\\AER_processed.xlsx')
scopus['pages']=scopus['pages'].str.strip()
print(scopus.shape)
# Out:
# (5810, 14)

# %%
#Note that we only have data up to 2019 in the masterlists because of the moving wall on JSTOR
print(sum(scopus['year']<2020))
# Out:
# 5573

# %%
Merged=pd.merge(cleaned, scopus, on=['year', 'issue','volume','pages'], how='left')

# %% [markdown]
# There are 47 titles that don't match.

# %%
sum(Merged['title_y'].isna()==False)
# Out:
# 5399

# %%
count=0
for m in Merged.index:
    
    if(pd.isna(Merged.iloc[m]['title_y'])==False):
        ratio=SequenceMatcher(None, Merged.iloc[m]['title_x'].lower(), Merged.iloc[m]['title_y'].lower()).ratio()

        if((ratio<0.7) & (Merged.iloc[m]['content_type']!='MISC')):
            print(Merged.iloc[m]['year'])
            print(ratio)
            count+=1
            A_ratio=SequenceMatcher(None, Merged.iloc[m]['authors_x'].lower(), Merged.iloc[m]['authors_y'].lower()).ratio()
            print(A_ratio)
            print(Merged.iloc[m]['stable_url'])
            print('vol: '+str(Merged.iloc[m]['volume']))
            print('issue: '+str(Merged.iloc[m]['issue']))
            print('pages: '+Merged.iloc[m]['pages'])
            print('jstor: '+Merged.iloc[m]['title_x'])
            print('scopus: '+Merged.iloc[m]['title_y'])
            print('jstor: '+Merged.iloc[m]['authors_x'])
            print('scopus: '+Merged.iloc[m]['authors_y'])
            print('scopus index: '+str(scopus[scopus['title']==Merged.iloc[m]['title_y']].index))
            print(m)
            print()
print(count)
# Out:
# 2014
# 0.16666666666666666
# 0.23809523809523808
# https://www.jstor.org/stable/43495358
# vol: 104
# issue: 12
# pages: 3814-3840
# jstor: Ambiguity Aversion with Three or More Outcomes
# scopus: Hospital choices, hospital prices, and financial incentives to physicians?
# jstor: Mark J. Machina
# scopus: Ho, K.--a--
# Pakes, A.--b--
# scopus index: Int64Index([4331], dtype='int64')
# 1131
#
# 2014
# 0.30601092896174864
# 0.2727272727272727
# https://www.jstor.org/stable/43495359
# vol: 104
# issue: 12
# pages: 3841-3884
# jstor: Hospital Choices, Hospital Prices, and Financial Incentives to Physicians
# scopus: Consumption and debt response to unanticipated income shocks: Evidence from a natural experiment in Singapore?
# jstor: Kate Ho and Ariel Pakes
# scopus: Agarwal, S., Qian, W.
# scopus index: Int64Index([4332], dtype='int64')
# 1132
#
# 2014
# 0.3522012578616352
# 0.19672131147540983
# https://www.jstor.org/stable/43495360
# vol: 104
# issue: 12
# pages: 3885-3920
# jstor: Is It Whom You Know or What You Know? An Empirical Assessment of the Lobbying Process
# scopus: Reputation and persistence of adverse selection in secondary loan markets?
# jstor: Marianne Bertrand, Matilde Bombardini and Francesco Trebbi
# scopus: Chari, V.V.--a-- --b--
# Shourideh, A.--c--
# Zetlin-Jones, A.--d--
# scopus index: Int64Index([4330], dtype='int64')
# 1133
#
# 2014
# 0.23931623931623933
# 0.125
# https://www.jstor.org/stable/43495361
# vol: 104
# issue: 12
# pages: 3921-3955
# jstor: The Effects of Poor Neonatal Health on Children's Cognitive Development
# scopus: Ambiguity aversion with three or more outcomes
# jstor: David Figlio, Jonathan Guryan, Krzysztof Karbownik and Jeffrey Roth
# scopus: Machina, M.J.
# scopus index: Int64Index([4335], dtype='int64')
# 1134
#
# 2014
# 0.2
# 0.096
# https://www.jstor.org/stable/43495362
# vol: 104
# issue: 12
# pages: 3956-3990
# jstor: Private Equity, Jobs, and Productivity
# scopus: Hot and cold seasons in the housing market
# jstor: Steven J. Davis, John Haltiwanger, Kyle Handley, Ron Jarmin, Josh Lerner and Javier Miranda
# scopus: Ngai, L.R.--a--
# Tenreyro, S.--b--
# scopus index: Int64Index([4334], dtype='int64')
# 1135
#
# 2014
# 0.14953271028037382
# 0.11940298507462686
# https://www.jstor.org/stable/43495363
# vol: 104
# issue: 12
# pages: 3991-4026
# jstor: Hot and Cold Seasons in the Housing Market
# scopus: The dynamic efficiency costs of common-pool resource exploitation
# jstor: L. Rachel Ngai and Silvana Tenreyro
# scopus: Huang, L.--a--
# Smith, M.D.--b--
# scopus index: Int64Index([4338], dtype='int64')
# 1136
#
# 2014
# 0.35668789808917195
# 0.2601626016260163
# https://www.jstor.org/stable/43495364
# vol: 104
# issue: 12
# pages: 4027-4070
# jstor: Reputation and Persistence of Adverse Selection in Secondary Loan Markets
# scopus: Consume now or later? Time inconsistency, collective choice, and revealed preference
# jstor: V. V. Chari, Ali Shourideh and Ariel Zetlin-Jones
# scopus: Adams, A.--a-- --b--
# Cherchye, L.--c--
# De Rock, B.--d--
# Verriest, E.--e--
# scopus index: Int64Index([4329], dtype='int64')
# 1137
#
# 2014
# 0.13725490196078433
# 0.15789473684210525
# https://www.jstor.org/stable/43495365
# vol: 104
# issue: 12
# pages: 4071-4103
# jstor: The Dynamic Efficiency Costs of Common-Pool Resource Exploitation
# scopus: Trade wars and trade talks with data?
# jstor: Ling Huang and Martin D. Smith
# scopus: Ossa, R.
# scopus index: Int64Index([4328], dtype='int64')
# 1138
#
# 2014
# 0.4
# 0.12
# https://www.jstor.org/stable/43495366
# vol: 104
# issue: 12
# pages: 4104-4146
# jstor: Trade Wars and Trade Talks with Data
# scopus: Present bias and collective dynamic choice in the lab?
# jstor: Ralph Ossa
# scopus: Jackson, M.O.--a-- --b--
# Yariv, L.--c--
# scopus index: Int64Index([4336], dtype='int64')
# 1139
#
# 2014
# 0.25
# 0.2268041237113402
# https://www.jstor.org/stable/43495367
# vol: 104
# issue: 12
# pages: 4147-4183
# jstor: Consume Now or Later? Time Inconsistency, Collective Choice, and Revealed Preference
# scopus: Risk matters: The real effects of volatility shocks: Comment
# jstor: Abi Adams, Laurens Cherchye, Bram De Rock and Ewout Verriest
# scopus: Born, B.--a-- --b--
# Pfeifer, J.--a--
# scopus index: Int64Index([4339], dtype='int64')
# 1140
#
# 2014
# 0.32967032967032966
# 0.17647058823529413
# https://www.jstor.org/stable/43495368
# vol: 104
# issue: 12
# pages: 4184-4204
# jstor: Present Bias and Collective Dynamic Choice in the Lab
# scopus: Private equity, jobs, and productivity
# jstor: Matthew O. Jackson and Leeat Yariv
# scopus: Davis, S.J.--a-- --g--
# Haltiwanger, J.--b-- --g-- --g--
# Handley, K.--c--
# Jarmin, R.--d--
# Lerner, J.--e-- --g-- --g--
# Miranda, J.--f--
# scopus index: Int64Index([4337], dtype='int64')
# 1141
#
# 2014
# 0.1878453038674033
# 0.17857142857142858
# https://www.jstor.org/stable/43495369
# vol: 104
# issue: 12
# pages: 4205-4230
# jstor: Consumption and Debt Response to Unanticipated Income Shocks: Evidence from a Natural Experiment in Singapore
# scopus: The effects of poor neonatal health on children's cognitive development?
# jstor: Sumit Agarwal and Wenlan Qian
# scopus: Figlio, D.--a-- --b--
# Guryan, J.--a-- --b--
# Karbownik, K.--a-- --c--
# Roth, J.--d--
# scopus index: Int64Index([4333], dtype='int64')
# 1142
#
# 2014
# 0.1793103448275862
# 0.29545454545454547
# https://www.jstor.org/stable/43495370
# vol: 104
# issue: 12
# pages: 4231-4239
# jstor: Risk Matters: The Real Effects of Volatility Shocks: Comment
# scopus: Is it whom you know or what you know? An empirical assessment of the lobbying process
# jstor: Benjamin Born and Johannes Pfeifer
# scopus: Bertrand, M.--a--
# Bombardini, M.--b--
# Trebbi, F.--b--
# scopus index: Int64Index([4340], dtype='int64')
# 1143
#
# 2012
# 0.6802721088435374
# 0.5666666666666667
# https://www.jstor.org/stable/23245449
# vol: 102
# issue: 2
# pages: 1186
# jstor: Erratum: Macroeconomic Effects of Financial Shocks
# scopus: Erratum: Macroeconomic Effects of Financial Shocks (American Economic Review (2012) 102:2 (1186))
# jstor: Urban Jermann and Vincenzo Quadrini
# scopus: Jermann, U., Quadrini, V.
# scopus index: Int64Index([4045], dtype='int64')
# 1890
#
# 2011
# 0.17142857142857143
# 0.4666666666666667
# https://www.jstor.org/stable/41038777
# vol: 101
# issue: 1
# pages: i
# jstor: [Introduction]
# scopus: American Economic Review: Front matter and editor's note
# jstor: Robert A. Moffitt
# scopus: Moffitt, R.A.
# scopus index: Int64Index([3830], dtype='int64')
# 2167
#
# 2010
# 0.6451612903225806
# 0.52
# https://www.jstor.org/stable/27805007
# vol: 100
# issue: 2
# pages: 292-296
# jstor: How Sensitive are Low Income Families to Health Plan Prices?
# scopus: The Massachusett s health insurance experiment: Early experiences how sensitive are low income families to health plan prices?
# jstor: David Chan and Jonathan Gruber
# scopus: Chan, D., Gruber, J.
# scopus index: Int64Index([3418], dtype='int64')
# 2329
#
# 2009
# 0.6407766990291263
# 0.46153846153846156
# https://www.jstor.org/stable/25592496
# vol: 99
# issue: 3
# pages: 1082
# jstor: Corrigendum: Women, Wealth, and Mobility
# scopus: Erratum: Women, wealth, and mobility (American Economic Review)
# jstor: Lena Edlund and Wojciech Kopczuk
# scopus: Edlund, L.--a--
# Kopczuk, W.--b--
# scopus index: Int64Index([3178], dtype='int64')
# 2513
#
# 2008
# 0.6797385620915033
# 0.4948453608247423
# https://www.jstor.org/stable/29730114
# vol: 98
# issue: 3
# pages: 1195-1196
# jstor: When Does Coordination Require Centralization? Corrigendum
# scopus: Erratum: When does coordination require centralization? (American Economic Review (2008) (153))
# jstor: Ricardo Alonso, Wouter Dessein and Niko Matouschek
# scopus: Ricardo, A.--a--
# Wouter, D.--b--
# Niko, M.--c--
# scopus index: Int64Index([2925], dtype='int64')
# 2730
#
# 2006
# 0.5815602836879432
# 0.42857142857142855
# https://www.jstor.org/stable/30034348
# vol: 96
# issue: 4
# pages: 1367
# jstor: Equilibrium Incentives in Oligopoly: Corrigendum
# scopus: Erratum: Equilibrium incentives in oligopoly (American Economic Review (1987) 77:5 (927-940))
# jstor: Chaim Fershtman and Kenneth L. Judd
# scopus: Fershtman, C.--a--
# Judd, K.L.--b--
# scopus index: Int64Index([2581], dtype='int64')
# 3119
#
# 2006
# 0.6547619047619048
# 0.4864864864864865
# https://www.jstor.org/stable/30034379
# vol: 96
# issue: 1
# pages: 456
# jstor: International Protection of Intellectual Property: Corrigendum
# scopus: Erratum: International protection of intellectual property (American Economic Review (2004) 94:5 (1635-53)
# jstor: Gene M. Grossman and Edwin L.-C. Lai
# scopus: Grossman, G.M.--a--
# Lai, E.L.-C.--b--
# scopus index: Int64Index([2722], dtype='int64')
# 3266
#
# 2005
# 0.650887573964497
# 0.41379310344827586
# https://www.jstor.org/stable/4132778
# vol: 95
# issue: 5
# pages: 1752
# jstor: Corrigendum: The Savers-Spenders Theory of Fiscal Policy: Corrigendum
# scopus: Erratum: The savers-spenders theory of fiscal policy (American Economic Review (2000) 90:2 (120-25))
# jstor: N. Gregory Mankiw
# scopus: Mankiw, N.G.
# scopus index: Int64Index([2370], dtype='int64')
# 3294
# 2001
# 0.36923076923076925
# 0.38461538461538464
# https://www.jstor.org/stable/2677725
# vol: 91
# issue: 2
# pages: 12-17
# jstor: Human Capital and Growth
# scopus: Human capital: Growth, history, and policy - A session to honor Stanley Engerman: Human capital and growth
# jstor: Robert J. Barro
# scopus: Barro, R.J.
# scopus index: Int64Index([1722], dtype='int64')
# 4162
#
# 2001
# 0.5753424657534246
# 0.4411764705882353
# https://www.jstor.org/stable/2677728
# vol: 91
# issue: 2
# pages: 29-33
# jstor: Input Trade and the Location of Production
# scopus: Development and history: A session to honor Stanley Engerman: Input trade and the location of production
# jstor: Ronald Findlay and Ronald W. Jones
# scopus: Findlay, R.--a--
# Jones, R.W.--b--
# scopus index: Int64Index([1738], dtype='int64')
# 4165
#
# 2001
# 0.5714285714285714
# 0.49557522123893805
# https://www.jstor.org/stable/2677763
# vol: 91
# issue: 2
# pages: 219-225
# jstor: Interest Rates and Inflation
# scopus: Recent advances in monetary-policy rules: Interest rates and inflation
# jstor: Fernando Alvarez, Robert E. Lucas, Jr. and Warren E. Weber
# scopus: Alvarez, F.--a--
# Lucas Jr., R.E.--a--
# Weber, W.E.--b--
# scopus index: Int64Index([1772], dtype='int64')
# 4200
#
# 2001
# 0.48214285714285715
# 0.6666666666666666
# https://www.jstor.org/stable/2677766
# vol: 91
# issue: 2
# pages: 238-242
# jstor: Fewer Monies, Better Monies
# scopus: Exchange rates and the choice of monetary-policy regimes: Fewer monies, better monies
# jstor: Rudi Dornbusch
# scopus: Dornbusch, R.
# scopus index: Int64Index([1796], dtype='int64')
# 4203
#
# 2001
# 0.6105263157894737
# 0.4927536231884058
# https://www.jstor.org/stable/2677769
# vol: 91
# issue: 2
# pages: 253-257
# jstor: Should Central Banks Respond to Movements in Asset Prices?
# scopus: Quantitative policy implications of new normative macroeconomic research: Should central banks respond to movements in asset prices?
# jstor: Ben S. Bernanke and Mark Gertler
# scopus: Bernanke, B.S.--a--
# Gertler, M.--b--
# scopus index: Int64Index([1681], dtype='int64')
# 4206
#
# 2001
# 0.36363636363636365
# 0.417910447761194
# https://www.jstor.org/stable/2677775
# vol: 91
# issue: 2
# pages: 287-291
# jstor: Internet Peering
# scopus: Interconnection and access in telecom and the internet: Internet peering
# jstor: Jean-Jacques Laffont, Scott Marcus, Patrick Rey and Jean Tirole
# scopus: Laffont, J.-J.--a--
# Marcus, S.--b--
# Rey, P.--e--
# Tirole, J.--c-- --d--
# scopus index: Int64Index([1710], dtype='int64')
# 4212
#
# 2001
# 0.6578947368421053
# 0.7096774193548387
# https://www.jstor.org/stable/2677785
# vol: 91
# issue: 2
# pages: 342-346
# jstor: Appeasement: Can It Work?
# scopus: Conflict and the economy: Appeasement: Can it work?
# jstor: Jack Hirshleifer
# scopus: Hirshleifer, J.
# scopus index: Int64Index([1711], dtype='int64')
# 4222
#
# 2001
# 0.5899280575539568
# 0.36363636363636365
# https://www.jstor.org/stable/2677788
# vol: 91
# issue: 2
# pages: 358-362
# jstor: Commercial Policy in a "Fragmented" World
# scopus: Fragmentation, diversification, and international trade: Commercial policy in a "Fragmented" world
# jstor: Eric W. Bond
# scopus: Bond, E.W.
# scopus index: Int64Index([1712], dtype='int64')
# 4225
#
# 2000
# 0.5185185185185185
# 0.5
# https://www.jstor.org/stable/117190
# vol: 90
# issue: 2
# pages: 48-52
# jstor: Why Did the Ruble Collapse in August 1998?
# scopus: Macroeconomic stabilization and exchange-rate regimes: Alternative scenarios: Why did the ruble collapse in August 1998?
# jstor: Padma Desai
# scopus: Desai, P.
# scopus index: Int64Index([1554], dtype='int64')
# 4362
#
# 2000
# 0.6883116883116883
# 0.4864864864864865
# https://www.jstor.org/stable/117205
# vol: 90
# issue: 2
# pages: 126-130
# jstor: Political Losers as a Barrier to Economic Development
# scopus: Political economy, governance, and development: Political losers as a barrier to economic development
# jstor: Daron Acemoglu and James A. Robinson
# scopus: Acemoglu, D.--a--
# Robinson, J.A.--b--
# scopus index: Int64Index([1508], dtype='int64')
# 4377
#
# 2000
# 0.49411764705882355
# 0.4473684210526316
# https://www.jstor.org/stable/117212
# vol: 90
# issue: 2
# pages: 161-167
# jstor: U.S. Economic Growth at the Industry Level
# scopus: Industry-level productivity and competitiveness between Canada and the United States: U.S. Economic growth at the industry level
# jstor: Dale W. Jorgenson and Kevin J. Stiroh
# scopus: Jorgenson, D.W.--a--
# Stiroh, K.J.--b--
# scopus index: Int64Index([1524], dtype='int64')
# 4384
#
# 2000
# 0.5148514851485149
# 0.5132743362831859
# https://www.jstor.org/stable/117223
# vol: 90
# issue: 2
# pages: 215-218
# jstor: Knowledge Spillovers and Patent Citations: Evidence from a Survey of Inventors
# scopus: The NBER/sloan project on industrial technology and productivity: Incorporating learning from plant visits and interviews into economic research - Knowledge spillovers and patent citations: Evidence from a survey of inventors
# jstor: Adam B. Jaffe, Manuel Trajtenberg and Michael S. Fogarty
# scopus: Jaffe, A.B.--a--
# Trajtenberg, M.--b--
# Fogarty, M.S.--c--
# scopus index: Int64Index([1649], dtype='int64')
# 4395
#
# 2000
# 0.6296296296296297
# 0.47368421052631576
# https://www.jstor.org/stable/117237
# vol: 90
# issue: 2
# pages: 288-292
# jstor: How Much Should Americans Be Saving for Retirement?
# scopus: How well are we and the government planning for the future? How much should americans be saving for retirement?
# jstor: B. Douglas Bernheim, Lorenzo Forni, Jagadeesh Gokhale and Laurence J. Kotlikoff
# scopus: Bernheim, B.D.--a--
# Forni, L.--b--
# Gokhale, J.--c--
# Kotlikoff, L.J.--d--
# scopus index: Int64Index([1544], dtype='int64')
# 4409
#
# 2000
# 0.6461538461538462
# 0.45977011494252873
# https://www.jstor.org/stable/117241
# vol: 90
# issue: 2
# pages: 308-311
# jstor: Racial and Ethnic Economic Inequality: The International Record
# scopus: Cross-national comparisons of racial and ethnic economic inequality: Racial and ethnic economic inequality: The international record
# jstor: William Darity, Jr. and Jessica Gordon Nembhard
# scopus: Darity Jr., W.--a--
# Nembhard, J.G.--b--
# scopus index: Int64Index([1513], dtype='int64')
# 4413
#
# 2000
# 0.691358024691358
# 0.4666666666666667
# https://www.jstor.org/stable/117253
# vol: 90
# issue: 2
# pages: 373-377
# jstor: Welfare Benefits and Female Headship in U.S. Time Series
# scopus: Policy effects on family structure and fertility: Welfare benefits and female headship in U.S. Time series
# jstor: Robert A. Moffitt
# scopus: Moffitt, R.A.
# scopus index: Int64Index([1561], dtype='int64')
# 4425
#
# 2000
# 0.5227272727272727
# 0.42857142857142855
# https://www.jstor.org/stable/117260
# vol: 90
# issue: 2
# pages: 410-414
# jstor: The Power of Incentives
# scopus: Unresolved issues in personnel economics: The power of incentives
# jstor: Edward P. Lazear
# scopus: Lazear, E.P.
# scopus index: Int64Index([1551], dtype='int64')
# 4432
#
# 1983
# 0.4727272727272727
# 0.5
# https://www.jstor.org/stable/1816823
# vol: 73
# issue: 2
# pages: 107-111
# jstor: An Entrepreneurial Problem
# scopus: The role of alien entrepreneurs in economic development: an entrepreneurial problem.
# jstor: Peter Kilby
# scopus: Kilby, P.
# scopus index: Int64Index([416], dtype='int64')
# 7990
#
# 1983
# 0.5588235294117647
# 1.0
# https://www.jstor.org/stable/1816824
# vol: 73
# issue: 2
# pages: 112-117
# jstor: Chinese Entrepreneurs in Southeast Asia
# scopus: The role of alien entrepreneurs in economic development: Chinese intrepreneurs in Southeast Asia.
# jstor: Yuan-Li Wu
# scopus: Yuan-Li Wu
# scopus index: Int64Index([417], dtype='int64')
# 7991
#
# 1983
# 0.5166666666666667
# 0.45454545454545453
# https://www.jstor.org/stable/1816825
# vol: 73
# issue: 2
# pages: 118-122
# jstor: The Levantines in Latin America
# scopus: The role of alien entrepreneurs in economic development: the Levantines in Latin America.
# jstor: William Glade
# scopus: Glade, W.
# scopus index: Int64Index([401], dtype='int64')
# 7992
#
# 1983
# 0.6236559139784946
# 0.5925925925925926
# https://www.jstor.org/stable/1816832
# vol: 73
# issue: 2
# pages: 159-163
# jstor: On the Effects of Federal Aid
# scopus: The changing fortunes of regions: on the effects of federal aid.
# jstor: George Tolley, Ronald Krumm and Jeffrey Sanders
# scopus: Tolley, G., Krumm, R., Sanders, J.
# scopus index: Int64Index([409], dtype='int64')
# 7999
#
# 1983
# 0.6391752577319587
# 0.5294117647058824
# https://www.jstor.org/stable/1816833
# vol: 73
# issue: 2
# pages: 164-168
# jstor: Industrial Bases and City Sizes
# scopus: The changing fortunes of regions: industrial bases and city sizes.
# jstor: J. Vernon Henderson
# scopus: Henderson, J.V.
# scopus index: Int64Index([420], dtype='int64')
# 8000
#
# 1983
# 0.532258064516129
# 0.5142857142857142
# https://www.jstor.org/stable/1816835
# vol: 73
# issue: 2
# pages: 173-177
# jstor: Leading Issues of Fact and Theory
# scopus: Economics of mass migration from poor to rich countries: leading issues of fact and theory.
# jstor: Michael J. Greenwood
# scopus: Greenwood, M.J.
# scopus index: Int64Index([421], dtype='int64')
# 8002
#
# 1983
# 0.5972222222222222
# 0.4827586206896552
# https://www.jstor.org/stable/1816836
# vol: 73
# issue: 2
# pages: 178-182
# jstor: International Migration Models and Policies
# scopus: Economics of mass migration from poor to rich countries: international migration models and policies.
# jstor: Edwin P. Reubens
# scopus: Reubens, E.P.
# scopus index: Int64Index([407], dtype='int64')
# 8003
#
# 1983
# 0.6463414634146342
# 0.5581395348837209
# https://www.jstor.org/stable/1816837
# vol: 73
# issue: 2
# pages: 183-187
# jstor: Trade Theory, Distribution of Income, and Immigration
# scopus: Economics of mass migration from poor to rich countries: trade theory, distribution of income, and immigration.
# jstor: Francisco L. Rivera-Batiz
# scopus: Rivera-Batiz, F.L.
# scopus index: Int64Index([418], dtype='int64')
# 8004
#
# 1981
# 0.5732484076433121
# 0.5384615384615384
# https://www.jstor.org/stable/1815724
# vol: 71
# issue: 2
# pages: 235-240
# jstor: Measuring the Benefits from Reduced Morbidity
# scopus: Measuring benefits from air pollution control: where do we stand? Measuring the benefits from reduced morbidity.
# jstor: M. L. Cropper
# scopus: Cropper, M.L.
# scopus index: Int64Index([371], dtype='int64')
# 8479
#
# 1981
# 0.3619047619047619
# 0.45454545454545453
# https://www.jstor.org/stable/1815725
# vol: 71
# issue: 2
# pages: 241-245
# jstor: Valuing Health Risk
# scopus: Measuring benefits from air pollution control: where do we stand? Valuing health risk.
# jstor: Sherwin Rosen
# scopus: Rosen, S.
# scopus index: Int64Index([370], dtype='int64')
# 8480
# 47

# %%
scopus.at[4331,'pages']='3841-3884'
scopus.at[4335,'pages']='3814-3840'
scopus.at[4340,'pages']='3885-3920'
scopus.at[4333,'pages']='3921-3955'
scopus.at[4337,'pages']='3956-3990'
scopus.at[4334,'pages']='3991-4026'
scopus.at[4330,'pages']='4027-4070'
scopus.at[4338,'pages']='4071-4103'
scopus.at[4328,'pages']='4104-4146'
scopus.at[4329,'pages']='4147-4183'
scopus.at[4336,'pages']='4184-4204'
scopus.at[4332,'pages']='4205-4230'
scopus.at[4339,'pages']='4231-4239'

scopus.at[4045,'title']="Erratum: Macroeconomic Effects of Financial Shocks"
scopus.at[2925,'title']="Erratum: When does coordination require centralization?"
scopus.at[2581,'title']="Erratum: Equilibrium incentives in oligopoly"
scopus.at[2722,'title']="Erratum: International protection of intellectual property"
scopus.at[2370, 'title']="Erratum: The savers-spenders theory of fiscal policy"
scopus.at[3178,'title']="Erratum: Women, wealth, and mobility"

# %%
Merged=pd.merge(cleaned, scopus, on=['year', 'issue','volume','pages'], how='left')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.DataFrame(Merged[Merged['document type'].str.len()>100])
# Out:
#                                  stable_url  \
# 1166  https://www.jstor.org/stable/43495314
# 2662  https://www.jstor.org/stable/29730164
# 4696    https://www.jstor.org/stable/117017
#
#                                               authors_x  \
# 1166  Matthew Gentzkow, Jesse M. Shapiro and Michael...
# 2662                                      Emir Kamenica
# 4696                                   Douglas A. Irwin
#
#                                                 title_x  abstract_x  \
# 1166  Competition and Ideological Diversity: Histori...         NaN
# 2662  Contextual Inference in Markets: On the Inform...         NaN
# 4696  Changes in U.S. Tariffs: The Role of Import Pr...         NaN
#
#      content_type                                       issue_url      pages  \
# 1166      Article  https://www.jstor.org/stable/10.2307/i40138653  3073-3114
# 2662      Article  https://www.jstor.org/stable/10.2307/i29730147  2127-2149
# 4696      Article    https://www.jstor.org/stable/10.2307/i300823  1015-1026
#
#       year  volume issue journal_x type  \
# 1166  2014     104    10       AER    N
# 2662  2008      98     5       AER    N
# 4696  1998      88     4       AER    N
#
#                                               authors_y  \
# 1166  Gentzkow, M.--a-- --b--\nShapiro, J.M.--a-- --...
# 2662                                       Kamenica, E.
# 4696                                        Irwin, D.A.
#
#                                                 title_y  \
# 1166  Competition and ideological diversity: Histori...
# 2662  Contextual inference in markets: On the inform...
# 4696  Changes in U.S. Tariffs: The Role of Import Pr...
#
#                      journal_y                      DOI  \
# 1166  American Economic Review  10.1257/aer.104.10.3073
# 2662  American Economic Review    10.1257/aer.98.5.2127
# 4696  American Economic Review                      NaN
#
#                                            affiliations  \
# 1166  a--University of Chicago Booth School of Busin...
# 2662  Graduate School of Business, University of Chi...
# 4696  Department of Economics, Dartmouth College, Ha...
#
#                                              abstract_y  \
# 1166  We study the competitive forces which shaped i...
# 2662  Context can influence decisions. This malleabi...
# 4696                                                NaN
#
#                                               citations  \
# 1166  Ackerberg, D.A., Rysman, M.|Unobserved Product...
# 2662  Anand, B.N., Shachar, R.|Brands as Beacons: A ...
# 4696  Anderson, J.E., Neary, J.P.|Measuring the Rest...
#
#                                           document type index keywords  \
# 1166   1850-1967(2006) The Historical Statistics of ...            NaN
# 2662   When and Why Variety Backfires(2005) Marketin...            NaN
# 4696   Percentage Distribution of Free, Specific, an...            NaN
#
#      author keywords
# 1166             NaN
# 2662             NaN
# 4696             NaN

# %%
Merged.at[4696,'document type']='Article'
Merged.at[2662,'document type']='Article'
Merged.at[1166,'document type']='Review'

# %%
pd.DataFrame(Merged[Merged['document type'].str.len()>100])

# %%
Merged.to_excel('C:\\Users\\sjwu1\\Journal_Data\\datadumps\\AER_M_sco_du.xlsx', index=False)
