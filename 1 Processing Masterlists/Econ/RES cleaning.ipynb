# %% [markdown]
# # RES Cleaning
#
# This notebook walks through how the RES articles were sorted into categories of articles and non-articles.
#
# ## Load Libraries

# %%
from tokenize import Ignore
from numpy import NaN
import numpy as np
import pandas as pd
from difflib import SequenceMatcher
import multiprocessing as mp
import time
from os import path
import os
from pathlib import Path
from PyPDF2 import PdfFileReader, PdfFileWriter
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Files
#
# Replace the file paths below to match local file paths. Note: comment out files that are not available eg: datadumps.

# %%
masters = pd.read_excel("C:\\Users\\sjwu1\\Journal_Data\\Master lists\\RES_master.xlsx")
pivots = pd.read_excel("C:\\Users\\sjwu1\\Journal_Data\\pivots\\RES_pivots.xlsx")
scopus = pd.read_excel("C:\\Users\\sjwu1\\Journal_Data\\Scopus\\RES_SCOPUS.xlsx")
datadump = pd.read_excel("C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_datadump.xlsx")

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Create File Names

# %%
authors="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_authors.xlsx"
non_auth="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_Nauthors.xlsx"
saveas="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_processed.xlsx"
reviews="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_reviews.xlsx"
misc="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_misc.xlsx"
conf="C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_conf.xlsx"

# %% [markdown]
# ## Some random checks on the masters list
#
# My assumption is that all data without author names must be miscellaneous documents like reports by the committee, forewords, front matters etc.. The goal of this notebook is to check for certain that all the documents without author names are actually miscellaneous documents and then classify them as miscellaneous (MISC). Hence, first we group everything the data by title to see the repetitive general content that can likely be removed.

# %%
pd.set_option('display.max_rows',masters.shape[0])
temp=masters['title'].str.lower().value_counts()
pd.DataFrame(temp[temp>1])
# Out:
#                                                                        title
# front matter                                                             297
# back matter                                                              278
# volume information                                                        73
# accepted manuscripts                                                       9
# periodicals received                                                       8
# books and monographs received                                              8
# editorial announcement                                                     8
# comment                                                                    5
# editorial                                                                  5
# introduction                                                               4
# i                                                                          3
# announcement                                                               3
# books and periodicals received                                             3
# economic thought in the soviet union                                       3
# materials for a theory of the duration of the process of tax shifting      2
# errata: neutral inventions and production functions                        2
# measuring the power of undervalued currency to stimulate exports           2
# empirical evidence on the acceleration principle                           2
# ii                                                                         2
# editorial announcements                                                    2
# new results in an old framework: comment on samuelson and modigliani       2
# the production function and the theory of capital                          2

# %% [markdown]
# Some repetitions are due to multiple comments. Now consider this list in absence of author names.

# %%
temp1=masters[masters['authors'].isna()]['title'].str.lower().value_counts()
pd.DataFrame(temp1)
# Out:
#                                                                                                            title
# front matter                                                                                                 297
# back matter                                                                                                  278
# volume information                                                                                            73
# accepted manuscripts                                                                                           9
# books and monographs received                                                                                  8
# periodicals received                                                                                           8
# books and periodicals received                                                                                 3
# announcement                                                                                                   3
# introduction                                                                                                   2
# errata: neutral inventions and production functions                                                            2
# periodicals                                                                                                    1
# corrections: the stability of the cournot oligopoly solution: a further generalization                         1
# errata: radner--efficiency prices for infinite horron production programmes                                    1
# correction: preferences, votes and the transitivity of majority decisions                                      1
# corrections: existence of a utility function to represent preferences                                          1
# correction: business saving and normal income                                                                  1
# corrections: a reply to professor chang                                                                        1
# index                                                                                                          1
# editorial                                                                                                      1
# author index                                                                                                   1
# subject index                                                                                                  1
# [correction]: entrepreneur's risk, lender's risk and investment                                                1
# economic thought in the soviet union                                                                           1
# errata: the explanation of productivity change                                                                 1
# errata                                                                                                         1
# errata: optimal savings under uncertainty                                                                      1
# erratum: the relationship between education and adult mortality in the united states adriana lleras-muney      1
# erratum: pecuniary externalities in economies with financial frictions                                         1
# corrigendum: signaling private choices                                                                         1
# erratum: the institutional causes of china's great famine, 1959-1961                                           1
# erratum: endogenous games and mechanisms: side payments among players                                          1
# erratum: sovereign debt without default penalties                                                              1
# erratum: market size, trade, and productivity                                                                  1
# corrigendum: consistent testing for stochastic dominance under general sampling schemes                        1
# erratum: who wants a good reputation?                                                                          1
# correction to "on optimal development in a multi-sector economy"                                               1
# editorial announcement                                                                                         1
# errata: variable returns to scale, non-uniqueness of equilibrium and the gains from international trade        1
# errata: volume information                                                                                     1
# index to volumes 47-56 1980-1989                                                                               1
# index to volumes 26-48 1959-1981                                                                               1
# european meeting of the econometric society athens, 1979                                                       1
# european meeting of the econometric society, vienna, 1977                                                      1
# a correction: interest in the theory of production                                                             1

# %%
#pd.DataFrame(masters[masters['content_type'].isna()]['title'].str.lower().value_counts())
#masters[masters['title'].str.lower().str.match(r'(^|: )report of the')]
#masters[masters['title'].str.lower().str.match(r'(^|.*: )report of the')]
#masters.loc[masters['title'].str.lower().str.match(r'^combined references(.*)')==True,'content_type']='MISC'

# this is a random panel for testing code
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, stable_url, authors, title, abstract, content_type, issue_url, pages]
# Index: []

# %% [markdown]
# Notice that titles with duplicates of greater or equal to 4 are miscellaneous items and so they are classified in bulk

# %%
temp2=masters[(masters['content_type'].isna()==True)]['title'].str.lower().value_counts()
removal=list(temp2[temp2>=4].index)
masters.loc[masters.title.str.lower().isin(removal),'content_type']='MISC'

# %% [markdown]
# Classify some titles via regex

# %%
masters.loc[masters['title'].str.lower().str.contains('books and periodicals')==True,'content_type']='MISC'
masters.loc[masters['title'].str.lower().str.match(r'^editorial')==True,'content_type']='MISC'
masters.loc[masters['title'].str.lower().str.match(r'^announcement')==True,'content_type']='MISC'
masters.loc[masters['title'].str.strip().str.len()<4,'content_type']='MISC'
#masters[masters.content_type=='MISC']

# %%
scopus.rename(columns = {'abstract':'abstract2', 'title':'title2', 'authors':'authors2'}, inplace = True)
scopus['pages2']=scopus['pages']
masters['pages']=masters['pages'].str.strip()  
masters.loc[masters.title.str.lower() == "back matter", 'pages'] = NaN

# %% [markdown]
# ## Classifying other content

# %%
sum(masters.content_type.isna())
#masters.shape[0]
# Out:
# 3259

# %%
masters.loc[masters['authors'].str.lower().str.match(r'^review(ed|) by(.*)')==True,'content_type']='Review' #reviews
masters.loc[(masters['title'].str.lower().str.match(r'(.*) by (.*)')==True) & (masters.authors.isna()==True),'content_type']='Review2' 
#possible reviews that don't have author names
masters[(masters['content_type']=='Review2') | (masters['content_type']=='Review')].shape[0] #reviews
# Out:
# 0

# %%
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*(:|\?).*comment.*$')==True,'content_type']='Comment'
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*comment$')==True,'content_type']='Comment'
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'(a further|further) comment.*$')==True,'content_type']='Comment'
masters[masters['content_type']=='Comment'].shape[0] 
#comments
# Out:
# 55

# %%
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*(:|\?) (|a )reply(| to.*)$')==True,'content_type']="Reply"
masters[masters['content_type']=='Reply'].shape[0]
# Out:
# 15

# %%
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*(:|\?|).*rejoinder.*$')==True,'content_type']="Rejoinder"
masters[masters['content_type']=='Rejoinder'].shape[0]
# Out:
# 9

# %%
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*: (|a )discussion$')==True,'content_type']="Discussion"
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'(^|a )discussion(|.*)$')==True,'content_type']="Discussion"
masters.loc[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*:.*(|a )discussion(|s)$')==True,'content_type']='Discussion'
masters[masters['content_type']=='Discussion'].shape[0]
# Out:
# 0

# %%
masters.loc[masters['content_type'].isna(),'content_type']="Article"
masters[masters['content_type']=='Article'].shape[0]
# Out:
# 3180

# %%
# block for testing regex patterns
#masters[masters['title'].str.lower().str.match(r'^\washington notes$')==True]
#masters[masters.content_type.isna() & masters.title.str.lower().str.match(r'.*(:|\?) (|a )rejoinder.*$')==True]
#masters[masters.content_type=='Discussion'].shape[0]

# %% [markdown]
# ## Consider the pivots file
# At times, conference papers are structured differently to normal articles. Hence, it may be necessary to distinguish conference papers from common articles. The next code block separates special issues (S) from normal issues (N)

# %%
pivots.loc[pivots.Jstor_issue_text.str.lower().str.match(r'(.*)(supplement|proceedings|annual meeting|survey)(.*)'),'type']="S"
pivots.loc[pivots.type.isna(),'type']='N'
pivots.type.value_counts()
# Out:
# N    309
# Name: type, dtype: int64

# %% [markdown]
# Merge masterlist and pivot list

# %%
result = pd.merge(masters, pivots[['issue_url','year','volume','issue','journal','type']], how="left", on=["issue_url", "issue_url"])

# %% [markdown]
# ## Summary

# %%
pd.DataFrame(result.content_type.value_counts())
# Out:
#            content_type
# Article            3180
# MISC                711
# Comment              55
# Reply                15
# Rejoinder             9

# %%
pd.DataFrame(result[result.year>1939].content_type.value_counts())
# Out:
#            content_type
# Article            3036
# MISC                670
# Comment              54
# Reply                11
# Rejoinder             7

# %%
pd.DataFrame(result[(result.year>1939) & (result.year<2011)].content_type.value_counts())
# Out:
#            content_type
# Article            2608
# MISC                606
# Comment              54
# Reply                11
# Rejoinder             7

# %%
result.to_excel(saveas, index=False)

# %% [markdown]
# ## This section aims to match up Scopus records and Jstor articles
# If an article's affiliations, citations or abstracts are recorded on Scopus. matching up the Scopus data is useful for comparing the textual accuracy of OCR parsers. I use volume, issue, year and page numbers which are common to both the scopus data and the Jstor metadata to match articles.
#
# Then I use a sequence comparison between the journal titles of the matched articles to decide if the scopus data has been matched correctly. If the match ratio is below 70%, the title is investigated and if wrong, the scopus data for that matched article is either corrected or discarded.
#
# The next section reads in the processed data previously saved. Please make sure the path in the variable 'cleaned' matches the file path on your local machine.

# %%
cleaned=pd.read_excel('C:\\Users\\sjwu1\\Journal_Data\\datadumps\\processed\\RES_processed.xlsx')
cleaned['volume']=cleaned['volume'].astype(int)
scopus['pages']=scopus['pages'].str.strip()
#print(scopus.shape)
#cleaned.year.unique()

# %% [markdown]
# This is the number of entries on Scopus

# %%
#Note that we only have data up to 2018 in the masterlists because of the moving wall on JSTOR
print(sum(scopus['year']<2019))
print(scopus.shape)
# Out:
# 2844
# (2992, 14)

# %% [markdown]
# Merge on year, issue, volume and pages.

# %%
Merged=pd.merge(cleaned, scopus, on=['year', 'issue','volume','pages'], how='left')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Check how many of the scopus entries matched.

# %%
sum(Merged['title_y'].isna()==False)
# Out:
# 2698

# %% [markdown]
# Quick maths: There are 3970 total documents for Review of econ. studies (RES) between, 3180 of these are actual articles. Scopus matched up to 2698 entries in the RES masterlist. This means there is 146 entries in Scopus that do not match up to something in the masterlists. And atleast 1272 entries in the masterlist without scopus records. Conclusion: 60% coverage ain't too bad! Now let's see if there is actual references and affiliations or did Scopus just bullshit us all.
#
# Consider the titles that have a less than 70% match.

# %%
count=0
for m in Merged.index:
    
    if(pd.isna(Merged.iloc[m]['title_y'])==False):
        ratio=SequenceMatcher(None, Merged.iloc[m]['title_x'].lower(), Merged.iloc[m]['title_y'].lower()).ratio()
        if((ratio<0.7) & (Merged.iloc[m]['content_type']!='MISC')):
            print(Merged.iloc[m]['year'])
            print(ratio)
            count+=1
            if pd.isna(Merged.iloc[m]['authors_x'])==False:
                A_ratio=SequenceMatcher(None, Merged.iloc[m]['authors_x'].lower(), Merged.iloc[m]['authors_y'].lower()).ratio()
                print(A_ratio)
            else:
                print('Author issue')
                print(Merged.iloc[m]['authors_x'])
                print(Merged.iloc[m]['authors_y'])
            print(Merged.iloc[m]['stable_url'])
            print('vol: '+str(Merged.iloc[m]['volume']))
            print('issue: '+str(Merged.iloc[m]['issue']))
            print('pages: '+Merged.iloc[m]['pages'])
            print('jstor: '+Merged.iloc[m]['title_x'])
            print('scopus: '+Merged.iloc[m]['title_y'])
            print('jstor: '+str(Merged.iloc[m]['authors_x']))
            print('scopus: '+str(Merged.iloc[m]['authors_y']))
            print('scopus index: '+str(scopus[scopus['title']==Merged.iloc[m]['title_y']].index))
            print(m)
            print()
print(count)
# Out:
# 2016
# 0.6098654708520179
# Author issue
# nan
# Meng, X.--a--
# Qian, N.--b--
# Yared, P.--c--
# https://www.jstor.org/stable/43869567
# vol: 83
# issue: 3.0
# pages: 1296
# jstor: Erratum: The Institutional Causes of China's Great Famine, 1959-1961
# scopus: Erratum: "The institutional causes of China's Great Famine, 1959-1961" [Review of Economic Studies, 82, 4, (2015), (1568-1611)]. Doi: 10.1093/restud/rdv016
# jstor: nan
# scopus: Meng, X.--a--
# Qian, N.--b--
# Yared, P.--c--
# scopus index: Int64Index([2694], dtype='int64')
# 166
#
# 2013
# 0.5858585858585859
# 0.4444444444444444
# https://www.jstor.org/stable/43551460
# vol: 80
# issue: 3.0
# pages: 1178-1214
# jstor: Estimating Ethnic Preferences Using Ethnic Housing Quotas in Singapore
# scopus: Estimating ethnic preferences
# jstor: MAISY WONG
# scopus: Wong, M.
# scopus index: Int64Index([2474], dtype='int64')
# 341
#
# 2013
# 0.5991189427312775
# Author issue
# nan
# nan
# https://www.jstor.org/stable/43551504
# vol: 80
# issue: 2.0
# pages: 840-843
# jstor: Erratum: Endogenous Games and Mechanisms: Side Payments among Players
# scopus: Erratum to endogenous games and mechanisms: Side payments among players by matthew o. jackson and simonwilkie, review of economic studies, 72, 543-566 (2005)]
# jstor: nan
# scopus: nan
# scopus index: Int64Index([2491], dtype='int64')
# 357
#
# 2010
# 0.6
# Author issue
# nan
# nan
# https://www.jstor.org/stable/40587632
# vol: 77
# issue: 1.0
# pages: 415
# jstor: Erratum: Sovereign Debt without Default Penalties
# scopus: Erratum to Sovereign debt without default penalties [The Review of Economic Studies (2009), 76, 4, (1295 1318)]
# jstor: nan
# scopus: nan
# scopus index: Int64Index([2341], dtype='int64')
# 550
#
# 2008
# 0.5555555555555556
# Author issue
# nan
# Melitz, M.J., Ottaviano, G.I.P.
# https://www.jstor.org/stable/20185062
# vol: 75
# issue: 3.0
# pages: 985
# jstor: Erratum: Market Size, Trade, and Productivity
# scopus: Erratum: Market size, trade, and productivity (Review of Economic Studies vol. 75 (1) 10.111/j1467-937x.2007.00463.x)
# jstor: nan
# scopus: Melitz, M.J., Ottaviano, G.I.P.
# scopus index: Int64Index([2412], dtype='int64')
# 638
#
# 2008
# 0.6274509803921569
# Author issue
# nan
# nan
# https://www.jstor.org/stable/4626198
# vol: 75
# issue: 1.0
# pages: 333-337
# jstor: Corrigendum: Consistent Testing for Stochastic Dominance under General Sampling Schemes
# scopus: Erratum: Consistent Testing for Stochastic Dominance under General Sampling Schemes" (The Review of Economic Studies vol. 72 (735-765) 10.1111/J.1467-937X.2005.00350.X)
# jstor: nan
# scopus: nan
# scopus index: Int64Index([2435], dtype='int64')
# 667
#
# 1993
# 0.24242424242424243
# 0.21052631578947367
# https://www.jstor.org/stable/2298057
# vol: 60
# issue: 2.0
# pages: 249-282
# jstor: A Model of Intertemporal Asset Prices Under Asymmetric Information
# scopus: How fast do rational agents learn
# jstor: Jiang Wang
# scopus: Vives, X.
# scopus index: Int64Index([1608], dtype='int64')
# 1380
#
# 1987
# 0.29411764705882354
# 0.2631578947368421
# https://www.jstor.org/stable/2297510
# vol: 54
# issue: 2.0
# pages: 175-192
# jstor: Bargaining with Two-sided Incomplete Information: An Infinite Horizon Model with Alternating Offers
# scopus: On Bayesian Implementable Allocations
# jstor: Kalyan Chatterjee and Larry Samuelson
# scopus: Palfrey, T.R.--a--
# Srivastava, S.--b--
# scopus index: Int64Index([1503], dtype='int64')
# 1726
#
# 1987
# 0.29411764705882354
# 0.23529411764705882
# https://www.jstor.org/stable/2297511
# vol: 54
# issue: 2.0
# pages: 193-208
# jstor: On Bayesian Implementable Allocations
# scopus: Bargaining With Two-Sided Incomplete Information: An Infinite Horizon Model With Alternating Offers
# jstor: Thomas R. Palfrey and Sanjay Srivastava
# scopus: Chatterjee, K., Samuelson, L.
# scopus index: Int64Index([1505], dtype='int64')
# 1727
#
# 1984
# 0.23300970873786409
# 0.16279069767441862
# https://www.jstor.org/stable/2297779
# vol: 51
# issue: 4.0
# pages: 559-578
# jstor: Earnings, Unemployment, and the Allocation of Time Over Time
# scopus: Acyclic choice without the pareto principle
# jstor: Kenneth Burdett, Nicholas M. Kiefer, Dale T. Mortensen and George R. Neumann
# scopus: Kelsey, D.
# scopus index: Int64Index([1252], dtype='int64')
# 1885
#
# 1984
# 0.28125
# 0.46296296296296297
# https://www.jstor.org/stable/2297781
# vol: 51
# issue: 4.0
# pages: 595-614
# jstor: A Comparison of Posted-Offer and Double-Auction Pricing Institutions
# scopus: Earnings, unemployment, and the allocation of time over time
# jstor: Jon Ketcham, Vernon L. Smith and Arlington W. Williams
# scopus: Ketcham, J.--a--
# Smith, V.L.--a--
# Williams, A.W.--b--
# scopus index: Int64Index([1253, 1284], dtype='int64')
# 1888
#
# 1977
# 0.39416058394160586
# 0.21052631578947367
# https://www.jstor.org/stable/2296898
# vol: 44
# issue: 3.0
# pages: 393-406
# jstor: The Noisy Monopolist: Imperfect Information, Price Dispersion and Price Discrimination
# scopus: Symposium on economics of information: Introduction
# jstor: Steven Salop
# scopus: Stiglitz, J.E.--a-- --b--
# scopus index: Int64Index([1170], dtype='int64')
# 2379
#
# 1972
# 0.24761904761904763
# 0.6666666666666666
# https://www.jstor.org/stable/2296360
# vol: 39
# issue: 3.0
# pages: 297-302
# jstor: The Optimal Linear Income-tax
# scopus: First version received March 1971; final version received August 1971 (Eds.)
# jstor: Eytan Sheshinski
# scopus: Sheshinski, E.
# scopus index: Int64Index([956], dtype='int64')
# 2729
#
# 1971
# 0.15517241379310345
# 0.631578947368421
# https://www.jstor.org/stable/2296621
# vol: 38
# issue: 1.0
# pages: 45-46
# jstor: [The Existence and Persistence of Cycles in a Non-linear Model: Kaldor's 1940 Model Re-examined]: A Comment
# scopus: A comment
# jstor: N. Kaldor
# scopus: Kaldor, N.
# scopus index: Int64Index([17, 309, 311, 433, 1029], dtype='int64')
# 2802
#
# 1970
# 0.3684210526315789
# 0.72
# https://www.jstor.org/stable/2296731
# vol: 37
# issue: 3.0
# pages: 439
# jstor: [Comment on Garegnani]: A Reply
# scopus: A reply
# jstor: P. Garegnani
# scopus: Garegnani, P.
# scopus index: Int64Index([57, 550, 556, 762], dtype='int64')
# 2838
#
# 1970
# 0.17391304347826086
# 0.7272727272727273
# https://www.jstor.org/stable/2296732
# vol: 37
# issue: 3.0
# pages: 441-445
# jstor: Expedient Choice of Transforms in Phase-Diagramming
# scopus: Notes and comments
# jstor: J. Conlisk and R. Ramanathan
# scopus: Conlisk, J., Ramanathan, R.
# scopus index: Int64Index([747], dtype='int64')
# 2839
#
# 1969
# 0.6727272727272727
# 0.5714285714285714
# https://www.jstor.org/stable/2296467
# vol: 36
# issue: 4.0
# pages: 399-415
# jstor: On Experimental Research in Oligopoly
# scopus: Symposium on experimental economics on experimental research in oligopoly
# jstor: J. W. Friedman
# scopus: Friedman, J.W.
# scopus index: Int64Index([801], dtype='int64')
# 2878
#
# 1969
# 0.34782608695652173
# Author issue
# nan
# Hadar, J.--a--
# Hillinger, C.--b--
# https://www.jstor.org/stable/2296475
# vol: 36
# issue: 4.0
# pages: 519-525
# jstor: Errata: Neutral Inventions and Production Functions
# scopus: Imperfect competition with unknown demand
# jstor: nan
# scopus: Hadar, J.--a--
# Hillinger, C.--b--
# scopus index: Int64Index([814], dtype='int64')
# 2886
#
# 1969
# 0.3595505617977528
# Author issue
# nan
# Britto, R.
# https://www.jstor.org/stable/2296436
# vol: 36
# issue: 3.0
# pages: 395-398
# jstor: Errata: The Explanation of Productivity Change
# scopus: Note and comments: On putty-clay: A comment
# jstor: nan
# scopus: Britto, R.
# scopus index: Int64Index([816], dtype='int64')
# 2898
#
# 1966
# 0.6796116504854369
# 0.64
# https://www.jstor.org/stable/2974427
# vol: 33
# issue: 4.0
# pages: 307-308
# jstor: New Results in an Old Framework: Comment on Samuelson and Modigliani
# scopus: Comment on samuelson and modigliani
# jstor: Joan Robinson
# scopus: Robinson, J.
# scopus index: Int64Index([566], dtype='int64')
# 3032
#
# 1966
# 0.46616541353383456
# 0.7457627118644068
# https://www.jstor.org/stable/2974429
# vol: 33
# issue: 4.0
# pages: 321-330
# jstor: Marginal Productivity and the Macro-Economic Theories of Distribution: Reply to Pasinetti and Robinson
# scopus: Reply to pasinetti and robinson
# jstor: P. Samuelson and F. Modigliani
# scopus: Samuelson, P., Modigliani, F.
# scopus index: Int64Index([590], dtype='int64')
# 3034
#
# 1961
# 0.6987951807228916
# 0.45454545454545453
# https://www.jstor.org/stable/2295705
# vol: 28
# issue: 2.0
# pages: 77-88
# jstor: I. The Story of a Mare's Nest
# scopus: Prices and the turnpike: i. the story of a mare's nest
# jstor: J. R. Hicks
# scopus: Hicks, J.R.
# scopus index: Int64Index([734], dtype='int64')
# 3245
#
# 1960
# 0.6862745098039216
# 0.5
# https://www.jstor.org/stable/2296246
# vol: 28
# issue: 1.0
# pages: 29-31
# jstor: Monetary and Value Theory: Comments
# scopus: A symposium on monetary theory: monetary and value theory: comments
# jstor: W. J. Baumol
# scopus: Baumol, W.J.
# scopus index: Int64Index([382], dtype='int64')
# 3259
#
# 1953
# 0.25
# 0.45454545454545453
# https://www.jstor.org/stable/2295775
# vol: 21
# issue: 3.0
# pages: 218-221
# jstor: [A Note on a Point in Value and Capital]: A Reply
# scopus: A reply
# jstor: J. R. Hicks
# scopus: Hicks, J.R.
# scopus index: Int64Index([57, 550, 556, 762], dtype='int64')
# 3472
#
# 1953
# 0.34375
# 0.72
# https://www.jstor.org/stable/2295776
# vol: 21
# issue: 3.0
# pages: 222
# jstor: [A Note on a Point in Value and Capital]: A Rejoinder
# scopus: A rejoinder
# jstor: M. Morishima
# scopus: Morishima, M.
# scopus index: Int64Index([135, 157, 542, 546], dtype='int64')
# 3473
#
# 1953
# 0.19130434782608696
# 0.47619047619047616
# https://www.jstor.org/stable/2295778
# vol: 21
# issue: 3.0
# pages: 229-231
# jstor: [The Role of National Income Estimates in the Statistical Policy of an Underdeveloped Area]: A Rejoinder
# scopus: A rejoinder
# jstor: Dudley Seers
# scopus: Seers, D.
# scopus index: Int64Index([135, 157, 542, 546], dtype='int64')
# 3475
# 1946
# 0.22784810126582278
# 0.5
# https://www.jstor.org/stable/2296089
# vol: 14
# issue: 2.0
# pages: 95-97
# jstor: [A New View of the Economics of International Readjustment]: A Comment
# scopus: A comment
# jstor: R. F. Harrod
# scopus: Harrod, R.F.
# scopus index: Int64Index([17, 309, 311, 433, 1029], dtype='int64')
# 3653
#
# 1945
# 0.21818181818181817
# Author issue
# nan
# Barna, T.
# https://www.jstor.org/stable/2296042
# vol: 13
# issue: 2.0
# pages: 84-108
# jstor: Periodicals
# scopus: Rebuilding london: A survey in stepney, 1946
# jstor: nan
# scopus: Barna, T.
# scopus index: Int64Index([316], dtype='int64')
# 3669
#
# 1940
# 0.23684210526315788
# 0.45454545454545453
# https://www.jstor.org/stable/2967420
# vol: 8
# issue: 1.0
# pages: 64-65
# jstor: [Complementarity and Interrelations of Shifts in Demand]: A Comment
# scopus: A comment
# jstor: J. R. Hicks
# scopus: Hicks, J.R.
# scopus index: Int64Index([17, 309, 311, 433, 1029], dtype='int64')
# 3760
#
# 1940
# 0.6176470588235294
# 0.48
# https://www.jstor.org/stable/2967407
# vol: 7
# issue: 3.0
# pages: 196-201
# jstor: A Note on the Theory of the Forward Market
# scopus: A symposium on the theory of the forward market: I. a note on the theory of the forward market
# jstor: Nicholas Kaldor
# scopus: Kaldor, N.
# scopus index: Int64Index([0], dtype='int64')
# 3770
#
# 1940
# 0.5423728813559322
# 0.5384615384615384
# https://www.jstor.org/stable/2967409
# vol: 7
# issue: 3.0
# pages: 202-205
# jstor: Mr. Kaldor on the Forward Market
# scopus: A symposium on the theory of the forward market: iii. mr. kaldor on the forward market
# jstor: R. G. Hawtrey
# scopus: Hawtrey, R.G.
# scopus index: Int64Index([5], dtype='int64')
# 3772
#
# 1938
# 0.27450980392156865
# 0.5925925925925926
# https://www.jstor.org/stable/2967530
# vol: 5
# issue: 2.0
# pages: 152-157
# jstor: [The Power of Undervalued Currency]: A Reply
# scopus: A reply
# jstor: Victor Edelberg
# scopus: Edelberg, V.
# scopus index: Int64Index([57, 550, 556, 762], dtype='int64')
# 3840
#
# 1936
# 0.37333333333333335
# 0.5925925925925926
# https://www.jstor.org/stable/2967506
# vol: 3
# issue: 2.0
# pages: 147-148
# jstor: I. Note on Dr. Machlup's Article
# scopus: Further notes on elasticity of substitution
# jstor: Milton Friedman
# scopus: Friedman, M.
# scopus index: Int64Index([112, 114], dtype='int64')
# 3896
#
# 1936
# 0.5631067961165048
# 0.5
# https://www.jstor.org/stable/2967508
# vol: 3
# issue: 2.0
# pages: 150-151
# jstor: III. The Question of Symmetry
# scopus: Further notes on elasticity of substitution: iii. the question of symmetry
# jstor: A. P. Lerner
# scopus: Lerner, A.P.
# scopus index: Int64Index([97], dtype='int64')
# 3898
#
# 1936
# 0.07692307692307693
# 0.32
# https://www.jstor.org/stable/2967509
# vol: 3
# issue: 2.0
# pages: 151-152
# jstor: IV. Reply
# scopus: Further notes on elasticity of substitution
# jstor: Fritz Machlup
# scopus: Lerner, A.P.
# scopus index: Int64Index([112, 114], dtype='int64')
# 3899
#
# 1935
# 0.24074074074074073
# 0.3333333333333333
# https://www.jstor.org/stable/2967557
# vol: 2
# issue: 2.0
# pages: 104-116
# jstor: A Proposal for Making Monetary Management Effective in the United States
# scopus: The “Chicago Plan” of banking reform
# jstor: Albert G. Hart
# scopus: Hart, A.G.
# scopus index: Int64Index([132], dtype='int64')
# 3921
#
# 1935
# 0.688
# 0.41379310344827586
# https://www.jstor.org/stable/2967558
# vol: 2
# issue: 2.0
# pages: 117-121
# jstor: The Application of the Proposals in England
# scopus: The chicago plan of banking reform: Ii the application of the proposals in england
# jstor: Charles H. Walker
# scopus: Walker, C.H.
# scopus index: Int64Index([124], dtype='int64')
# 3922
#
# 1935
# 0.3492063492063492
# 0.5
# https://www.jstor.org/stable/2967562
# vol: 2
# issue: 2.0
# pages: 152-154
# jstor: [Economic Theory and Socialist Economy]: A Rejoinder
# scopus: A rejoinder
# jstor: A. P. Lerner
# scopus: Lerner, A.P.
# scopus index: Int64Index([135, 157, 542, 546], dtype='int64')
# 3926
#
# 1934
# 0.6666666666666666
# 0.3333333333333333
# https://www.jstor.org/stable/2967547
# vol: 2
# issue: 1.0
# pages: 18-30
# jstor: Taxation and Production: The Wicksell Analysis
# scopus: Taxation and production
# jstor: Ursula K. Webb
# scopus: Webb, U.K.
# scopus index: Int64Index([150], dtype='int64')
# 3932
#
# 1934
# 0.5
# 0.5
# https://www.jstor.org/stable/2967620
# vol: 1
# issue: 2.0
# pages: 141-143
# jstor: Taxation and Returns: A Rejoinder
# scopus: A rejoinder
# jstor: L. M. Fraser
# scopus: Fraser, L.M.
# scopus index: Int64Index([135, 157, 542, 546], dtype='int64')
# 3957
#
# 40

# %% [markdown]
# This code is used to search for title or author matches in the jstor masterlists to find entries to correct the scopus data.

# %%
#search='Bargaining With Two-Sided Incomplete Information: An Infinite Horizon Model With Alternating Offers'
#search='Acyclic choice without the pareto principle'
#search='On Bayesian Implementable Allocations'
#search='How fast do rational agents learn'
search='A. P. lerner'
for i in cleaned.index:
    if pd.isna(cleaned.iloc[i]['authors'])==False:
        c=SequenceMatcher(None, cleaned.iloc[i]['authors'].lower(), search).ratio()
        if c>0.7:
            print(cleaned.iloc[i])

# %% [markdown]
# Now let's do some manual corrections.

# %%
#scopus index 1170 wrong citation altogether in scopus drop from scopus set
scopus.drop(1170, axis=0, inplace=True) #uncomment later for full run
#these recorded incorrect pages
scopus.loc[1252,'pages']='693-699'
scopus.loc[1505,'pages']='175-192'
scopus.loc[1503,'pages']='193-208'
scopus.loc[1608, 'pages']='329-347'

# %% [markdown]
# There are some issues in the masterlists caused by the scraper logic. If there was a NaN in the page reference, the previous entries' page numbers were used which duplicated the uniqueness of year-volume-issue-pages. This is to be corrected now.

# %%
#get a dataframe of counts
x=pd.DataFrame(cleaned[['year','volume','issue','pages']].value_counts()).reset_index()
k=x[x[0]>1]
k
# Out:
#     year  volume  issue                                 pages  0
# 0   1945      13    2.0                                84-108  3
# 1   1964      31    3.0   220) https://doi.org/10.2307/229591  3
# 2   1987      54    4.0                               701-703  2
# 3   1982      49    4.0                               669-674  2
# 4   1934       1    3.0                                   236  2
# 5   1941       8    3.0                                   188  2
# 6   1969      36    3.0                               395-398  2
# 7   1996      63    4.0                               677-680  2
# 8   1966      33    4.0                                  i-iv  2
# 9   1995      62    4.0                               665-668  2
# 10  1969      36    4.0                               519-525  2
# 11  1997      64    4.0                               717-720  2
# 12  1998      65    4.0                               867-871  2
# 13  1994      61    4.0                               795-799  2
# 14  1981      48    4.0                               677-681  2
# 15  1988      55    4.0                               669-673  2
# 16  1990      57    4.0                               709-713  2
# 17  1970      37    1.0  i-iv) https://doi.org/10.2307/229649  2
# 18  1936       3    3.0                                   235  2
# 19  1967      34    2.0                                  i-iv  2
# 20  1984      51    4.0                               700-703  2
# 21  2005      72    4.0                             1201-1205  2
# 22  1940       7    2.0                                   138  2
# 23  2003      70    4.0                               921-924  2
# 24  1999      66    4.0                               995-999  2
# 25  1968      35    2.0                                  i-iv  2
# 26  1992      59    1.0   227) https://doi.org/10.2307/229793  2
# 27  2004      71    4.0                             1241-1245  2
# 28  2001      68    4.0                               907-910  2
# 29  1944      12    2.0                               121-122  2
# 30  1991      58    5.0                             1045-1050  2
# 31  1993      60    4.0                               961-965  2
# 32  1989      56    4.0                               645-649  2
# 33  1983      50    4.0                               757-761  2
# 34  1985      52    4.0                               725-729  2
# 35  2002      69    4.0                             1019-1022  2

# %% [markdown]
# Now let's remove the duplicates and text issues. The first if statement resets the page numbers to remove leftover doi references. The second searches for duplicates and if it is a "Front Matter" or duplicates the pages of an actual article then the pages are set to None.

# %%
count=0
for i in cleaned.index:
    m=cleaned.iloc[i]
    if 'http' in str(cleaned.loc[i, 'pages']):
        cleaned.loc[i, 'pages']=cleaned.loc[i, 'pages'].split(')')[0]
    if sum((k['year']==m['year']) & (k['volume']==m['volume']) & (k['issue']==m['issue']) & (k['pages']==m['pages']))==1:
        if m.title.strip()=='Front Matter':
            cleaned.loc[i,'pages']=None
        if pd.isna(m.authors)==False:
            temp=cleaned[(cleaned['year']==m['year']) & (cleaned['volume']==m['volume']) & (cleaned['issue']==m['issue']) & (cleaned['pages']==m['pages'])]
            for j in temp.index:
                if pd.isna(temp.loc[j, 'authors'])==True:
                    cleaned.loc[j,'pages']=None
        count+=1
        #print(m)

print(count)
# Out:
# 69

# %% [markdown]
# Re-merge the scopus data and the cleaned masterlists

# %%
Merged=pd.merge(cleaned, scopus, on=['year', 'issue','volume','pages'], how='left')

# %% [markdown]
# Check for whether there is an issue in document type and correct it.

# %%
pd.DataFrame(Merged[Merged['document type'].str.len()>100])
Merged.loc[170,'document_type']='Article'
Merged.loc[174,'document_type']='Article'

# %% [markdown]
# Note: the datadump does not have any references for res. So merged data is saved directly after renaming.

# %%
Merged.rename(columns = {'authors_x':'Jstor_authors', 'title_x':'Jstor_title', 'abstract_x':'Jstor_abstract', 'journal_x':'Jstor_journal', 'authors_y':'scopus_authors','title_y':'scopus_title', 'abstract_y':'scopus_abstract', 'journal_y':'scopus_journal' }, inplace = True)

# %% [markdown]
# saving...

# %%
Merged.to_excel('C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_M_sco_du.xlsx', index=False)

# %% [markdown]
# # Merged dataset field description
#
# This is a description of fields in the Merged dataset that combines JPE masterlist, pivot list, Scopus data pre-2018. The Merged dataset is stored in RES_M_sco_du.xlsx. Note that RES does not contain any reference data scraped from JSTOR.
#
#     'stable_url' : JSTOR url for article
#     'Jstor_authors' : Author names recorded by JSTOR
#     'Jstor_title' : Title of article recorded by JSTOR
#     'Jstor_abstract' : abstract recorded by JSTOR nb: this is blank at the moment
#     'content_type' : Article type determined during cleaning. Includes MISC for miscellaneous, Reviews, Note, Comment, Rejoinder and Article categorizations
#     'issue_url' : url of issue article belongs to on JSTOR
#     'pages' : pages as recorded by JSTOR
#     'year' : Year of publication recorded by JSTOR
#     'volume' : Volume of article recorded by JSTOR
#     'issue' : issue of article recorded by JSTOR
#     'Jstor_journal' : journal name JSTOR
#     'type' : Type of issue determined during cleaning. S for special issue. N for normal issue
#     'scopus_authors' : Author names recorded by Scopus
#     'scopus_title' : Title recorded by Scopus
#     'scopus_journal' : Journal name recorded by Scopus
#     'DOI' : DOI recorded by scopus
#     'affiliations' : affiliations of authors as recorded by scopus
#     'scopus_abstract' : abstract of article recorded by scopus
#     'citations' : citations of article recorded by scopus
#     'document type' : Article type recorded by scopus, may differ from that in cleaning
#     'index keywords' : from scopus
#     'author keywords' : from scopus

# %%
Merged=pd.read_excel('C:\\Users\\sjwu1\\Journal_Data\\datadumps\\RES_M_sco_du.xlsx')

# %%
inv=Merged[(Merged['year']<=1971) & (Merged['year']>=1940)&(Merged['content_type']!='MISC')&(Merged['content_type']!='Review')&(Merged['content_type']!='Discussion')]
inv.shape
# Out:
# (805, 24)

# %%
Merged.content_type.unique()
# Out:
# array(['MISC', 'Article', 'Comment', 'Reply', 'Rejoinder'], dtype=object)

# %% [markdown]
# ### Plots of counts
# Exploratory analysis of available data in scopus and datadumps.

# %%
plt.rcParams["figure.figsize"] = (25, 10)
dta=Merged[(Merged['content_type']!='MISC')]['year'].value_counts()
plt.bar(dta.index,dta, label='Articles', alpha=0.4)
dta2=Merged[(Merged['affiliations'].isnull()==False) & (Merged['content_type']!='MISC')]['year'].value_counts()
dta3=scopus[(scopus['citations'].isnull()==False) & (scopus['year']>2018)]['year'].value_counts()
plt.bar(dta2.index, dta2, label='Scopus coverage', alpha=0.4)
plt.bar(dta3.index, dta3, label='Additional Scopus coverage', alpha=0.4)
plt.title('Barchart of RES Scopus coverage for affiliations overlaying counts of non-miscellaneous documents in \nRES for each year between 1940 and 2018 (inclusive). Note that JSTOR coverage ends at 2018.', fontsize=20)
plt.xticks(np.arange(1930, 2030, 10))
plt.legend(prop={'size': 20})

# %% [markdown]
# Some years of coverage are almost complete, it may not be necessary to use OCR to extract affiliations. I propose there's only a real point to set up the OCR if there if more than 80% of the articles in a issue are missing affiliations.
#
# Consider the missing counts of articles per issue by getting counts of total per issue and scopus affiliations per issue.

# %%
sc_aff=Merged[(Merged['affiliations'].isnull()==False) & (Merged['content_type']!='MISC')][['year','volume','issue']].value_counts()
js_aff=Merged[(Merged['content_type']!='MISC')][['year','volume','issue']].value_counts()

# %% [markdown]
# Create a dataframe of counts of missing article affiliations per issue and merge that with the total articles per issue and calculate the percentage of missing article affiliations.

# %%
difference=pd.DataFrame(js_aff-sc_aff).reset_index()  #get difference
difference=pd.merge(difference, js_aff.reset_index(), on=['year', 'issue','volume'], how='right').sort_values(['year','issue','volume'])
difference['retrieval_req']=difference['0_x']/difference['0_y']
difference.rename(columns = {'0_x':'missing', '0_y':'total'}, inplace = True)
difference['retrieval_req'] = difference['retrieval_req'].fillna(1)

difference[difference['year']>=1940] # if missing is NaN that means the whole issue is missing.
# Out:
#      year  volume  issue  missing  total  retrieval_req
# 242  1940       8    1.0      5.0      8       0.625000
# 301  1940       7    2.0      2.0      5       0.400000
# 244  1940       7    3.0      4.0      8       0.500000
# 281  1941       9    1.0      3.0      6       0.500000
# 266  1941       8    2.0      1.0      7       0.142857
# 296  1941       8    3.0      2.0      5       0.400000
# 258  1942      10    1.0      3.0      7       0.428571
# 293  1942       9    2.0      1.0      5       0.200000
# 284  1943      11    1.0      3.0      6       0.500000
# 299  1943      10    2.0      0.0      5       0.000000
# 302  1944      12    1.0      1.0      4       0.250000
# 297  1944      11    2.0      2.0      5       0.400000
# 255  1944      12    2.0      3.0      7       0.428571
# 304  1945      13    1.0      3.0      4       0.750000
# 279  1945      13    2.0      1.0      6       0.166667
# 252  1946      14    1.0      3.0      7       0.428571
# 294  1946      14    2.0      1.0      5       0.200000
# 214  1947      15    1.0      4.0      9       0.444444
# 278  1947      15    2.0      2.0      6       0.333333
# 295  1948      16    1.0      1.0      5       0.200000
# 275  1949      17    1.0      2.0      6       0.333333
# 276  1949      16    2.0      1.0      6       0.166667
# 274  1949      17    2.0      1.0      6       0.166667
# 298  1949      16    3.0      2.0      5       0.400000
# 247  1949      17    3.0      3.0      7       0.428571
# 300  1950      18    1.0      1.0      5       0.200000
# 237  1950      18    2.0      4.0      8       0.500000
# 241  1950      18    3.0      2.0      8       0.250000
# 240  1951      19    1.0      NaN      8       1.000000
# 253  1951      19    2.0      2.0      7       0.285714
# 220  1952      20    1.0      5.0      8       0.625000
# 227  1952      20    2.0      3.0      8       0.375000
# 286  1952      19    3.0      3.0      6       0.500000
# 179  1952      20    3.0      4.0     10       0.400000
# 291  1953      21    1.0      2.0      6       0.333333
# 251  1953      21    2.0      4.0      7       0.571429
# 77   1953      21    3.0      8.0     13       0.615385
# 186  1954      22    1.0      4.0     10       0.400000
# 285  1954      22    2.0      0.0      6       0.000000
# 207  1954      22    3.0      2.0      9       0.222222
# 192  1955      23    1.0      2.0      9       0.222222
# 217  1955      23    2.0      4.0      9       0.444444
# 140  1955      23    3.0      4.0     11       0.363636
# 191  1956      24    1.0      5.0      9       0.555556
# 190  1957      25    1.0      8.0      9       0.888889
# 249  1957      24    2.0      2.0      7       0.285714
# 185  1957      24    3.0      5.0     10       0.500000
# 200  1958      26    1.0      3.0      9       0.333333
# 188  1958      25    2.0      3.0      9       0.333333
# 195  1958      25    3.0      3.0      9       0.333333
# 248  1959      27    1.0      1.0      7       0.142857
# 290  1959      26    2.0      3.0      6       0.500000
# 254  1959      26    3.0      5.0      7       0.714286
# 205  1960      28    1.0      3.0      9       0.333333
# 203  1960      27    2.0      4.0      9       0.444444
# 204  1960      27    3.0      4.0      9       0.444444
# 229  1961      29    1.0      1.0      8       0.125000
# 206  1961      28    2.0      4.0      9       0.444444
# 287  1961      28    3.0      NaN      6       1.000000
# 283  1962      29    2.0      4.0      6       0.666667
# 189  1962      29    3.0      3.0      9       0.333333
# 173  1962      29    4.0      3.0     10       0.300000
# 174  1963      30    1.0      4.0     10       0.400000
# 175  1963      30    2.0      3.0     10       0.300000
# 176  1963      30    3.0      4.0     10       0.400000
# 177  1964      31    1.0      5.0     10       0.500000
# 47   1964      31    2.0     11.0     14       0.785714
# 230  1964      31    3.0      4.0      8       0.500000
# 259  1964      31    4.0      2.0      7       0.285714
# 269  1965      32    1.0      4.0      7       0.571429
# 226  1965      32    2.0      1.0      8       0.125000
# 221  1965      32    3.0      2.0      8       0.250000
# 288  1965      32    4.0      0.0      6       0.000000
# 267  1966      33    1.0      0.0      7       0.000000
# 289  1966      33    2.0      0.0      6       0.000000
# 223  1966      33    3.0      0.0      8       0.000000
# 208  1966      33    4.0      2.0      9       0.222222
# 202  1967      34    1.0      0.0      9       0.000000
# 236  1967      34    2.0      1.0      8       0.125000
# 271  1967      34    3.0      0.0      7       0.000000
# 144  1967      34    4.0      0.0     11       0.000000
# 194  1968      35    1.0      0.0      9       0.000000
# 183  1968      35    2.0      1.0     10       0.100000
# 50   1968      35    3.0      2.0     13       0.153846
# 197  1968      35    4.0      1.0      9       0.111111
# 11   1969      36    1.0      3.0     17       0.176471
# 87   1969      36    2.0      2.0     12       0.166667
# 181  1969      36    3.0      1.0     10       0.100000
# 193  1969      36    4.0      2.0      9       0.222222
# 45   1970      37    1.0      5.0     14       0.357143
# 23   1970      37    2.0      0.0     16       0.000000
# 138  1970      37    3.0      1.0     11       0.090909
# 178  1970      37    4.0      1.0     10       0.100000
# 12   1971      38    1.0      0.0     16       0.000000
# 218  1971      38    2.0      0.0      9       0.000000
# 91   1971      38    3.0      0.0     12       0.000000
# 243  1971      38    4.0      0.0      8       0.000000
# 184  1972      39    1.0      0.0     10       0.000000
# 147  1972      39    2.0      0.0     11       0.000000
# 148  1972      39    3.0      1.0     11       0.090909
# 8    1972      39    4.0      0.0     18       0.000000
# 61   1973      40    1.0      0.0     13       0.000000
# 59   1973      40    2.0      0.0     13       0.000000
# 71   1973      40    3.0      1.0     13       0.076923
# 76   1973      40    4.0      0.0     13       0.000000
# 90   1974      41    1.0      NaN     12       1.000000
# 146  1974      41    2.0      NaN     11       1.000000
# 85   1974      41    3.0      NaN     12       1.000000
# 93   1974      41    4.0      NaN     12       1.000000
# 13   1975      42    1.0      NaN     16       1.000000
# 145  1975      42    2.0      NaN     11       1.000000
# 10   1975      42    3.0      NaN     17       1.000000
# 32   1975      42    4.0      NaN     14       1.000000
# 3    1976      43    1.0      1.0     21       0.047619
# 14   1976      43    2.0      0.0     16       0.000000
# 0    1976      43    3.0      0.0     25       0.000000
# 2    1977      44    1.0      3.0     22       0.136364
# 15   1977      44    2.0      4.0     16       0.250000
# 43   1977      44    3.0      1.0     14       0.071429
# 5    1978      45    1.0      0.0     20       0.000000
# 4    1978      45    2.0      0.0     21       0.000000
# 1    1978      45    3.0      0.0     24       0.000000
# 52   1979      46    1.0      NaN     13       1.000000
# 35   1979      46    2.0     13.0     14       0.928571
# 17   1979      46    3.0      NaN     16       1.000000
# 40   1979      46    4.0      NaN     14       1.000000
# 58   1980      47    1.0      NaN     13       1.000000
# 42   1980      47    2.0      NaN     14       1.000000
# 9    1980      47    3.0      NaN     17       1.000000
# 18   1980      47    4.0      NaN     16       1.000000
# 19   1980      47    5.0      0.0     16       0.000000
# 20   1981      48    1.0      0.0     16       0.000000
# 24   1981      48    2.0      2.0     15       0.133333
# 16   1981      48    3.0      2.0     16       0.125000
# 21   1981      48    4.0      4.0     16       0.250000
# 51   1982      49    1.0      0.0     13       0.000000
# 128  1982      49    2.0      0.0     11       0.000000
# 31   1982      49    3.0      0.0     14       0.000000
# 25   1982      49    4.0      0.0     15       0.000000
# 232  1982      49    5.0      1.0      8       0.125000
# 26   1983      50    1.0     14.0     15       0.933333
# 116  1983      50    2.0      NaN     12       1.000000
# 119  1983      50    3.0      NaN     12       1.000000
# 46   1983      50    4.0      NaN     14       1.000000
# 117  1984      51    1.0      4.0     12       0.333333
# 60   1984      51    2.0      0.0     13       0.000000
# 134  1984      51    3.0      1.0     11       0.090909
# 182  1984      51    4.0      0.0     10       0.000000
# 133  1985      52    1.0     10.0     11       0.909091
# 62   1985      52    2.0      NaN     13       1.000000
# 109  1985      52    3.0     11.0     12       0.916667
# 44   1985      52    4.0     13.0     14       0.928571
# 136  1986      53    1.0      0.0     11       0.000000
# 166  1986      53    2.0      0.0     10       0.000000
# 132  1986      53    3.0      0.0     11       0.000000
# 126  1986      53    4.0      0.0     11       0.000000
# 96   1986      53    5.0      1.0     12       0.083333
# 135  1987      54    1.0      1.0     11       0.090909
# 63   1987      54    2.0      1.0     13       0.076923
# 129  1987      54    3.0      2.0     11       0.181818
# 127  1987      54    4.0      0.0     11       0.000000
# 88   1988      55    1.0      1.0     12       0.083333
# 167  1988      55    2.0      0.0     10       0.000000
# 131  1988      55    3.0      6.0     11       0.545455
# 213  1988      55    4.0      4.0      9       0.444444
# 82   1989      56    1.0      2.0     12       0.166667
# 170  1989      56    2.0      4.0     10       0.400000
# 215  1989      56    3.0      3.0      9       0.333333
# 80   1989      56    4.0      1.0     12       0.083333
# 209  1990      57    1.0      0.0      9       0.000000
# 130  1990      57    2.0      0.0     11       0.000000
# 81   1990      57    3.0      0.0     12       0.000000
# 164  1990      57    4.0      NaN     10       1.000000
# 55   1991      58    1.0      1.0     13       0.076923
# 113  1991      58    2.0      0.0     12       0.000000
# 92   1991      58    3.0      1.0     12       0.083333
# 67   1991      58    4.0      2.0     13       0.153846
# 137  1991      58    5.0      0.0     11       0.000000
# 41   1992      59    1.0      2.0     14       0.142857
# 210  1992      59    2.0      1.0      9       0.111111
# 79   1992      59    3.0      2.0     12       0.166667
# 162  1992      59    4.0      1.0     10       0.100000
# 84   1993      60    1.0      2.0     12       0.166667
# 57   1993      60    2.0      0.0     13       0.000000
# 83   1993      60    3.0      2.0     12       0.166667
# 149  1993      60    4.0      0.0     11       0.000000
# 150  1994      61    1.0      0.0     10       0.000000
# 219  1994      61    2.0      0.0      9       0.000000
# 169  1994      61    3.0      0.0     10       0.000000
# 235  1994      61    4.0      0.0      8       0.000000
# 260  1995      62    1.0      0.0      7       0.000000
# 261  1995      62    2.0      0.0      7       0.000000
# 228  1995      62    3.0      0.0      8       0.000000
# 262  1995      62    4.0      0.0      7       0.000000
# 224  1996      63    1.0      0.0      8       0.000000
# 263  1996      63    2.0      1.0      7       0.142857
# 292  1996      63    3.0      0.0      6       0.000000
# 264  1996      63    4.0      0.0      7       0.000000
# 256  1997      64    1.0      5.0      7       0.714286
# 265  1997      64    2.0      NaN      7       1.000000
# 187  1997      64    3.0      NaN      9       1.000000
# 257  1997      64    4.0      5.0      7       0.714286
# 238  1998      65    1.0      NaN      8       1.000000
# 239  1998      65    2.0      7.0      8       0.875000
# 86   1998      65    3.0      0.0     12       0.000000
# 168  1998      65    4.0      8.0     10       0.800000
# 143  1999      66    1.0      0.0     11       0.000000
# 196  1999      66    2.0      0.0      9       0.000000
# 89   1999      66    3.0      1.0     12       0.083333
# 171  1999      66    4.0      0.0     10       0.000000
# 165  2000      67    1.0      6.0     10       0.600000
# 245  2000      67    2.0      4.0      8       0.500000
# 198  2000      67    3.0      6.0      9       0.666667
# 199  2000      67    4.0      4.0      9       0.444444
# 163  2001      68    1.0      3.0     10       0.300000
# 201  2001      68    2.0      5.0      9       0.555556
# 142  2001      68    3.0      2.0     11       0.181818
# 268  2001      68    4.0      2.0      7       0.285714
# 141  2002      69    1.0      0.0     11       0.000000
# 222  2002      69    2.0      0.0      8       0.000000
# 160  2002      69    3.0      0.0     10       0.000000
# 161  2002      69    4.0      0.0     10       0.000000
# 270  2003      70    1.0      0.0      7       0.000000
# 151  2003      70    2.0      0.0     10       0.000000
# 159  2003      70    3.0      0.0     10       0.000000
# 158  2003      70    4.0      0.0     10       0.000000
# 125  2004      71    1.0      0.0     12       0.000000
# 124  2004      71    2.0      0.0     12       0.000000
# 123  2004      71    3.0      0.0     12       0.000000
# 122  2004      71    4.0      0.0     12       0.000000
# 120  2005      72    1.0      0.0     12       0.000000
# 118  2005      72    2.0      0.0     12       0.000000
# 94   2005      72    3.0      0.0     12       0.000000
# 157  2005      72    4.0      0.0     10       0.000000
# 156  2006      73    1.0      1.0     10       0.100000
# 155  2006      73    2.0      0.0     10       0.000000
# 115  2006      73    3.0      1.0     12       0.083333
# 114  2006      73    4.0      0.0     12       0.000000
# 121  2007      74    1.0      0.0     12       0.000000
# 154  2007      74    2.0      0.0     10       0.000000
# 95   2007      74    3.0      0.0     12       0.000000
# 56   2007      74    4.0      0.0     13       0.000000
# 53   2008      75    1.0      1.0     13       0.076923
# 112  2008      75    2.0      0.0     12       0.000000
# 54   2008      75    3.0      1.0     13       0.076923
# 97   2008      75    4.0      0.0     12       0.000000
# 37   2009      76    1.0      0.0     14       0.000000
# 36   2009      76    2.0      0.0     14       0.000000
# 98   2009      76    3.0      0.0     12       0.000000
# 153  2009      76    4.0      0.0     10       0.000000
# 27   2010      77    1.0      2.0     15       0.133333
# 99   2010      77    2.0      0.0     12       0.000000
# 100  2010      77    3.0      0.0     12       0.000000
# 78   2010      77    4.0      0.0     13       0.000000
# 33   2011      78    1.0      1.0     14       0.071429
# 101  2011      78    2.0      0.0     12       0.000000
# 102  2011      78    3.0      0.0     12       0.000000
# 103  2011      78    4.0      0.0     12       0.000000
# 74   2012      79    1.0      0.0     13       0.000000
# 38   2012      79    2.0      0.0     14       0.000000
# 75   2012      79    3.0      0.0     13       0.000000
# 104  2012      79    4.0      0.0     12       0.000000
# 64   2013      80    1.0      0.0     13       0.000000
# 39   2013      80    2.0      1.0     14       0.071429
# 72   2013      80    3.0      0.0     13       0.000000
# 73   2013      80    4.0      0.0     13       0.000000
# 28   2014      81    1.0      0.0     15       0.000000
# 105  2014      81    2.0      NaN     12       1.000000
# 70   2014      81    3.0      0.0     13       0.000000
# 106  2014      81    4.0      0.0     12       0.000000
# 107  2015      82    1.0     11.0     12       0.916667
# 108  2015      82    2.0     11.0     12       0.916667
# 139  2015      82    3.0      9.0     11       0.818182
# 69   2015      82    4.0     10.0     13       0.769231
# 68   2016      83    1.0      0.0     13       0.000000
# 110  2016      83    2.0      0.0     12       0.000000
# 66   2016      83    3.0      0.0     13       0.000000
# 49   2016      83    4.0      0.0     14       0.000000
# 48   2017      84    1.0      0.0     14       0.000000
# 65   2017      84    2.0     12.0     13       0.923077
# 111  2017      84    3.0      0.0     12       0.000000
# 22   2017      84    4.0      2.0     16       0.125000
# 7    2018      85    1.0      0.0     18       0.000000
# 6    2018      85    2.0      0.0     18       0.000000
# 29   2018      85    3.0      1.0     15       0.066667
# 30   2018      85    4.0      0.0     15       0.000000

# %% [markdown]
# There are on average 10 articles per issue. And for older papers, there are only 5 to 7 articles in the issue. Hence, if there are only one or two missing affiliations in that issue it makes sense to collect them manually since setting up the rules for OCR to find the affiliations in just one paper is more time consuming than looking it up.

# %%
check_aff=Merged[(Merged['content_type']!='MISC')&(Merged['year']>=1940)&(Merged['year']<=2010)] #restrict to 1940 to 2010
print(sum(check_aff['affiliations'].isnull())) #number of missing in time period
print(check_aff.shape[0]) #total articles in 1940 to 2010
print(1-(sum(check_aff['affiliations'].isnull())/check_aff.shape[0])) #percentage coverage
sum(difference[difference['retrieval_req']<0.5]['missing']) #manual work expected
# Out:
# 746
# 2681
# 0.721745617306975
# 250.0

# %%
plt.rcParams["figure.figsize"] = (25, 10)
dta=Merged['year'].value_counts()
dta.index
plt.bar(dta.index, dta, alpha=0.4, label='Articles')

dta4=Merged[(Merged['citations'].isnull()==False) & (Merged['content_type']!='MISC')]['year'].value_counts()
plt.bar(dta4.index, dta4, alpha=0.4, label='Scopus coverage')
dta5=scopus[(scopus['citations'].isnull()==False) & (scopus['year']>2018)]['year'].value_counts()
plt.bar(dta5.index, dta5, alpha=0.4, label='Addtional Scopus coverage')
plt.title('Barchart of RES Scopus coverage for references overlaying counts of non-miscellaneous documents in RES for each year before 2018 (inclusive)')
plt.xticks(np.arange(1930, 2030, 10))
plt.legend()

# %%
check_ref=Merged[(Merged['content_type']!='MISC')&(Merged['year']>=1940)&(Merged['year']<=2010)] # restrict between 1940 and 2010
print(sum(check_aff['citations'].isnull())) # number of missing ref articles 
print(check_aff.shape[0]) # total number of articles
print(1-(sum(check_aff['citations'].isnull())/check_aff.shape[0])) #percentage coverage
# Out:
# 1166
# 2681
# 0.5650876538604999
