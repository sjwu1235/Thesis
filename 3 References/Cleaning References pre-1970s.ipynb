# %%
import pandas as pd
from unidecode import unidecode
import re
from datetime import date

# %%
ecta_1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_ecta_501_results.csv")
ecta_2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_ecta_1001_results.csv")
ecta_3=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_ecta_1501_results.csv")
ecta_4=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_ecta_2001_results.csv")
ecta_5=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_ecta_2501_results.csv")
ecta_6=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_ecta_2651_results.csv")
res_1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_res_501_results.csv")
res_2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_res_1001_results.csv")
res_3=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_res_1501_results.csv")
res_4=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_res_2001_results.csv")
res_5=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_res_2501_results.csv")
jpe_1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_501_results.csv")
jpe_2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_1001_results.csv")
jpe_3=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_1501_results.csv")
jpe_4=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_2001_results.csv")
jpe_5=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_2501_results.csv")
jpe_6=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_3001_results.csv")
jpe_7=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_3501_results.csv")
jpe_8=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_4001_results.csv")
jpe_9=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_4501_results.csv")
jpe_10=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_5001_results.csv")
jpe_11=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_5501_results.csv")
jpe_12=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_6001_results.csv")
jpe_13=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_6501_results.csv")
jpe_14=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_7001_results.csv")
jpe_15=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_7501_results.csv")
jpe_16=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8001_results.csv")
jpe_17=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8101_results.csv")
jpe_18=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8201_results.csv")
jpe_19=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8301_results.csv")
jpe_20=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8401_results.csv")
jpe_21=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8501_results.csv")
jpe_22=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8601_results.csv")
jpe_23=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8701_results.csv")
jpe_24=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8801_results.csv")
jpe_25=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_8901_results.csv")
jpe_26=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_9001_results.csv")
jpe_27=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_9501_results.csv")
jpe_28=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_10001_results.csv")
jpe_29=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_jpe_10168_results.csv")
qje_1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_qje_wo_nones_501_results.csv")
qje_2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\progress results\\progress_qje_wo_nones_1001_results.csv")

# %%
ecta_c=pd.concat([ecta_1,ecta_2, ecta_3, ecta_4, ecta_5, ecta_6], ignore_index=True)
res_c=pd.concat([res_1,res_2, res_3, res_4, res_5], ignore_index=True)
jpe_c=pd.concat([jpe_1, jpe_2, jpe_3, jpe_4, jpe_5, jpe_6, jpe_7, jpe_8, jpe_9, jpe_10, jpe_11, jpe_12, jpe_13, jpe_14, jpe_15, jpe_16, jpe_17, jpe_18, jpe_19, jpe_20, jpe_21, jpe_22, jpe_23, jpe_24, jpe_25, jpe_26, jpe_27, jpe_28, jpe_29], ignore_index=True)
qje_c=pd.concat([qje_1,qje_2,], ignore_index=True)

# %%
All=pd.concat([ecta_c, res_c, jpe_c, qje_c], ignore_index=True)

# %%
All.shape
# Out:
# (16227, 474)

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
list(All.columns)
# Out:
# ['HITId',
#  'HITTypeId',
#  'Title',
#  'Description',
#  'Keywords',
#  'Reward',
#  'CreationTime',
#  'MaxAssignments',
#  'RequesterAnnotation',
#  'AssignmentDurationInSeconds',
#  'AutoApprovalDelayInSeconds',
#  'Expiration',
#  'NumberOfSimilarHITs',
#  'LifetimeInSeconds',
#  'AssignmentId',
#  'WorkerId',
#  'AssignmentStatus',
#  'AcceptTime',
#  'SubmitTime',
#  'AutoApprovalTime',
#  'ApprovalTime',
#  'RejectionTime',
#  'RequesterFeedback',
#  'WorkTimeInSeconds',
#  'LifetimeApprovalRate',
#  'Last30DaysApprovalRate',
#  'Last7DaysApprovalRate',
#  'Input.pdf_url',
#  'Input.year',
#  'Input.journal',
#  'Input.ID',
#  'Input.page',
#  'Input.authors',
#  'Input.title',
#  'Input.vol',
#  'Input.issue',
#  'Answer.1.1',
#  'Answer.1.2',
#  'Answer.1.3',
#  'Answer.1.4',
#  'Answer.2.1',
#  'Answer.2.2',
#  'Answer.2.3',
#  'Answer.2.4',
#  'Answer.3.1',
#  'Answer.3.2',
#  'Answer.3.3',
#  'Answer.3.4',
#  'Answer.4.1',
#  'Answer.4.2',
#  'Answer.4.3',
# ...

# %%
dict = {'Answer.ref0.1': 'Answer.0.1',
        'Answer.ref0.2': 'Answer.0.2',
        'Answer.ref0.3': 'Answer.0.3',
        'Answer.ref0.4': 'Answer.0.4',
        'Answer.ref0.5': 'Answer.0.5',
        'Answer.ref1.5': 'Answer.1.5',
        'Answer.ref2.5': 'Answer.2.5',
        'Answer.ref3.5': 'Answer.3.5',
        'Answer.ref4.5': 'Answer.4.5',
        'Answer.ref5.5': 'Answer.5.5',
        'Answer.ref6.5': 'Answer.6.5',
        'Answer.ref7.5': 'Answer.7.5',
        'Answer.ref8.5': 'Answer.8.5',
        'Answer.ref9.5': 'Answer.9.5',
        'Answer.ref10.5': 'Answer.10.5',
        'Answer.ref11.5': 'Answer.11.5',
        'Answer.ref12.5': 'Answer.12.5',
        'Answer.ref13.5': 'Answer.13.5',
        'Answer.ref14.5': 'Answer.14.5',
        'Answer.ref15.5': 'Answer.15.5',
        'Answer.ref16.5': 'Answer.16.5',
        'Answer.ref17.5': 'Answer.17.5',
        'Answer.ref18.5': 'Answer.18.5',
        'Answer.ref19.5': 'Answer.19.5',
        'Answer.ref20.5': 'Answer.20.5',
        'Answer.ref21.5': 'Answer.21.5',
        'Answer.ref22.5': 'Answer.22.5',
        'Answer.ref23.5': 'Answer.23.5',
        'Answer.ref24.5': 'Answer.24.5',
        'Answer.ref25.5': 'Answer.25.5',
        'Answer.ref26.5': 'Answer.26.5',
        'Answer.ref27.5': 'Answer.27.5',
        'Answer.ref28.5': 'Answer.28.5',
        'Answer.ref29.5': 'Answer.29.5',
       }
 
# call rename () method
All=All.rename(columns=dict)

lst=['HITTypeId',
 'Title',
 'Description',
 'Keywords',
 'Reward',
 'CreationTime',
 'MaxAssignments',
 'RequesterAnnotation',
 'AssignmentDurationInSeconds',
 'AutoApprovalDelayInSeconds',
 'Expiration',
 'NumberOfSimilarHITs',
 'LifetimeInSeconds',
 'AssignmentId',
 'AssignmentStatus',
 'AcceptTime',
 'AutoApprovalTime',
 'ApprovalTime',
 'RejectionTime',
 'LifetimeApprovalRate',
 'Last30DaysApprovalRate',
 'Last7DaysApprovalRate']

All=All.drop(lst, axis=1)
#list(ecta_1.columns)

All["num_refs"] = None #add for number of referencing counts

All['SubmitTime']=pd.DataFrame(pd.to_datetime(All['SubmitTime']))
All['Date']=All['SubmitTime'].dt.date
# Out:
# C:\Users\sjwu1\Documents\thesis\env\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# C:\Users\sjwu1\Documents\thesis\env\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname PDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
Journals=[]
Book=[]
def strip_and_convert(str_, strip_the):
    #print(str_)
    if pd.isna(str_)==True:
        return "None"
    temp=unidecode(str_)
    try:
        l = [x.isalpha() for x in temp].index(True)
        m = [x.isalpha() for x in temp[::-1]].index(True)
        temp=temp[l:len(str_)-m]
    except:
        print(temp)
        temp="none"
    #temp=re.sub('^"(.*)"$','(.*)', temp)
    if (temp[0:4].lower()=="the ")&(strip_the==True):
        temp=temp[4:]
    temp=re.sub(' +', ' ', temp)
    temp=re.sub(' ,', ', ', temp)
    return temp

def process_article(x, num):
    article_dict={
        "type": "article",
        "author": x["Answer.ref."+str(num)+"_author"],
        "title": x["Answer.ref."+str(num)+"_title"],
        "journal": strip_and_convert(x["Answer.ref."+str(num)+"_journal"], True),
        "year": x["Answer.ref."+str(num)+"_year"],
        "volume": x["Answer.ref."+str(num)+"_vol"],
        "issue": x["Answer.ref."+str(num)+"_issue"],
        "pages": x["Answer.ref."+str(num)+"_pages"],  
    }
    '''
    Journals.append({"journal":strip_and_convert(x["Answer.ref."+str(num)+"_journal"]),
                     "author": x["Answer.ref."+str(num)+"_author"],
                     "title": x["Answer.ref."+str(num)+"_title"],
                     "m":len(Journals)})
    '''
    
    Journals.append(strip_and_convert(x["Answer.ref."+str(num)+"_journal"], True))
    return article_dict

def process_book(x, num):
    book_dict={
        "type": "book",
        "author": x["Answer.ref."+str(num)+"_author"],
        "title": x["Answer.ref."+str(num)+"_title"],
        "chapter_title": x["Answer.ref."+str(num)+"_chapter_title"],
        "year": x["Answer.ref."+str(num)+"_year"],
        "volume": x["Answer.ref."+str(num)+"_vol"],
        "location": x["Answer.ref."+str(num)+"_location"],
        "publisher": x["Answer.ref."+str(num)+"_publisher"],
        "pages": x["Answer.ref."+str(num)+"_pages"],  
    }
    Book.append(strip_and_convert(x["Answer.ref."+str(num)+"_title"], False))
    return book_dict

def process_other(x, num):
    other_dict={
        "type": "other",
        "author": x["Answer.ref."+str(num)+"_author"],
        "title": x["Answer.ref."+str(num)+"_title"],
        "year": x["Answer.ref."+str(num)+"_year"],
        "publisher": x["Answer.ref."+str(num)+"_publisher"],
        "textfull": x["Answer.ref."+str(num)+"_textfull"],  
    }
    return other_dict

def Merge(dict1, dict2):
    return(dict2|dict1)

# %%
nA=0
ref=0
article=0
book=0
other=0
a=0
all_ref={}


for j in All.index:
    count=0
    
    if(pd.isna(All.iloc[j]["RequesterFeedback"])==False):
        All.at[j, "rej_flag"]=True
    else:
        All.at[j, "rej_flag"]=False
        
    for i in range(0,29,1):
        item=None
        temp={
            "HITId": All.iloc[j]["HITId"],
            "ID": All.iloc[j]["Input.ID"],
            "page_o": All.iloc[j]["Input.page"],
            "year_o": All.iloc[j]["Input.year"],
            "journal_o": All.iloc[j]["Input.journal"],
            "authors_o": All.iloc[j]["Input.authors"],
            "title_o": All.iloc[j]["Input.title"],
            "volume_o": All.iloc[j]["Input.vol"],
            "issue_o": All.iloc[j]["Input.issue"],
        }
        
        if pd.isna(All.iloc[j]["Answer."+str(i)+".1"]):
            continue
        elif All.iloc[j]["Answer."+str(i)+".1"]==True:
            nA=nA+1
        elif All.iloc[j]["Answer."+str(i)+".2"]==True:
            article=article+1
            count=count+1
            item=process_article(All.iloc[j],i)
        elif All.iloc[j]["Answer."+str(i)+".3"]==True:
            book=book+1
            count=count+1
            item=process_book(All.iloc[j],i)
        elif All.iloc[j]["Answer."+str(i)+".4"]==True:
            other=other+1
            count=count+1
            item=process_other(All.iloc[j],i)
        elif All.iloc[j]["Answer."+str(i)+".5"]==True:
            ref=ref+1
            
        if(pd.isna(All.iloc[j]["RequesterFeedback"])==False)&(item != None):
            temp["rejected"]=True
            print(j)
            print(temp|item)
        if item != None:
            a=a+1
            all_ref[a]=temp|item
    
        #print(i)
        #if item!=None:
            #print(Merge(item, temp))
            #print(temp|item)
    All.at[j,"num_refs"]=count

#change this into a bloody function switch statement, horrible if ladder is good enough for now
# Out:
# 48
# {'HITId': '3JMNNNO3C8ZFGFCNDZ9VCLYHFR42WV', 'ID': 1909101, 'page_o': 4, 'year_o': 1940, 'journal_o': 'ECONOMETRICA', 'authors_o': 'H. Neisser', 'title_o': "A Note on Pareto's Theory of Production", 'volume_o': 8, 'issue_o': '3', 'rejected': True, 'type': 'book', 'author': 'Wicksell', 'title': 'Lectures on the political economy', 'chapter_title': 'None', 'year': '1934', 'volume': '1', 'location': 'None', 'publisher': 'None', 'pages': '129-130'}
# 83
# {'HITId': '31YWE12TF771RGEJTGMCAVTWZ9W7X9', 'ID': 1905717, 'page_o': 12, 'year_o': 1943, 'journal_o': 'ECONOMETRICA', 'authors_o': 'Martin Bronfenbrenner', 'title_o': 'The Role of Money in Equilibrium Capital Theory', 'volume_o': 11, 'issue_o': '1', 'rejected': True, 'type': 'book', 'author': 'V. Pareto', 'title': "Cours d'economie politique", 'chapter_title': 'None', 'year': '1896', 'volume': '1', 'location': 'Lausanne', 'publisher': 'None', 'pages': '60'}
# 83
# ...

# %%
All.apply(lambda row : expander(row), axis = 1)

# %%
All.head()
# Out:
#                             HITId        WorkerId          SubmitTime  \
# 0  3UEDKCTPA2LV7GFCUX7NK1LU30H7KK  A3TMO46POHUQ5R 2023-01-10 10:00:16
# 1  3YOAVL4CB7CTDOWFS0CQ44PXG744ZJ  A3DBGA6NGIUQ2J 2023-01-17 04:53:55
# 2  30EV7DWJU2Q7NLQOF23MNV09645Y66  A1P79XGTU8M781 2023-01-14 00:32:19
# 3  3MJ9GGZYPA1I929KCUD3UW1QN81A2S  A3DBGA6NGIUQ2J 2023-01-10 04:54:02
# 4  3JGHED38FKMQRL4TYC8ET9051FPY75  A30URQE2HQRV40 2023-01-12 09:19:11
#
#   RequesterFeedback  WorkTimeInSeconds  \
# 0               NaN                740
# 1               NaN                314
# 2               NaN                 65
# 3               NaN                 48
# 4               NaN                433
#
#                                                                                     Input.pdf_url  \
# 0  'https://myawsbucket-1231.s3.eu-west-3.amazonaws.com/ECTA_shards/1906881_wo_cover_page-12.pdf'
# 1  'https://myawsbucket-1231.s3.eu-west-3.amazonaws.com/ECTA_shards/1906881_wo_cover_page-13.pdf'
# ...

# %%
ar=pd.DataFrame.from_dict(all_ref)
ar.transpose
# Out:
# <bound method DataFrame.transpose of                                                                                                                                      1      \
# HITId                                                                                                       3UEDKCTPA2LV7GFCUX7NK1LU30H7KK
# ID                                                                                                                                 1906881
# page_o                                                                                                                                  12
# year_o                                                                                                                                1940
# journal_o                                                                                                                     ECONOMETRICA
# ...

# %%
len(all_ref)
# Out:
# 13272

# %%
temp=pd.DataFrame(arts[arts.str.contains('^"')])['title'].str[1:]
fit=pd.DataFrame(arts[arts.str.contains('^"')]).reset_index().drop('index',axis=1)
print(strip_and_convert(fit.loc[10,'title'], False))
print(re.sub('^".+"$','.+',fit.loc[10,'title']))
print(re.sub(', $','',strip_and_convert(fit.loc[10, 'title'], False)))
fit.loc[10,'title'].strip().lstrip('"')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 temp=pd.DataFrame(arts[arts.str.contains('^"')])['title'].str[1:]
#       2 fit=pd.DataFrame(arts[arts.str.contains('^"')]).reset_index().drop('index',axis=1)
#       3 print(strip_and_convert(fit.loc[10,'title'], False))
#
# NameError: name 'arts' is not defined

# %%
unique_journals=list(set([element.lower() for element in Journals]))

# %%
unique_journals.sort()
unique_journals
stripped = list(map(str.strip, unique_journals))
stripped
# Out:
# ['economic record',
#  'review of economic studies',
#  'a merican economic review, proceedings',
#  'a survey of contemporary economics',
#  'a.e.r',
#  'aamerican economic review',
#  'accountant',
#  'accounting review',
#  'activity analysis of production and allocation',
#  'actuarial society of america',
#  'agenda',
#  'agricultural history',
#  'agricultural information bulletin',
#  'ajp',
#  'al of law and economics',
#  'allgemeines statistisches archiv',
#  'almanac issue',
#  'america economic review',
#  'american agriculturist',
#  'american banker',
#  'american city',
#  'american econkomic review',
#  'american economic association',
#  'american economic association, papers and proceedings',
#  'american economic revie',
#  'american economic review',
#  'american economic review supplement',
#  'american economic review, papers and proceedings',
#  'american economic review, supplement',
#  'american economic review: papers and proceedings',
# ...

# %%
import numpy as np
from sklearn.cluster import AffinityPropagation
import distance
    
words = stripped
words = np.asarray(words) #So that indexing with a list will work
lev_similarity = -1*np.array([[distance.levenshtein(w1,w2) for w1 in words] for w2 in words])

# %%
lev_similarity
# Out:
# array([[  0, -17, -25, ..., -27, -20, -38],
#        [-17,   0, -25, ..., -28, -23, -36],
#        [-25, -25,   0, ..., -33, -31, -36],
#        ...,
#        [-27, -28, -33, ...,   0, -17, -28],
#        [-20, -23, -31, ..., -17,   0, -33],
#        [-38, -36, -36, ..., -28, -33,   0]])

# %%
affprop = AffinityPropagation(affinity="precomputed", damping=0.5)

# %%
lev_similarity.dtype
test_temp=np.asarray(lev_similarity, dtype=float)

# %%
affprop.fit(test_temp)
# Out:
# AffinityPropagation(affinity='precomputed')

# %%
np.unique(affprop.labels_).shape
# Out:
# (136,)

# %%
for cluster_id in np.unique(affprop.labels_):
    exemplar = words[affprop.cluster_centers_indices_[cluster_id]]
    cluster = np.unique(words[np.nonzero(affprop.labels_==cluster_id)])
    cluster_str = ", ".join(cluster)
    print(list(cluster))
    print(" - *%s:* %s" % (exemplar, cluster_str))
# Out:
# ['essays in the theory of economic fluctuations', 'harvard economic studies', 'income and wealth studies', 'kobe university economic studies', 'kobe university economic studies annual report', 'revie of economic studies', 'review fo economic studies', 'review of economi studiess', 'review of economic', 'review of economic progress', 'review of economic studies', 'review of economic studis', 'review of economic stusdie', 'review of economics studies', 'review of economicstudies', 'review of social sciences', 'review of the river plate', 'review of. economic studies', 'review or economics studies', 'survey of current business']
# ...

# %%
sort_info={
    "review of economic studies": ['r.e.s',
         'revie of economic studies', 'review fo economic studies',
         'review of economi studiess', 'review of economic', 'review of economic studies',
         'review of economic studis', 'review of economic stusdie',
         'review of economics studies', 'review of economicstudies',
         'review of. economic studies', 'review or economics studies', 'review of economic studies, volume 14, issue 2, 1 january'],
    "american economic review": ['aamerican economic review', 
                                 'america economic review', 
                                 'american econkomic review', 
                                 'american economic revie', 
                                 'american economic review', 
                                 'american economic review supplement', 
                                 'american economic review, supplement', 
                                 'american economic reviiew', 
                                 'american economics review', 
                                 'american economix review', 
                                 'american economnic review', 
                                 'american eocnomic review', 
                                 'a merican economic review, proceedings', 
                                 'american economic association, papers and proceedings', 
                                 'american economic review, papers and proceedings', 
                                 'american economic review: papers and proceedings', 
                                 'american economic reviews papers and proceedings',
                                 'papers and proceedings of the american economic association', 
                                 'american economic review',
                                 'americn economic association, papers and proceedings'],
    "national okonomisk tidskrift":['ationalokonomisk tidsskrift', 
                                    'ekonomisk tidskrift', 
                                    'national okonomisk tidskrift', 
                                    'nationalokonomis tidsskrift', 
                                    'nationloekonomisk tidskrift'],
    'bulletin of the oxford university institute of statistic':[ 'bulletin of the oxford university institute for statistics',
             'bulletin of the oxford university institute of statistics',
             'bulletin of the oxford university instituty of statistics'],
    "economic journal": ['economic hournal', 
                         'economic jonrnal', 
                         'economic journa', 
                         'economic journal', 
                         'economic journal review', 
                         'economic journal supplement', 
                         'economic journal, december', 
                         'economic jourrnal', 
                         'economical journal', 
                         'economics journal',],
    "ergebnisse eines mathematischen kolloquiums": ['ergebnisse eines mat he- matischen kolloquiu', 
                                                    'ergebnisse eines mathematischen kolloquiums', 
                                                    'ergebnisse eines mathematisclen kolloquium'],
    "federal reserve bulletin": ['federal reserve bulletin', 
                                 'federal reserve bullletin', 
                                 'federal rserve bulletin'],
    "journal of political economy": ['j.p.e (journal of political economy', 
                                     'journal of policial economy', 
                                     'journal of polilical economy', 
                                     'journal of politic economy', 
                                     'journal of political ecnomy', 
                                     'journal of political econiomy', 
                                     'journal of political economiy', 
                                     'journal of political economny', 
                                     'journal of political economy', 
                                     'journal of political economy chicago', 
                                     'journal of political economy: supplement', 
                                     'journal of polotical economy', 
                                     'journal of poltical economy', 
                                     'journal of the political economy', 
                                     'journal political economics', 
                                     'journial of political economy'],
    "quarterly journal of economics": ['quartely journal of economics', 
                                       'quarterlv journal of economics', 
                                       'quarterly journal economics',
                                       'quarterly journal fo economics', 
                                       'quarterly journal of economic', 
                                       'quarterly journal of economics', 
                                       'quarterly journal of economies', 
                                       'quarterly journal of economy', 
                                       'quarterly journal of econonics'],
    'econometrica': ['economeirica', 
                     'econometria', 
                     'econometric', 
                     'econometric a', 
                     'econometrica', 
                     'econometricia', 
                     'econometrics', 
                     'econometrie', 
                     'economietrica', 
                     'economnetrica'],
    'oxford economic papers': [ 'oxford economic paper',
                                 'oxford economic papers',
                                 'oxford economics papers',]
    
    

}

# %%
split_out={}
for key in sort_info.keys():
    for i in sort_info[key]:
        split_out[i]=key

# %%
for i in df:
    print(df)
# Out:
#   Input In [129]
#     for i in all_ref
#                     ^
# SyntaxError: expected ':'

# %%
df=ar.transpose()
df.head()
# Out:
#                             HITId       ID page_o year_o     journal_o  \
# 1  3UEDKCTPA2LV7GFCUX7NK1LU30H7KK  1906881     12   1940  ECONOMETRICA
# 2  3UEDKCTPA2LV7GFCUX7NK1LU30H7KK  1906881     12   1940  ECONOMETRICA
# 3  3UEDKCTPA2LV7GFCUX7NK1LU30H7KK  1906881     12   1940  ECONOMETRICA
# 4  3YOAVL4CB7CTDOWFS0CQ44PXG744ZJ  1906881     13   1940  ECONOMETRICA
# 5  3YOAVL4CB7CTDOWFS0CQ44PXG744ZJ  1906881     13   1940  ECONOMETRICA
#
#                            authors_o  \
# 1  David Weintraub and Harry Magdoff
# 2  David Weintraub and Harry Magdoff
# 3  David Weintraub and Harry Magdoff
# 4  David Weintraub and Harry Magdoff
# 5  David Weintraub and Harry Magdoff
#
#                                                    title_o volume_o issue_o  \
# 1  The Service Industries in Relation to Employment Trends        8       4
# 2  The Service Industries in Relation to Employment Trends        8       4
# 3  The Service Industries in Relation to Employment Trends        8       4
# ...

# %%
ar_out=pd.DataFrame(all_ref)
