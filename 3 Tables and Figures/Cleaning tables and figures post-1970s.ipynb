# %% [markdown]
# # Cleaning RA submissions for Tables and Figures

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Tables and Figures

# %%
ecta_t1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\ecta_tfe_501_results.csv")
ecta_t2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\ecta_tfe_1001_results.csv")
ecta_t3=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\ecta_tfe_1501_results.csv")
ecta_t4=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\ecta_tfe_2001_results.csv")
ecta_t5=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\ecta_tfe_2501_results.csv")
ecta_t6=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\ecta_tfe_2957_results.csv")
ecta_t7=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\ecta_tfe_not_5_50_501_results.csv")
ecta_t8=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\ecta_tfe_not_5_50_512_results.csv")
res_t1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\res_tfe_501_results.csv")
res_t2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\res_tfe_1001_results.csv")
res_t3=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\res_tfe_1501_results.csv")
res_t4=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\res_tfe_1726_results.csv")
res_t5=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\res_tfe_not_5_50_results.csv")
qje_t1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\qje_tfe_501_results.csv")
qje_t2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\qje_tfe_1001_results.csv")
qje_t3=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\qje_tfe_1480_results.csv")
qje_t4=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\qje_tfe_not_5_50_results.csv")
jpe_t1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_425_results.csv")
jpe_t2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_889_results.csv")
jpe_t3=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_1398_results.csv")
jpe_t4=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_1489_results.csv")
jpe_t5=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_1989_results.csv")
jpe_t6=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_2089_results.csv")
jpe_t7=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_2520_results.csv")
jpe_t8=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_2694_results.csv")
jpe_t9=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\jpe_tfe_not_5_50_results.csv")
aer_t1=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_501_results.csv")
aer_t2=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_1001_results.csv")
aer_t3=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_1449_results.csv")
aer_t4=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_1900_results.csv")
aer_t5=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_2400_results.csv")
aer_t6=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_2900_results.csv")
aer_t7=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_3000_results.csv")
aer_t8=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_3500_results.csv")
aer_t9=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_4000_results.csv")
aer_t10=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_4300_results.csv")
aer_t11=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_4800_results.csv")
aer_t12=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_5000_results.csv")
aer_t13=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_5500_results.csv")
aer_t14=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_6000_results.csv")
aer_t15=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_6500_results.csv")
aer_t16=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_7000_results.csv")
aer_t17=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_7130_results.csv")
aer_t18=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_7438_results.csv")
aer_t19=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_7300_results.csv")
aer_t20=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_7200_results.csv")
aer_t21=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_not_5_50_501_results.csv")
aer_t22=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_not_5_50_1001_results.csv")
aer_t23=pd.read_csv("C:\\Users\\sjwu1\\Downloads\\tfe results\\aer_tfe_not_5_50_1441_results.csv")

# %%
ecta_t=pd.concat([ecta_t1,ecta_t2, ecta_t3, ecta_t4, ecta_t5, ecta_t6, ecta_t7, ecta_t8], ignore_index=True)
res_t=pd.concat([res_t1, res_t2, res_t3, res_t4, res_t5], ignore_index=True)
qje_t=pd.concat([qje_t1, qje_t2, qje_t3, qje_t4], ignore_index=True)
jpe_t=pd.concat([jpe_t1, jpe_t2, jpe_t3, jpe_t4, jpe_t5, jpe_t6, jpe_t7, jpe_t8, jpe_t9], ignore_index=True)
aer_t=pd.concat([aer_t1, aer_t2, aer_t3,aer_t4, aer_t5, aer_t6,aer_t7, aer_t8, aer_t9,
                 aer_t10, aer_t11, aer_t12, aer_t13, aer_t14, aer_t15, aer_t16, 
                 aer_t17, aer_t18, aer_t19, aer_t20, aer_t21, aer_t22, aer_t23], ignore_index=True)

# %%
All_t=pd.concat([ecta_t, res_t, qje_t, jpe_t, aer_t], ignore_index=True)

# %%
All_t.to_csv("tb_fg_counts.csv", index=False)

# %%
All_t.columns
# Out:
# Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.pdf_url',
#        'Input.year', 'Input.num_pages', 'Input.title', 'Input.journal',
#        'Input.authors', 'Input.vol', 'Input.issue', 'Input.ID',
#        'Answer.fg_count', 'Answer.tb_count', 'Approve', 'Reject'],
#       dtype='object')

# %%
lst=['HITTypeId',
 'Title',
 'Description',
 'Keywords',
 'Reward',
 'CreationTime',
 'MaxAssignments',
 'RequesterAnnotation',
 'AssignmentDurationInSeconds',
 'AutoApprovalDelayInSeconds',
 'Expiration',
 'NumberOfSimilarHITs',
 'LifetimeInSeconds',
 'AssignmentId',
 'AssignmentStatus',
 'AcceptTime',
 'AutoApprovalTime',
 'ApprovalTime',
 'LifetimeApprovalRate',
 'Last30DaysApprovalRate',
 'Last7DaysApprovalRate',]

All_t=All_t.drop(lst, axis=1)
#list(ecta_1.columns)

All_t['SubmitTime']=pd.DataFrame(pd.to_datetime(All_t['SubmitTime']))
All_t['Date']=All_t['SubmitTime'].dt.date
# Out:
# C:\Users\sjwu1\Documents\thesis\env\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# C:\Users\sjwu1\Documents\thesis\env\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname PDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
All_t=All_t[All_t["RejectionTime"].isna()==True].reset_index(drop=True)

# %%
sum(All_t["WorkTimeInSeconds"])/All_t.shape[0] #how many seconds on average per paper
# Out:
# 46.615310233682514

# %%
# drop mturk worker stuff
lst_2=[
        "HITId",
        "WorkerId",
        "SubmitTime",
        "RejectionTime",
        "RequesterFeedback",
        "WorkTimeInSeconds",
        "Approve",
        "Reject",
        "Date"
]

All_t=All_t.drop(lst_2, axis=1)

# remove mturk input and answer prefixes
new_names={'Input.pdf_url': 'pdf_url', 
           'Input.year': 'year',
           'Input.num_pages': 'num_pages', 
           'Input.title': 'title',
           'Input.journal':"journal", 
           'Input.authors':'authors', 
           'Input.vol': 'vol', 
           'Input.issue': 'issue',
           'Input.ID': 'ID', 
           'Answer.fg_count': 'fg_count', 
           'Answer.tb_count': 'tb_count'}

All_t.rename(columns=new_names, inplace=True)

# %%
All_t.to_csv("tb_fg_post_1970s.csv", index=False)

# %% [markdown]
# ### Complete the missing data for the period

# %%
All_t= pd.read_csv("tb_fg_post_1970s.csv")

# %%
All_t.columns
# Out:
# Index(['pdf_url', 'year', 'num_pages', 'title', 'journal', 'authors', 'vol',
#        'issue', 'ID', 'fg_count', 'tb_count'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', None)

# %%
JOURNALS= ['AER', 'JPE', 'ECTA', 'RES', 'QJE']
#read in all processed masterlists
All=pd.DataFrame()
for i in JOURNALS:
    All=pd.concat([pd.read_excel('C:\\Users\\sjwu1\\Journal_Data\\datadumps\\combined\\'+i+'_M_sco_du.xlsx'), All], ignore_index=True)
#Create a batch file

All=All[All.duplicated()==False].reset_index().drop('index', axis=1)

# %%
All.columns
# Out:
# Index([     'stable_url',   'Jstor_authors',     'Jstor_title',
#         'Jstor_abstract',    'content_type',       'issue_url',
#                  'pages',            'year',          'volume',
#                  'issue',   'Jstor_journal',            'type',
#                        0,  'scopus_authors',    'scopus_title',
#         'scopus_journal',             'DOI',    'affiliations',
#        'scopus_abstract',       'citations',   'document type',
#         'index keywords', 'author keywords',      'Unnamed: 0',
#          'document_type',       'footnotes',             'raw',
#             'references'],
#       dtype='object')

# %%
Checking=All[["stable_url","Jstor_journal", "content_type","year"]].reset_index(drop=True)

# %%
Checking["ID"]=Checking["stable_url"].str.split('/').str[-1].astype('int64')

# %%
Checking["tf_count"]=Checking['ID'].isin(All_t["ID"].to_list()+M_collect["ID"].to_list())
Checking["tf_count"]=Checking["tf_count"].astype('int')

# %%
Restricted=Checking[(Checking["year"]>=1940)&(Checking["year"]<=2010)&(Checking["content_type"]!="MISC")&(Checking["content_type"]!="Review")&(Checking["content_type"]!="Review2")].reset_index(drop=True)

# %%
Restricted.content_type.unique()
# Out:
# array(['Article', 'Comment', 'Reply', 'Rejoinder', 'Discussion'],
#       dtype=object)

# %%
pd.DataFrame(Restricted[['year',"Jstor_journal",'tf_count']].groupby(["year",'Jstor_journal',"tf_count"])["tf_count"].count())
# Out:
#                              tf_count
# year Jstor_journal tf_count
# 1940 AER           0              113
#      ECONOMETRICA  0               25
#      JPE           0               43
#      QJE           0               49
#      RES           0               21
# 1941 AER           0              105
#      ECONOMETRICA  0               22
#      JPE           0               35
#      QJE           0               43
#      RES           0               18
# 1942 AER           0              103
#      ECONOMETRICA  0               23
#      JPE           0               38
#      QJE           0               36
#      RES           0               12
# 1943 AER           0              110
#      ECONOMETRICA  0               23
#      JPE           0               41
#      QJE           0               32
#      RES           0               11
# 1944 AER           0               92
#      ECONOMETRICA  0               23
#      JPE           0               21
# ...

# %%
for a in Restricted[(Restricted["year"]>=1972)&(Restricted["Jstor_journal"]=="ECONOMETRICA")&(Restricted["tf_count"]==0)].index:
    item=Restricted.loc[a]
    print("{'journal':'"+ item["Jstor_journal"]+"', 'year':"+str(item["year"])+", 'ID':"+str(item["ID"])+",'fg_count':0, 'tb_count':0},")
# Out:
# {'journal':'ECONOMETRICA', 'year':2010, 'ID':40928972,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2005, 'ID':3598868,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2004, 'ID':3598855,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2001, 'ID':2692223,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2000, 'ID':2999451,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2000, 'ID':2999454,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1998, 'ID':2998575,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1996, 'ID':2171842,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1993, 'ID':2951792,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1991, 'ID':2938167,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1990, 'ID':2938352,'fg_count':0, 'tb_count':0},
# ...

# %%
manual=[

    {'journal':'ECONOMETRICA', 'year':1964, 'ID': 1913741, 'fg_count':2, 'tb_count':5},
    {'journal':'ECONOMETRICA', 'year':1964, 'ID': 1913070, 'fg_count':0, 'tb_count':0},
    {'journal':'ECONOMETRICA', 'year':1964, 'ID': 1913765, 'fg_count':0, 'tb_count':0},

{'journal':'ECONOMETRICA', 'year':2010, 'ID':40928972,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':2005, 'ID':3598868,'fg_count':0, 'tb_count':5},
{'journal':'ECONOMETRICA', 'year':2004, 'ID':3598855,'fg_count':2, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':2001, 'ID':2692223,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':2000, 'ID':2999451,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':2000, 'ID':2999454,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':1998, 'ID':2998575,'fg_count':8, 'tb_count':10},
{'journal':'ECONOMETRICA', 'year':1996, 'ID':2171842,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':1993, 'ID':2951792,'fg_count':0, 'tb_count':2},
{'journal':'ECONOMETRICA', 'year':1991, 'ID':2938167,'fg_count':0, 'tb_count':13},
{'journal':'ECONOMETRICA', 'year':1990, 'ID':2938352,'fg_count':5, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':1990, 'ID':2938202,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':1990, 'ID':2938346,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':1989, 'ID':1913630,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':1989, 'ID':1913781,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':1989, 'ID':1911061,'fg_count':0, 'tb_count':0},
{'journal':'ECONOMETRICA', 'year':1989, 'ID':1912556,'fg_count':5, 'tb_count':6},
    
# {'journal':'ECONOMETRICA', 'year':1988, 'ID':1911369,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1987, 'ID':1911036,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1986, 'ID':1912324,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1985, 'ID':1912665,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1985, 'ID':1911664,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1984, 'ID':1910989,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1984, 'ID':1911204,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1984, 'ID':1913477,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1984, 'ID':1911491,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1984, 'ID':1911495,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1983, 'ID':1912125,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1983, 'ID':1912292,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1983, 'ID':1912002,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1983, 'ID':1912012,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1981, 'ID':1911125,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1981, 'ID':1911134,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1981, 'ID':1911143,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1980, 'ID':1912943,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1979, 'ID':1914006,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1979, 'ID':1914209,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1979, 'ID':1912365,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1978, 'ID':1913911,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1978, 'ID':1913930,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1977, 'ID':40263866,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1977, 'ID':1914078,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1977, 'ID':1914079,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1977, 'ID':1911695,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1977, 'ID':1911228,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1976, 'ID':1912742,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1973, 'ID':1914050,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1972, 'ID':1912090,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2008, 'ID':40056505,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2003, 'ID':1555519,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2002, 'ID':2692300,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2001, 'ID':2692200,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':2000, 'ID':2999525,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1999, 'ID':2999521,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1999, 'ID':2999522,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1999, 'ID':2999540,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1998, 'ID':2998572,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1984, 'ID':1911503,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1984, 'ID':1911476,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1983, 'ID':1912013,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1978, 'ID':1909762,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1976, 'ID':1912738,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1976, 'ID':1912739,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1976, 'ID':1912740,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1975, 'ID':1913426,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1973, 'ID':1914098,'fg_count':0, 'tb_count':0},
# {'journal':'ECONOMETRICA', 'year':1973, 'ID':1913500,'fg_count':0, 'tb_count':0},
    

    {'journal':'AER', 'year':2010, 'ID':27871230,'fg_count':14, 'tb_count':3},
    {'journal':'AER', 'year':2009, 'ID':29730180,'fg_count':18, 'tb_count':6},
    {'journal':'AER', 'year':2008, 'ID':29730096,'fg_count':6, 'tb_count':12},
    {'journal':'AER', 'year':2008, 'ID':29730108,'fg_count':5, 'tb_count':9},
    {'journal':'AER', 'year':2004, 'ID':3592949,'fg_count':2, 'tb_count':7},
    {'journal':'AER', 'year':2004, 'ID':3592886,'fg_count':0, 'tb_count':3},
    {'journal':'AER', 'year':2003, 'ID':3132231,'fg_count':0, 'tb_count':2},
    {'journal':'AER', 'year':2002, 'ID':3083370,'fg_count':4, 'tb_count':0},
    {'journal':'AER', 'year':1992, 'ID':2117471,'fg_count':1, 'tb_count':11},
    {'journal':'AER', 'year':1991, 'ID':2006906,'fg_count':0, 'tb_count':12},
    {'journal':'AER', 'year':1991, 'ID':2006788,'fg_count':1, 'tb_count':16},
    {'journal':'AER', 'year':1991, 'ID':2006833,'fg_count':0, 'tb_count':0},
    {'journal':'AER', 'year':1990, 'ID':2006616,'fg_count':0, 'tb_count':0},
    {'journal':'AER', 'year':1990, 'ID':2006742,'fg_count':0, 'tb_count':9},
    {'journal':'AER', 'year':1990, 'ID':2006747,'fg_count':10, 'tb_count':3},
    {'journal':'AER', 'year':1989, 'ID':1827934,'fg_count':0, 'tb_count':6},
    {'journal':'AER', 'year':1989, 'ID':1827734,'fg_count':0, 'tb_count':0},
    {'journal':'AER', 'year':1989, 'ID':1827762,'fg_count':0, 'tb_count':2},
    {'journal':'AER', 'year':1988, 'ID':1807154,'fg_count':2, 'tb_count':9},
    {'journal':'AER', 'year':1986, 'ID':1816492,'fg_count':0, 'tb_count':1},
    {'journal':'AER', 'year':1976, 'ID':1827498,'fg_count':2, 'tb_count':8},
    {'journal':'AER', 'year':1976, 'ID':1806694,'fg_count':4, 'tb_count':6},
    {'journal':'AER', 'year':1976, 'ID':1817197,'fg_count':0, 'tb_count':2},
    {'journal':'AER', 'year':1975, 'ID':1806553,'fg_count':0, 'tb_count':0},
    {'journal':'AER', 'year':1974, 'ID':1815257,'fg_count':0, 'tb_count':0},
    {'journal':'AER', 'year':1973, 'ID':1808858,'fg_count':0, 'tb_count':8},
    {'journal':'AER', 'year':1973, 'ID':1803130,'fg_count':1, 'tb_count':5},
    {'journal':'AER', 'year':1971, 'ID':1813432,'fg_count':0, 'tb_count':27},
    {'journal':'AER', 'year':1970, 'ID':1818405,'fg_count':0, 'tb_count':6},
    {'journal':'AER', 'year':1967, 'ID':1814419,'fg_count':0, 'tb_count':5},
    {'journal':'AER', 'year':1963, 'ID': 1823859, 'fg_count':0, 'tb_count':0},
    {'journal':'AER', 'year':1964, 'ID': 1810712, 'fg_count':0, 'tb_count':3},
    {'journal':'AER', 'year':1964, 'ID': 1810719, 'fg_count':0, 'tb_count':3},
    {'journal':'AER', 'year':1964, 'ID': 1818525, 'fg_count':0, 'tb_count':8},
    
    {'journal':'JPE', 'year':2010, 'ID':659224,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2010, 'ID':652705,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2009, 'ID':650478,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2009, 'ID':649771,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2009, 'ID':606067,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2009, 'ID':604735,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2009, 'ID':600051,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2009, 'ID':598959,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2008, 'ID':596752,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2008, 'ID':595969,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2008, 'ID':592827,'fg_count':0, 'tb_count':1},
    {'journal':'JPE', 'year':2008, 'ID':592823,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2008, 'ID':591153,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2008, 'ID':589676,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2008, 'ID':589463,'fg_count':0, 'tb_count':1},
    {'journal':'JPE', 'year':2008, 'ID':587817,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2007, 'ID':587086,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2007, 'ID':527505,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2007, 'ID':523906,'fg_count':0, 'tb_count':1},
    {'journal':'JPE', 'year':2007, 'ID':523904,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2007, 'ID':521413,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2007, 'ID':518724,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2007, 'ID':513721,'fg_count':0, 'tb_count':1},
    {'journal':'JPE', 'year':2007, 'ID':513454,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2006, 'ID':511317,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2006, 'ID':509728,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2006, 'ID':508241,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2006, 'ID':505657,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2006, 'ID':503758,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2006, 'ID':502782,'fg_count':0, 'tb_count':1},
    {'journal':'JPE', 'year':2006, 'ID':502780,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2005, 'ID':500059,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2005, 'ID':502781,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2005, 'ID':432964,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2005, 'ID':431290,'fg_count':0, 'tb_count':1},
    {'journal':'JPE', 'year':2005, 'ID':430890,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2005, 'ID':430366,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2005, 'ID':428475,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2004, 'ID':426892,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2004, 'ID':425346,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2004, 'ID':423631,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2004, 'ID':421965,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2004, 'ID':392522,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2004, 'ID':383482,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2004, 'ID':421434,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2003, 'ID':381379,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2003, 'ID':379879,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2003, 'ID':377506,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2003, 'ID':374184,'fg_count':3, 'tb_count':11},
    {'journal':'JPE', 'year':2003, 'ID':375401,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2003, 'ID':373885,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2003, 'ID':368262,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2003, 'ID':367967,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2002, 'ID':342812,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2002, 'ID':344195,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2002, 'ID':342337,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2002, 'ID':339748,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2002, 'ID':339337,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2002, 'ID':339335,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2001, 'ID':338091,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2001, 'ID':323621,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2001, 'ID':512659,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2001, 'ID':321023,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2001, 'ID':319560,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2001, 'ID':318607,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2000, 'ID':317691,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2000, 'ID':317679,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':2000, 'ID':316105,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':1999, 'ID':250101,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':1999, 'ID':250104,'fg_count':7, 'tb_count':1},
    {'journal':'JPE', 'year':1990, 'ID':2937629,'fg_count':0, 'tb_count':0},
    {'journal':'JPE', 'year':1990, 'ID':2937635,'fg_count':0, 'tb_count':14},
    {'journal':'JPE', 'year':1990, 'ID':2937625,'fg_count':1, 'tb_count':0},
    {'journal':'JPE', 'year':1990, 'ID':2937768,'fg_count':1, 'tb_count':0},
    {'journal':'JPE', 'year':1990, 'ID':2937772,'fg_count':0, 'tb_count':7},
    {'journal':'JPE', 'year':1990, 'ID':2937698,'fg_count':0, 'tb_count':1},
    {'journal':'JPE', 'year':1990, 'ID':2937666,'fg_count':2, 'tb_count':3},
    {'journal':'JPE', 'year':1990, 'ID':2937639,'fg_count':3, 'tb_count':1},
    {'journal':'JPE', 'year':1990, 'ID':2937646,'fg_count':1, 'tb_count':0},
    
    {'journal':'QJE', 'year':2009, 'ID':40506233,'fg_count':0, 'tb_count':0},
    {'journal':'QJE', 'year':2004, 'ID':25098726,'fg_count':1, 'tb_count':0},
    {'journal':'QJE', 'year':2002, 'ID':4132489,'fg_count':0, 'tb_count':4},
    {'journal':'QJE', 'year':2002, 'ID':4132495,'fg_count':4, 'tb_count':3},
    {'journal':'QJE', 'year':2002, 'ID':2696491,'fg_count':3, 'tb_count':0},
    {'journal':'QJE', 'year':2000, 'ID':2587009,'fg_count':0, 'tb_count':0},
    {'journal':'QJE', 'year':1998, 'ID':2586875,'fg_count':0, 'tb_count':12},
    {'journal':'QJE', 'year':1984, 'ID':1885532,'fg_count':0, 'tb_count':0},
    {'journal':'QJE', 'year':1983, 'ID':1881776,'fg_count':0, 'tb_count':0},
    {'journal':'QJE', 'year':1983, 'ID':1881786,'fg_count':2, 'tb_count':0},
    {'journal':'QJE', 'year':1979, 'ID':1884484,'fg_count':0, 'tb_count':1},
    
{'journal':'RES', 'year':2010, 'ID':40587632,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':2008, 'ID':20185062,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':2008, 'ID':4626198,'fg_count':0, 'tb_count':8},
{'journal':'RES', 'year':2006, 'ID':20185031,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':2001, 'ID':2695903,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':1992, 'ID':2297935,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':1992, 'ID':2297936,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':1989, 'ID':23758796,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':1981, 'ID':23758581,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':1979, 'ID':2297181,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':1977, 'ID':2296990,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':1972, 'ID':2296355,'fg_count':0, 'tb_count':0},
{'journal':'RES', 'year':1972, 'ID':2296874,'fg_count':0, 'tb_count':0},
]

# %%
M_collect = pd.DataFrame(manual)

# %% [markdown]
# Note:
#     The econometric society is a miscelanneous author
#     Fellows of the Economic Society as of January
#     The quarterly journal greatly acknowledges. anything with key words containting the journals
#     Statement of Ownership, Management and Circulation
#     INDEX TO VOLUMES 47-56 1980-1989
#     Empirical Applications of Structural Models: Call for Papers
